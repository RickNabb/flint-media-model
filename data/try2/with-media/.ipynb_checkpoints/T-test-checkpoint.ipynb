# %%
#install packages
import csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
from scipy.stats import ranksums

# %%
infl_mod_df = pd.read_csv("influence_mod_with_metrics_laptop.csv")
org_mod_df = pd.read_csv("org_mod_with_metrics_laptop.csv")

# %% [markdown]
# # Test 1: Global Kruskal-Wallis (All runs)
#
# ## First, run global, then for each org-strat/org-cap combo
# ### What do we see?

# %%
#Total runs

infl_mod_peaks = infl_mod_df['peak-time'].to_numpy()
org_mod_peaks = org_mod_df['peak-time'].to_numpy()

stats.kruskal(infl_mod_peaks, org_mod_peaks)
#Note: are these really independent trials??? sort of?
# Out:
# KruskalResult(statistic=660.7608824142045, pvalue=1.020611737066442e-145)

# %%
# let's break town per org strat/org mod combo

org_strat_list = ['neighbors-of-neighbors', "high-degree-citizens", "high-degree-media", "high-degree-cit-and-media"]
org_cap_list = [1,5]

for i in range(0, len(org_strat_list)):
    org_mod_strat = org_mod_df.loc[org_mod_df["flint-organizing-strategy"] == org_strat_list[i]]
    for j in range(0, len(org_cap_list)):
        org_mod_cap = org_mod_strat.loc[org_mod_strat['organizing-capacity'] == org_cap_list[j]]
        infl_mod_peaks = infl_mod_df['peak-time'].to_numpy()
        org_mod_peaks = org_mod_cap['peak-time'].to_numpy()
        print(org_strat_list[i], org_cap_list[j])
        print(stats.kruskal(infl_mod_peaks, org_mod_peaks))
#we won't break down the other parameters yet- let's see how we do on these 8 tests
# Out:
# neighbors-of-neighbors 1
# KruskalResult(statistic=59.3494045022673, pvalue=1.3202012921332312e-14)
# neighbors-of-neighbors 5
# KruskalResult(statistic=170.44757660170072, pvalue=5.907612871765762e-39)
# high-degree-citizens 1
# KruskalResult(statistic=168.509063354346, pvalue=1.5660662558245732e-38)
# high-degree-citizens 5
# KruskalResult(statistic=298.5937811800566, pvalue=6.670239822881502e-67)
# high-degree-media 1
# KruskalResult(statistic=115.30774981137318, pvalue=6.738497216470113e-27)
# high-degree-media 5
# KruskalResult(statistic=281.7793422277938, pvalue=3.075041260928089e-63)
# high-degree-cit-and-media 1
# KruskalResult(statistic=128.40287942535943, pvalue=9.16226517646946e-30)
# high-degree-cit-and-media 5
# KruskalResult(statistic=295.45596167191025, pvalue=3.21950500869596e-66)

# %% [markdown]
# ## UPDATE: Moving to Wilcoxon tests because it appears that Kruskal- Wallis is designed for 2 groups

# %%
infl_mod_peaks = infl_mod_df['peak-time'].to_numpy()
org_mod_peaks = org_mod_df['peak-time'].to_numpy()

print(ranksums(infl_mod_peaks, org_mod_peaks))
#Note: are these really independent trials??? sort of?
# Out:
# RanksumsResult(statistic=25.698483640914542, pvalue=1.21540323938797e-145)

# %%
org_strat_list = ['neighbors-of-neighbors', "high-degree-citizens", "high-degree-media", "high-degree-cit-and-media"]
org_cap_list = [1,5]

for i in range(0, len(org_strat_list)):
    org_mod_strat = org_mod_df.loc[org_mod_df["flint-organizing-strategy"] == org_strat_list[i]]
    for j in range(0, len(org_cap_list)):
        org_mod_cap = org_mod_strat.loc[org_mod_strat['organizing-capacity'] == org_cap_list[j]]
        infl_mod_peaks = infl_mod_df['peak-time'].to_numpy()
        org_mod_peaks = org_mod_cap['peak-time'].to_numpy()
        print(org_strat_list[i], org_cap_list[j])
        print(ranksums(infl_mod_peaks, org_mod_peaks))
#we won't break down the other parameters yet- let's see how we do on these 8 tests
# Out:
# neighbors-of-neighbors 1
# RanksumsResult(statistic=7.7019887024107625, pvalue=1.3396473404887347e-14)
# neighbors-of-neighbors 5
# RanksumsResult(statistic=13.052291505085437, pvalue=6.166433886348462e-39)
# high-degree-citizens 1
# RanksumsResult(statistic=12.977925112728578, pvalue=1.632431407772714e-38)
# high-degree-citizens 5
# RanksumsResult(statistic=17.27546385740577, pvalue=7.199227940110784e-67)
# high-degree-media 1
# RanksumsResult(statistic=10.735541055928563, pvalue=6.931175421071367e-27)
# high-degree-media 5
# RanksumsResult(statistic=16.782089528328253, pvalue=3.300167246981936e-63)
# high-degree-cit-and-media 1
# RanksumsResult(statistic=11.328736349132573, pvalue=9.455907969483027e-30)
# high-degree-cit-and-media 5
# RanksumsResult(statistic=17.184491104897788, pvalue=3.4697831918155465e-66)

# %%
org_strat_list = ['neighbors-of-neighbors', "high-degree-citizens", "high-degree-media", "high-degree-cit-and-media"]
org_cap_list = [1,5]
p_list =[0.01, 0.05, 0.1, 0.25, 0.5, 0.75]
cit_cit_list = [0.01, 0.05, 0.1, 0.25, 0.5, 0.75]
cit_media_list = [0.01, 0.05, 0.1, 0.25, 0.5, 0.75]
ba_m_list = [3, 10]
total_scen = 0

for i in range(0, len(org_strat_list)):
    org_mod_strat = org_mod_df.loc[org_mod_df["flint-organizing-strategy"] == org_strat_list[i]]
    for j in range(0, len(org_cap_list)):
        org_mod_cap = org_mod_strat.loc[org_mod_strat['organizing-capacity'] == org_cap_list[j]]
        for k in range(0, len(p_list)):
            org_mod_p = org_mod_cap.loc[org_mod_cap["simple-spread-chance"] == p_list[k]]
            infl_mod_p = infl_mod_df.loc[infl_mod_df["simple-spread-chance"] == p_list[k]]
            for l in range(0, len(cit_cit_list)):
                org_mod_cc= org_mod_p.loc[org_mod_p["citizen-citizen-influence"] == cit_cit_list[l]]
                infl_mod_cc = infl_mod_p.loc[infl_mod_p["citizen-citizen-influence"] == cit_cit_list[l]]
                for m in range(0, len(cit_media_list)):
                    org_mod_cm= org_mod_cc.loc[org_mod_cc["citizen-media-influence"] == cit_media_list[m]]
                    infl_mod_cm = infl_mod_cc.loc[infl_mod_cc["citizen-media-influence"] == cit_media_list[m]]
                    for n in range(0, len(ba_m_list)):
                        org_mod_b= org_mod_cm.loc[org_mod_cm["ba-m"] == ba_m_list[n]]
                        infl_mod_b = infl_mod_cm.loc[infl_mod_cm["ba-m"] == ba_m_list[n]]
                        
                        infl_mod_peaks = infl_mod_b['peak-time'].to_numpy()
                        org_mod_peaks = org_mod_b['peak-time'].to_numpy()
                        print(org_strat_list[i], org_cap_list[j], p_list[k], cit_cit_list[l], cit_media_list[m], ba_m_list[n])
                        print(ranksums(infl_mod_peaks, org_mod_peaks))
                        total_scen = total_scen + 1
                        
print("total_Scen", total_scen)
# Out:
# neighbors-of-neighbors 1 0.01 0.01 0.01 3
# RanksumsResult(statistic=7.551962412507515, pvalue=4.2874823941872747e-14)
# neighbors-of-neighbors 1 0.01 0.01 0.01 10
# RanksumsResult(statistic=8.114281341825102, pvalue=4.886680715344223e-16)
# neighbors-of-neighbors 1 0.01 0.01 0.05 3
# RanksumsResult(statistic=6.617323099955759, pvalue=3.657614988848676e-11)
# neighbors-of-neighbors 1 0.01 0.01 0.05 10
# RanksumsResult(statistic=5.172182643381894, pvalue=2.3137525542198082e-07)
# neighbors-of-neighbors 1 0.01 0.01 0.1 3
# RanksumsResult(statistic=6.049246638938675, pvalue=1.4552472721064642e-09)
# neighbors-of-neighbors 1 0.01 0.01 0.1 10
# RanksumsResult(statistic=5.26762656559869, pvalue=1.3819887665151723e-07)
# neighbors-of-neighbors 1 0.01 0.01 0.25 3
# RanksumsResult(statistic=3.009269901604011, pvalue=0.002618763601192218)
# neighbors-of-neighbors 1 0.01 0.01 0.25 10
# RanksumsResult(statistic=5.759450876730636, pvalue=8.438801309091621e-09)
# neighbors-of-neighbors 1 0.01 0.01 0.5 3
# RanksumsResult(statistic=0.9768612116814042, pvalue=0.3286378669763188)
# neighbors-of-neighbors 1 0.01 0.01 0.5 10
# RanksumsResult(statistic=3.76350655423818, pvalue=0.00016754733358164512)
# neighbors-of-neighbors 1 0.01 0.01 0.75 3
# RanksumsResult(statistic=0.9308009580854244, pvalue=0.3519565340173525)
# neighbors-of-neighbors 1 0.01 0.01 0.75 10
# RanksumsResult(statistic=0.019309481545449744, pvalue=0.984594220160167)
# neighbors-of-neighbors 1 0.01 0.05 0.01 3
# RanksumsResult(statistic=3.573508008154763, pvalue=0.0003522304658330789)
# neighbors-of-neighbors 1 0.01 0.05 0.01 10
# RanksumsResult(statistic=4.262492634861294, pvalue=2.021591637708487e-05)
# neighbors-of-neighbors 1 0.01 0.05 0.05 3
# RanksumsResult(statistic=4.367804725580732, pvalue=1.255016246543982e-05)
# neighbors-of-neighbors 1 0.01 0.05 0.05 10
# RanksumsResult(statistic=3.1263397128271264, pvalue=0.0017699696126643224)
# neighbors-of-neighbors 1 0.01 0.05 0.1 3
# RanksumsResult(statistic=2.1725086279437122, pvalue=0.029817319568077143)
# neighbors-of-neighbors 1 0.01 0.05 0.1 10
# RanksumsResult(statistic=1.7829156496110499, pvalue=0.0746000351864719)
# neighbors-of-neighbors 1 0.01 0.05 0.25 3
# RanksumsResult(statistic=1.2244350747597954, pvalue=0.22078814455690277)
# neighbors-of-neighbors 1 0.01 0.05 0.25 10
# RanksumsResult(statistic=2.5160413526803946, pvalue=0.011868125690831946)
# neighbors-of-neighbors 1 0.01 0.05 0.5 3
# RanksumsResult(statistic=0.529659384167093, pvalue=0.5963481131324073)
# neighbors-of-neighbors 1 0.01 0.05 0.5 10
# RanksumsResult(statistic=2.408567427623108, pvalue=0.016015267600244847)
# neighbors-of-neighbors 1 0.01 0.05 0.75 3
# RanksumsResult(statistic=-0.575753169949747, pvalue=0.5647820310198043)
# neighbors-of-neighbors 1 0.01 0.05 0.75 10
# RanksumsResult(statistic=0.32633023811810064, pvalue=0.7441745126173596)
# neighbors-of-neighbors 1 0.01 0.1 0.01 3
# RanksumsResult(statistic=1.9135696211540696, pvalue=0.05567516978839568)
# neighbors-of-neighbors 1 0.01 0.1 0.01 10
# RanksumsResult(statistic=3.056690928644694, pvalue=0.0022379490234802186)
# neighbors-of-neighbors 1 0.01 0.1 0.05 3
# RanksumsResult(statistic=1.0075680474120572, pvalue=0.31366187485574926)
# neighbors-of-neighbors 1 0.01 0.1 0.05 10
# RanksumsResult(statistic=1.3012021640864282, pvalue=0.19318926472900855)
# neighbors-of-neighbors 1 0.01 0.1 0.1 3
# RanksumsResult(statistic=1.3875651395788904, pvalue=0.16526950283772024)
# neighbors-of-neighbors 1 0.01 0.1 0.1 10
# RanksumsResult(statistic=0.1554533558864317, pvalue=0.8764639234477992)
# neighbors-of-neighbors 1 0.01 0.1 0.25 3
# RanksumsResult(statistic=-1.9633183095286373, pvalue=0.04960919925708043)
# neighbors-of-neighbors 1 0.01 0.1 0.25 10
# RanksumsResult(statistic=2.446067046952747, pvalue=0.014442414026724254)
# neighbors-of-neighbors 1 0.01 0.1 0.5 3
# RanksumsResult(statistic=0.4507446822025713, pvalue=0.6521735745592814)
# neighbors-of-neighbors 1 0.01 0.1 0.5 10
# RanksumsResult(statistic=-0.8770639955567813, pvalue=0.38045187937888747)
# neighbors-of-neighbors 1 0.01 0.1 0.75 3
# RanksumsResult(statistic=-0.9039324768211028, pvalue=0.3660312069101994)
# neighbors-of-neighbors 1 0.01 0.1 0.75 10
# RanksumsResult(statistic=1.4163527980763777, pvalue=0.1566722365473763)
# neighbors-of-neighbors 1 0.01 0.25 0.01 3
# RanksumsResult(statistic=-0.4209466976908044, pvalue=0.6737940046160676)
# neighbors-of-neighbors 1 0.01 0.25 0.01 10
# RanksumsResult(statistic=-2.0631155256532603, pvalue=0.03910165342447288)
# neighbors-of-neighbors 1 0.01 0.25 0.05 3
# RanksumsResult(statistic=-0.11585688927269847, pvalue=0.9077659629132487)
# neighbors-of-neighbors 1 0.01 0.25 0.05 10
# RanksumsResult(statistic=-2.565939960742706, pvalue=0.010289663696148584)
# neighbors-of-neighbors 1 0.01 0.25 0.1 3
# RanksumsResult(statistic=-1.9921059680261246, pvalue=0.0463594322965929)
# neighbors-of-neighbors 1 0.01 0.25 0.1 10
# RanksumsResult(statistic=-0.47501324601806366, pvalue=0.634777532017426)
# neighbors-of-neighbors 1 0.01 0.25 0.25 3
# RanksumsResult(statistic=-0.7811051338984901, pvalue=0.4347406626573165)
# neighbors-of-neighbors 1 0.01 0.25 0.25 10
# RanksumsResult(statistic=-0.2590889264773862, pvalue=0.7955666285533602)
# neighbors-of-neighbors 1 0.01 0.25 0.5 3
# RanksumsResult(statistic=-3.686739464911547, pvalue=0.00022714569593199128)
# neighbors-of-neighbors 1 0.01 0.25 0.5 10
# RanksumsResult(statistic=-2.3932140097577816, pvalue=0.016701496132631086)
# neighbors-of-neighbors 1 0.01 0.25 0.75 3
# RanksumsResult(statistic=-1.9729141956944665, pvalue=0.04850533899865822)
# neighbors-of-neighbors 1 0.01 0.25 0.75 10
# RanksumsResult(statistic=0.5638368611271325, pvalue=0.5728651630341485)
# neighbors-of-neighbors 1 0.01 0.5 0.01 3
# RanksumsResult(statistic=-1.6159472303256233, pvalue=0.10610572285091015)
# neighbors-of-neighbors 1 0.01 0.5 0.01 10
# RanksumsResult(statistic=-4.139665291938681, pvalue=3.478129176164519e-05)
# neighbors-of-neighbors 1 0.01 0.5 0.05 3
# RanksumsResult(statistic=-2.6810905947326553, pvalue=0.007338264640296098)
# neighbors-of-neighbors 1 0.01 0.5 0.05 10
# RanksumsResult(statistic=-1.9460457144301448, pvalue=0.051649248557880036)
# neighbors-of-neighbors 1 0.01 0.5 0.1 3
# RanksumsResult(statistic=-2.6024043281728564, pvalue=0.00925726400703469)
# neighbors-of-neighbors 1 0.01 0.5 0.1 10
# RanksumsResult(statistic=-3.4871450326623012, pvalue=0.0004882065281269717)
# neighbors-of-neighbors 1 0.01 0.5 0.25 3
# RanksumsResult(statistic=-0.5508038659185913, pvalue=0.5817681337497668)
# neighbors-of-neighbors 1 0.01 0.5 0.25 10
# RanksumsResult(statistic=0.35888614260200896, pvalue=0.7196802666070132)
# neighbors-of-neighbors 1 0.01 0.5 0.5 3
# RanksumsResult(statistic=-0.26950056370884945, pvalue=0.7875445084811331)
# neighbors-of-neighbors 1 0.01 0.5 0.5 10
# RanksumsResult(statistic=0.37999709216683303, pvalue=0.7039475736599878)
# neighbors-of-neighbors 1 0.01 0.5 0.75 3
# RanksumsResult(statistic=-1.2704953283557752, pvalue=0.2039082458779019)
# neighbors-of-neighbors 1 0.01 0.5 0.75 10
# RanksumsResult(statistic=0.7676708932663293, pvalue=0.44268273274812764)
# neighbors-of-neighbors 1 0.01 0.75 0.01 3
# RanksumsResult(statistic=-2.932502812277378, pvalue=0.0033624187725766414)
# neighbors-of-neighbors 1 0.01 0.75 0.01 10
# RanksumsResult(statistic=-5.189455238480386, pvalue=2.1091019414739767e-07)
# neighbors-of-neighbors 1 0.01 0.75 0.05 3
# RanksumsResult(statistic=-2.4296783771879324, pvalue=0.015112226507243453)
# neighbors-of-neighbors 1 0.01 0.75 0.05 10
# RanksumsResult(statistic=-2.1568690886267365, pvalue=0.031015866057371992)
# neighbors-of-neighbors 1 0.01 0.75 0.1 3
# RanksumsResult(statistic=-2.293416793633159, pvalue=0.021824020699206078)
# neighbors-of-neighbors 1 0.01 0.75 0.1 10
# RanksumsResult(statistic=-2.1510762441631015, pvalue=0.03147018221321602)
# neighbors-of-neighbors 1 0.01 0.75 0.25 3
# RanksumsResult(statistic=1.421177841745101, pvalue=0.15526506471327697)
# neighbors-of-neighbors 1 0.01 0.75 0.25 10
# RanksumsResult(statistic=0.8727885658543284, pvalue=0.3827783330602269)
# neighbors-of-neighbors 1 0.01 0.75 0.5 3
# RanksumsResult(statistic=-0.9538310848834143, pvalue=0.34016915188524965)
# neighbors-of-neighbors 1 0.01 0.75 0.5 10
# RanksumsResult(statistic=2.262709957902506, pvalue=0.02365357457393398)
# neighbors-of-neighbors 1 0.01 0.75 0.75 3
# RanksumsResult(statistic=0.4855518399909533, pvalue=0.6272849492883783)
# neighbors-of-neighbors 1 0.01 0.75 0.75 10
# RanksumsResult(statistic=1.9709950184613005, pvalue=0.04872444561703773)
# neighbors-of-neighbors 1 0.05 0.01 0.01 3
# RanksumsResult(statistic=5.763289231196968, pvalue=8.249025096808522e-09)
# neighbors-of-neighbors 1 0.05 0.01 0.01 10
# RanksumsResult(statistic=3.8959297833266215, pvalue=9.78227284528637e-05)
# neighbors-of-neighbors 1 0.05 0.01 0.05 3
# RanksumsResult(statistic=0.20151360948241145, pvalue=0.8402969888731917)
# neighbors-of-neighbors 1 0.05 0.01 0.05 10
# RanksumsResult(statistic=2.241830807426715, pvalue=0.0249723093312132)
# neighbors-of-neighbors 1 0.05 0.01 0.1 3
# RanksumsResult(statistic=0.5066627895557774, pvalue=0.612391443618159)
# neighbors-of-neighbors 1 0.05 0.01 0.1 10
# RanksumsResult(statistic=2.326042806596978, pvalue=0.020016267173205406)
# neighbors-of-neighbors 1 0.05 0.01 0.25 3
# RanksumsResult(statistic=-0.424138168529647, pvalue=0.6714650508637703)
# neighbors-of-neighbors 1 0.05 0.01 0.25 10
# RanksumsResult(statistic=1.9095813469999943, pvalue=0.05618713867980016)
# neighbors-of-neighbors 1 0.05 0.01 0.5 3
# RanksumsResult(statistic=-0.4711513497089737, pvalue=0.6375326577220026)
# neighbors-of-neighbors 1 0.05 0.01 0.5 10
# RanksumsResult(statistic=-0.6507295280816563, pvalue=0.5152210985520869)
# neighbors-of-neighbors 1 0.05 0.01 0.75 3
# RanksumsResult(statistic=-1.846248498305522, pvalue=0.06485613197554005)
# neighbors-of-neighbors 1 0.05 0.01 0.75 10
# RanksumsResult(statistic=0.7926201972974851, pvalue=0.42799913769412745)
# neighbors-of-neighbors 1 0.05 0.05 0.01 3
# RanksumsResult(statistic=-1.1342337448010016, pvalue=0.2566965126668186)
# neighbors-of-neighbors 1 0.05 0.05 0.01 10
# RanksumsResult(statistic=-1.4604938744391915, pvalue=0.14415438982860032)
# neighbors-of-neighbors 1 0.05 0.05 0.05 3
# RanksumsResult(statistic=1.2205967202934638, pvalue=0.22223874873102079)
# neighbors-of-neighbors 1 0.05 0.05 0.05 10
# RanksumsResult(statistic=0.6966613356391939, pvalue=0.4860147610388904)
# neighbors-of-neighbors 1 0.05 0.05 0.1 3
# RanksumsResult(statistic=-1.999782676958788, pvalue=0.04552373595890541)
# neighbors-of-neighbors 1 0.05 0.05 0.1 10
# RanksumsResult(statistic=1.663926661154769, pvalue=0.09612708630458668)
# neighbors-of-neighbors 1 0.05 0.05 0.25 3
# RanksumsResult(statistic=0.6870654494733648, pvalue=0.4920414854783316)
# neighbors-of-neighbors 1 0.05 0.05 0.25 10
# RanksumsResult(statistic=0.13434240632160763, pvalue=0.893131821752615)
# neighbors-of-neighbors 1 0.05 0.05 0.5 3
# RanksumsResult(statistic=-0.6717120316080382, pvalue=0.5017670403101799)
# neighbors-of-neighbors 1 0.05 0.05 0.5 10
# RanksumsResult(statistic=0.3723203832341697, pvalue=0.7096543241593918)
# neighbors-of-neighbors 1 0.05 0.05 0.75 3
# RanksumsResult(statistic=0.8981749451216053, pvalue=0.36909228861252075)
# neighbors-of-neighbors 1 0.05 0.05 0.75 10
# RanksumsResult(statistic=-1.554533558864317, pvalue=0.12005719820843133)
# neighbors-of-neighbors 1 0.05 0.1 0.01 3
# RanksumsResult(statistic=-2.596646796473359, pvalue=0.00941386704182084)
# neighbors-of-neighbors 1 0.05 0.1 0.01 10
# RanksumsResult(statistic=-1.0040930403633868, pvalue=0.3153337696977423)
# neighbors-of-neighbors 1 0.05 0.1 0.05 3
# RanksumsResult(statistic=-0.9653461482824092, pvalue=0.33437146461036793)
# neighbors-of-neighbors 1 0.05 0.1 0.05 10
# RanksumsResult(statistic=0.49706690338994824, pvalue=0.6191418728797323)
# neighbors-of-neighbors 1 0.05 0.1 0.1 3
# RanksumsResult(statistic=-1.2858487462211017, pvalue=0.19849585406545112)
# neighbors-of-neighbors 1 0.05 0.1 0.1 10
# RanksumsResult(statistic=-1.8616019161708488, pvalue=0.06265922300744195)
# neighbors-of-neighbors 1 0.05 0.1 0.25 3
# RanksumsResult(statistic=0.4107039278974862, pvalue=0.681289646406868)
# neighbors-of-neighbors 1 0.05 0.1 0.25 10
# RanksumsResult(statistic=0.1800808673178424, pvalue=0.8570890827239026)
# neighbors-of-neighbors 1 0.05 0.1 0.5 3
# RanksumsResult(statistic=1.1150419724693434, pvalue=0.26483243585236604)
# neighbors-of-neighbors 1 0.05 0.1 0.5 10
# RanksumsResult(statistic=0.5603997520844204, pvalue=0.5752068006930979)
# neighbors-of-neighbors 1 0.05 0.1 0.75 3
# RanksumsResult(statistic=-0.999891338479394, pvalue=0.317363096533678)
# neighbors-of-neighbors 1 0.05 0.1 0.75 10
# RanksumsResult(statistic=2.001701854191954, pvalue=0.04531680687383429)
# neighbors-of-neighbors 1 0.05 0.25 0.01 3
# RanksumsResult(statistic=-3.498660096061296, pvalue=0.00046760227158708953)
# neighbors-of-neighbors 1 0.05 0.25 0.01 10
# RanksumsResult(statistic=-2.510283820980897, pvalue=0.012063415964255827)
# neighbors-of-neighbors 1 0.05 0.25 0.05 3
# RanksumsResult(statistic=0.13626158355477347, pvalue=0.8916144924501823)
# neighbors-of-neighbors 1 0.05 0.25 0.05 10
# RanksumsResult(statistic=-2.6202966457175303, pvalue=0.008785330879949366)
# neighbors-of-neighbors 1 0.05 0.25 0.1 3
# RanksumsResult(statistic=0.10363557059095446, pvalue=0.9174585583906181)
# neighbors-of-neighbors 1 0.05 0.25 0.1 10
# RanksumsResult(statistic=1.5913667948848464, pvalue=0.11152705259423713)
# neighbors-of-neighbors 1 0.05 0.25 0.25 3
# RanksumsResult(statistic=2.780887810857278, pvalue=0.005421046770283473)
# neighbors-of-neighbors 1 0.05 0.25 0.25 10
# RanksumsResult(statistic=-1.361318448954207, pvalue=0.1734130752315972)
# neighbors-of-neighbors 1 0.05 0.25 0.5 3
# RanksumsResult(statistic=3.1915917387547643, pvalue=0.001414911704245335)
# neighbors-of-neighbors 1 0.05 0.25 0.5 10
# RanksumsResult(statistic=-0.021110949564824056, pvalue=0.9831571503525829)
# neighbors-of-neighbors 1 0.05 0.25 0.75 3
# RanksumsResult(statistic=-1.262818619423112, pvalue=0.2066543716759306)
# neighbors-of-neighbors 1 0.05 0.25 0.75 10
# RanksumsResult(statistic=0.3281793068713558, pvalue=0.74277609291809)
# neighbors-of-neighbors 1 0.05 0.5 0.01 3
# RanksumsResult(statistic=1.021002288044218, pvalue=0.3072533546840891)
# neighbors-of-neighbors 1 0.05 0.5 0.01 10
# RanksumsResult(statistic=-1.2570610877236144, pvalue=0.20873151614671603)
# neighbors-of-neighbors 1 0.05 0.5 0.05 3
# RanksumsResult(statistic=2.8019987604221024, pvalue=0.005078706877394067)
# neighbors-of-neighbors 1 0.05 0.5 0.05 10
# RanksumsResult(statistic=0.8350410686570711, pvalue=0.40369458546468195)
# neighbors-of-neighbors 1 0.05 0.5 0.1 3
# RanksumsResult(statistic=2.661898822400997, pvalue=0.007770123049610327)
# neighbors-of-neighbors 1 0.05 0.5 0.1 10
# RanksumsResult(statistic=1.7042293830512512, pvalue=0.08833824183020182)
# neighbors-of-neighbors 1 0.05 0.5 0.25 3
# RanksumsResult(statistic=-1.2110008341276346, pvalue=0.2258950850152639)
# neighbors-of-neighbors 1 0.05 0.5 0.25 10
# RanksumsResult(statistic=-2.3106893887316513, pvalue=0.020850017779885172)
# neighbors-of-neighbors 1 0.05 0.5 0.5 3
# RanksumsResult(statistic=-0.29939164837386845, pvalue=0.7646412337360282)
# neighbors-of-neighbors 1 0.05 0.5 0.5 10
# RanksumsResult(statistic=1.109284440769846, pvalue=0.26730749509949026)
# neighbors-of-neighbors 1 0.05 0.5 0.75 3
# RanksumsResult(statistic=-0.848276337059294, pvalue=0.3962840926183341)
# neighbors-of-neighbors 1 0.05 0.5 0.75 10
# RanksumsResult(statistic=1.2685761511226092, pvalue=0.20459227472632047)
# neighbors-of-neighbors 1 0.05 0.75 0.01 3
# RanksumsResult(statistic=1.5449376726984878, pvalue=0.12236133996673944)
# neighbors-of-neighbors 1 0.05 0.75 0.01 10
# RanksumsResult(statistic=-3.3336108540090352, pvalue=0.000857265033606983)
# neighbors-of-neighbors 1 0.05 0.75 0.05 3
# RanksumsResult(statistic=0.978990714354302, pvalue=0.32758456759015064)
# neighbors-of-neighbors 1 0.05 0.75 0.05 10
# RanksumsResult(statistic=1.3933226712783877, pvalue=0.16352223790825693)
# neighbors-of-neighbors 1 0.05 0.75 0.1 3
# RanksumsResult(statistic=3.0457342690341616, pvalue=0.0023211287615472168)
# neighbors-of-neighbors 1 0.05 0.75 0.1 10
# RanksumsResult(statistic=-0.6333284869447218, pvalue=0.5265191542415524)
# neighbors-of-neighbors 1 0.05 0.75 0.25 3
# RanksumsResult(statistic=1.4018683601996513, pvalue=0.160954560209425)
# neighbors-of-neighbors 1 0.05 0.75 0.25 10
# RanksumsResult(statistic=2.849978191251248, pvalue=0.0043722226920268085)
# neighbors-of-neighbors 1 0.05 0.75 0.5 3
# RanksumsResult(statistic=4.680873271691444, pvalue=2.856554879407913e-06)
# neighbors-of-neighbors 1 0.05 0.75 0.5 10
# RanksumsResult(statistic=1.6792800790200955, pvalue=0.09309747154851818)
# neighbors-of-neighbors 1 0.05 0.75 0.75 3
# RanksumsResult(statistic=-0.3514325641271853, pvalue=0.7252638557803162)
# neighbors-of-neighbors 1 0.05 0.75 0.75 10
# RanksumsResult(statistic=0.23989715414572793, pvalue=0.8104099871120831)
# neighbors-of-neighbors 1 0.1 0.01 0.01 3
# RanksumsResult(statistic=3.3412875629416985, pvalue=0.0008339080472095971)
# neighbors-of-neighbors 1 0.1 0.01 0.01 10
# RanksumsResult(statistic=2.7616960385256197, pvalue=0.005750198436756536)
# neighbors-of-neighbors 1 0.1 0.01 0.05 3
# RanksumsResult(statistic=-0.4344633347726192, pvalue=0.6639520144809165)
# neighbors-of-neighbors 1 0.1 0.01 0.05 10
# RanksumsResult(statistic=0.3552944604362753, pvalue=0.7223690050391373)
# neighbors-of-neighbors 1 0.1 0.01 0.1 3
# RanksumsResult(statistic=-0.1400999380211051, pvalue=0.8885810295622768)
# neighbors-of-neighbors 1 0.1 0.01 0.1 10
# RanksumsResult(statistic=-0.21110949564824058, pvalue=0.8328018307548968)
# neighbors-of-neighbors 1 0.1 0.01 0.25 3
# RanksumsResult(statistic=-0.6870654494733648, pvalue=0.4920414854783316)
# neighbors-of-neighbors 1 0.1 0.01 0.25 10
# RanksumsResult(statistic=0.7369640575356762, pvalue=0.46114420714392645)
# neighbors-of-neighbors 1 0.1 0.01 0.5 3
# RanksumsResult(statistic=0.5174941054180531, pvalue=0.6048112827057195)
# neighbors-of-neighbors 1 0.1 0.01 0.5 10
# RanksumsResult(statistic=0.2648464581768836, pvalue=0.7911277459294537)
# neighbors-of-neighbors 1 0.1 0.01 0.75 3
# RanksumsResult(statistic=0.4625217131929634, pvalue=0.6437072350586424)
# neighbors-of-neighbors 1 0.1 0.01 0.75 10
# RanksumsResult(statistic=0.25141221754472287, pvalue=0.801495422766016)
# neighbors-of-neighbors 1 0.1 0.05 0.01 3
# RanksumsResult(statistic=-0.41262310513065203, pvalue=0.67988277037759)
# neighbors-of-neighbors 1 0.1 0.05 0.01 10
# RanksumsResult(statistic=-1.0335075863458782, pvalue=0.3013664221313901)
# neighbors-of-neighbors 1 0.1 0.05 0.05 3
# RanksumsResult(statistic=1.011406401878389, pvalue=0.3118219583724834)
# neighbors-of-neighbors 1 0.1 0.05 0.05 10
# RanksumsResult(statistic=-1.262818619423112, pvalue=0.2066543716759306)
# neighbors-of-neighbors 1 0.1 0.05 0.1 3
# RanksumsResult(statistic=1.967156663994969, pvalue=0.04916515233197787)
# neighbors-of-neighbors 1 0.1 0.05 0.1 10
# RanksumsResult(statistic=-0.10363557059095446, pvalue=0.9174585583906181)
# neighbors-of-neighbors 1 0.1 0.05 0.25 3
# RanksumsResult(statistic=-0.8214078557949724, pvalue=0.41141399034618387)
# neighbors-of-neighbors 1 0.1 0.05 0.25 10
# RanksumsResult(statistic=-0.22262455904723552, pvalue=0.8238277207325432)
# neighbors-of-neighbors 1 0.1 0.05 0.5 3
# RanksumsResult(statistic=-0.09595886165829116, pvalue=0.9235532453724784)
# neighbors-of-neighbors 1 0.1 0.05 0.5 10
# RanksumsResult(statistic=0.9442351987175851, pvalue=0.3450494719089633)
# neighbors-of-neighbors 1 0.1 0.05 0.75 3
# RanksumsResult(statistic=0.6928229811728622, pvalue=0.48842064827052367)
# neighbors-of-neighbors 1 0.1 0.05 0.75 10
# RanksumsResult(statistic=-0.554642220384923, pvalue=0.5791394044060465)
# neighbors-of-neighbors 1 0.1 0.1 0.01 3
# RanksumsResult(statistic=-0.6774695633075357, pvalue=0.49810807508836663)
# neighbors-of-neighbors 1 0.1 0.1 0.01 10
# RanksumsResult(statistic=-0.47787513105829005, pvalue=0.6327390827335031)
# neighbors-of-neighbors 1 0.1 0.1 0.05 3
# RanksumsResult(statistic=0.07484791209346711, pvalue=0.9403357203629744)
# neighbors-of-neighbors 1 0.1 0.1 0.05 10
# RanksumsResult(statistic=1.0407810552997412, pvalue=0.2979771744262667)
# neighbors-of-neighbors 1 0.1 0.1 0.1 3
# RanksumsResult(statistic=2.122610019881401, pvalue=0.03378654462505419)
# neighbors-of-neighbors 1 0.1 0.1 0.1 10
# RanksumsResult(statistic=-1.184132352863313, pvalue=0.2363606750121815)
# neighbors-of-neighbors 1 0.1 0.1 0.25 3
# RanksumsResult(statistic=1.0497899465417053, pvalue=0.2938146984792791)
# neighbors-of-neighbors 1 0.1 0.1 0.25 10
# RanksumsResult(statistic=-1.4508979882733626, pvalue=0.14680826818487328)
# neighbors-of-neighbors 1 0.1 0.1 0.5 3
# RanksumsResult(statistic=-0.14182914569305044, pvalue=0.8872149618431077)
# neighbors-of-neighbors 1 0.1 0.1 0.5 10
# RanksumsResult(statistic=-0.8885790589557763, pvalue=0.37422934958738574)
# neighbors-of-neighbors 1 0.1 0.1 0.75 3
# RanksumsResult(statistic=0.01727259509849241, pvalue=0.9862191482850413)
# neighbors-of-neighbors 1 0.1 0.1 0.75 10
# RanksumsResult(statistic=-0.02303012679798988, pvalue=0.981626241608544)
# neighbors-of-neighbors 1 0.1 0.25 0.01 3
# RanksumsResult(statistic=-0.23222044521306462, pvalue=0.8163667987697143)
# neighbors-of-neighbors 1 0.1 0.25 0.01 10
# RanksumsResult(statistic=-0.32626012963818996, pvalue=0.7442275511207657)
# neighbors-of-neighbors 1 0.1 0.25 0.05 3
# RanksumsResult(statistic=0.03089517047271959, pvalue=0.9753531414906936)
# neighbors-of-neighbors 1 0.1 0.25 0.05 10
# RanksumsResult(statistic=0.5128389917095078, pvalue=0.6080639521780646)
# neighbors-of-neighbors 1 0.1 0.25 0.1 3
# RanksumsResult(statistic=0.3185834207055267, pvalue=0.7500424272133137)
# neighbors-of-neighbors 1 0.1 0.25 0.1 10
# RanksumsResult(statistic=-0.9979721612462281, pvalue=0.3182928581022264)
# neighbors-of-neighbors 1 0.1 0.25 0.25 3
# RanksumsResult(statistic=-2.836543950619087, pvalue=0.004560470111329582)
# neighbors-of-neighbors 1 0.1 0.25 0.25 10
# RanksumsResult(statistic=2.9919973065055188, pvalue=0.00277158708454787)
# neighbors-of-neighbors 1 0.1 0.25 0.5 3
# RanksumsResult(statistic=0.14393829248743675, pvalue=0.8855491974882863)
# neighbors-of-neighbors 1 0.1 0.25 0.5 10
# RanksumsResult(statistic=-0.5412079797527622, pvalue=0.5883642379549373)
# neighbors-of-neighbors 1 0.1 0.25 0.75 3
# RanksumsResult(statistic=1.9613991322954716, pvalue=0.049832481148193886)
# neighbors-of-neighbors 1 0.1 0.25 0.75 10
# RanksumsResult(statistic=-0.6506010820432141, pvalue=0.5153040317018884)
# neighbors-of-neighbors 1 0.1 0.5 0.01 3
# RanksumsResult(statistic=3.467953260330643, pvalue=0.0005244384951008478)
# neighbors-of-neighbors 1 0.1 0.5 0.01 10
# RanksumsResult(statistic=-0.7964585517638167, pvalue=0.42576555750840805)
# neighbors-of-neighbors 1 0.1 0.5 0.05 3
# RanksumsResult(statistic=0.7216106396703496, pvalue=0.4705338958624645)
# neighbors-of-neighbors 1 0.1 0.5 0.05 10
# RanksumsResult(statistic=-0.22262455904723552, pvalue=0.8238277207325432)
# neighbors-of-neighbors 1 0.1 0.5 0.1 3
# RanksumsResult(statistic=0.3704012060010039, pvalue=0.7110835753511068)
# neighbors-of-neighbors 1 0.1 0.5 0.1 10
# RanksumsResult(statistic=-0.1976752550160798, pvalue=0.8432991513049917)
# neighbors-of-neighbors 1 0.1 0.5 0.25 3
# RanksumsResult(statistic=1.3031213413195941, pvalue=0.19253333872238787)
# neighbors-of-neighbors 1 0.1 0.5 0.25 10
# RanksumsResult(statistic=1.1438296309668308, pvalue=0.2526942987885128)
# neighbors-of-neighbors 1 0.1 0.5 0.5 3
# RanksumsResult(statistic=-0.10171639335778863, pvalue=0.9189817896190008)
# neighbors-of-neighbors 1 0.1 0.5 0.5 10
# RanksumsResult(statistic=0.5565613976180888, pvalue=0.5778271344533535)
# neighbors-of-neighbors 1 0.1 0.5 0.75 3
# RanksumsResult(statistic=-0.06333284869447217, pvalue=0.9495014587827427)
# neighbors-of-neighbors 1 0.1 0.5 0.75 10
# RanksumsResult(statistic=-0.6064600056804001, pvalue=0.5442093325449675)
# neighbors-of-neighbors 1 0.1 0.75 0.01 3
# RanksumsResult(statistic=1.560120602623555, pvalue=0.11873138371094565)
# neighbors-of-neighbors 1 0.1 0.75 0.01 10
# RanksumsResult(statistic=1.807367472654096, pvalue=0.07070500209264298)
# neighbors-of-neighbors 1 0.1 0.75 0.05 3
# RanksumsResult(statistic=1.0382748831427104, pvalue=0.2991420986269484)
# neighbors-of-neighbors 1 0.1 0.75 0.05 10
# RanksumsResult(statistic=1.1508451001088047, pvalue=0.2497959668749783)
# neighbors-of-neighbors 1 0.1 0.75 0.1 3
# RanksumsResult(statistic=2.207053818140697, pvalue=0.02731029965657527)
# neighbors-of-neighbors 1 0.1 0.75 0.1 10
# RanksumsResult(statistic=4.437137763079384, pvalue=9.11629532128619e-06)
# neighbors-of-neighbors 1 0.1 0.75 0.25 3
# RanksumsResult(statistic=2.2032154636743653, pvalue=0.027579565903490928)
# neighbors-of-neighbors 1 0.1 0.75 0.25 10
# RanksumsResult(statistic=-1.2280830262906037, pvalue=0.21941580212682332)
# neighbors-of-neighbors 1 0.1 0.75 0.5 3
# RanksumsResult(statistic=2.8768466725155695, pvalue=0.0040167071457841725)
# neighbors-of-neighbors 1 0.1 0.75 0.5 10
# RanksumsResult(statistic=-0.8233270330281383, pvalue=0.4103220447446183)
# neighbors-of-neighbors 1 0.1 0.75 0.75 3
# RanksumsResult(statistic=1.7822651466450112, pvalue=0.07470600351686256)
# neighbors-of-neighbors 1 0.1 0.75 0.75 10
# RanksumsResult(statistic=5.356423657765813, pvalue=8.488534163090145e-08)
# neighbors-of-neighbors 1 0.25 0.01 0.01 3
# RanksumsResult(statistic=-1.694633496885422, pvalue=0.09014496854631131)
# neighbors-of-neighbors 1 0.25 0.01 0.01 10
# RanksumsResult(statistic=-1.901904638067331, pvalue=0.057183622739205985)
# neighbors-of-neighbors 1 0.25 0.01 0.05 3
# RanksumsResult(statistic=0.7772667794321585, pvalue=0.4370013904170186)
# neighbors-of-neighbors 1 0.25 0.01 0.05 10
# RanksumsResult(statistic=1.2129200113608003, pvalue=0.22516040390980097)
# neighbors-of-neighbors 1 0.25 0.01 0.1 3
# RanksumsResult(statistic=-0.9077708312874345, pvalue=0.363999312270168)
# neighbors-of-neighbors 1 0.25 0.01 0.1 10
# RanksumsResult(statistic=0.07337602987270903, pvalue=0.9415068915579807)
# neighbors-of-neighbors 1 0.25 0.01 0.25 3
# RanksumsResult(statistic=-0.6717120316080382, pvalue=0.5017670403101799)
# neighbors-of-neighbors 1 0.25 0.01 0.25 10
# RanksumsResult(statistic=0.7878268470543496, pvalue=0.43079799512002603)
# neighbors-of-neighbors 1 0.25 0.01 0.5 3
# RanksumsResult(statistic=1.1265570358683383, pvalue=0.2599298130019171)
# neighbors-of-neighbors 1 0.25 0.01 0.5 10
# RanksumsResult(statistic=-0.6717120316080382, pvalue=0.5017670403101799)
# neighbors-of-neighbors 1 0.25 0.01 0.75 3
# RanksumsResult(statistic=0.4759559538251242, pvalue=0.6341057578683958)
# neighbors-of-neighbors 1 0.25 0.01 0.75 10
# RanksumsResult(statistic=1.2473925078360535, pvalue=0.2122536123498181)
# neighbors-of-neighbors 1 0.25 0.05 0.01 3
# RanksumsResult(statistic=-1.5257459003668297, pvalue=0.12707315852207726)
# neighbors-of-neighbors 1 0.25 0.05 0.01 10
# RanksumsResult(statistic=1.2781720372884384, pvalue=0.20118877333696328)
# neighbors-of-neighbors 1 0.25 0.05 0.05 3
# RanksumsResult(statistic=-0.5503202240453177, pvalue=0.5820997551838216)
# neighbors-of-neighbors 1 0.25 0.05 0.05 10
# RanksumsResult(statistic=-0.12164973373633338, pvalue=0.9031764241252673)
# neighbors-of-neighbors 1 0.25 0.05 0.1 3
# RanksumsResult(statistic=0.7312065258361787, pvalue=0.4646530147317377)
# neighbors-of-neighbors 1 0.25 0.05 0.1 10
# RanksumsResult(statistic=2.5448290111778817, pvalue=0.010933126047267759)
# neighbors-of-neighbors 1 0.25 0.05 0.25 3
# RanksumsResult(statistic=-0.33969437027035077, pvalue=0.734086701785257)
# neighbors-of-neighbors 1 0.25 0.05 0.25 10
# RanksumsResult(statistic=-0.8789831727899471, pvalue=0.37941039969512314)
# neighbors-of-neighbors 1 0.25 0.05 0.5 3
# RanksumsResult(statistic=1.1687789349979865, pvalue=0.2424927095278695)
# neighbors-of-neighbors 1 0.25 0.05 0.5 10
# RanksumsResult(statistic=-1.9425338434722441, pvalue=0.052072506977969744)
# neighbors-of-neighbors 1 0.25 0.05 0.75 3
# RanksumsResult(statistic=0.02878765849748735, pvalue=0.9770339438941905)
# neighbors-of-neighbors 1 0.25 0.05 0.75 10
# RanksumsResult(statistic=-0.00575753169949747, pvalue=0.9954061797288744)
# neighbors-of-neighbors 1 0.25 0.1 0.01 3
# RanksumsResult(statistic=-1.4105952663768802, pvalue=0.1583639881852129)
# neighbors-of-neighbors 1 0.25 0.1 0.01 10
# RanksumsResult(statistic=-1.2877679234542676, pvalue=0.19782676127449295)
# neighbors-of-neighbors 1 0.25 0.1 0.05 3
# RanksumsResult(statistic=0.8789831727899471, pvalue=0.37941039969512314)
# neighbors-of-neighbors 1 0.25 0.1 0.05 10
# RanksumsResult(statistic=-0.08252462102613041, pvalue=0.9342295403590714)
# neighbors-of-neighbors 1 0.25 0.1 0.1 3
# RanksumsResult(statistic=0.815650324095475, pvalue=0.4147001582481622)
# neighbors-of-neighbors 1 0.25 0.1 0.1 10
# RanksumsResult(statistic=-1.7829156496110499, pvalue=0.0746000351864719)
# neighbors-of-neighbors 1 0.25 0.1 0.25 3
# RanksumsResult(statistic=-0.33969437027035077, pvalue=0.734086701785257)
# neighbors-of-neighbors 1 0.25 0.1 0.25 10
# RanksumsResult(statistic=1.1778783742724344, pvalue=0.23884509764610296)
# neighbors-of-neighbors 1 0.25 0.1 0.5 3
# RanksumsResult(statistic=-1.0581595886906459, pvalue=0.28998269144748545)
# neighbors-of-neighbors 1 0.25 0.1 0.5 10
# RanksumsResult(statistic=0.07100955762713547, pvalue=0.9433901488085427)
# neighbors-of-neighbors 1 0.25 0.1 0.75 3
# RanksumsResult(statistic=2.826948064453258, pvalue=0.004699394888018242)
# neighbors-of-neighbors 1 0.25 0.1 0.75 10
# RanksumsResult(statistic=-2.218568881539692, pvalue=0.026516068571582237)
# neighbors-of-neighbors 1 0.25 0.25 0.01 3
# RanksumsResult(statistic=3.964236561280832, pvalue=7.363120869182923e-05)
# neighbors-of-neighbors 1 0.25 0.25 0.01 10
# RanksumsResult(statistic=-2.1993771092080334, pvalue=0.027851118912999705)
# neighbors-of-neighbors 1 0.25 0.25 0.05 3
# RanksumsResult(statistic=2.815433001054263, pvalue=0.004871155274192742)
# neighbors-of-neighbors 1 0.25 0.25 0.05 10
# RanksumsResult(statistic=2.1110949564824057, pvalue=0.03476415086291657)
# neighbors-of-neighbors 1 0.25 0.25 0.1 3
# RanksumsResult(statistic=-1.8289759032070296, pvalue=0.0674032181768864)
# neighbors-of-neighbors 1 0.25 0.25 0.1 10
# RanksumsResult(statistic=0.34929025643617984, pvalue=0.7268714126094481)
# neighbors-of-neighbors 1 0.25 0.25 0.25 3
# RanksumsResult(statistic=-1.773319763445221, pvalue=0.0761757359999075)
# neighbors-of-neighbors 1 0.25 0.25 0.25 10
# RanksumsResult(statistic=3.826839402932652, pvalue=0.0001297991377703989)
# neighbors-of-neighbors 1 0.25 0.25 0.5 3
# RanksumsResult(statistic=0.6655162487833306, pvalue=0.505720354251779)
# neighbors-of-neighbors 1 0.25 0.25 0.5 10
# RanksumsResult(statistic=-0.2840382305085419, pvalue=0.7763810829410939)
# neighbors-of-neighbors 1 0.25 0.25 0.75 3
# RanksumsResult(statistic=0.8386804508934649, pvalue=0.40164865134320393)
# neighbors-of-neighbors 1 0.25 0.25 0.75 10
# RanksumsResult(statistic=1.314636404718589, pvalue=0.18863212906207494)
# neighbors-of-neighbors 1 0.25 0.5 0.01 3
# RanksumsResult(statistic=-1.2359501381587903, pvalue=0.21647709841856766)
# neighbors-of-neighbors 1 0.25 0.5 0.01 10
# RanksumsResult(statistic=-1.2359501381587903, pvalue=0.21647709841856766)
# neighbors-of-neighbors 1 0.25 0.5 0.05 3
# RanksumsResult(statistic=0.11323145675678357, pvalue=0.9098470571496396)
# neighbors-of-neighbors 1 0.25 0.5 0.05 10
# RanksumsResult(statistic=3.0150274333035085, pvalue=0.0025695601317588445)
# neighbors-of-neighbors 1 0.25 0.5 0.1 3
# RanksumsResult(statistic=1.673522547320598, pvalue=0.09422447164973127)
# neighbors-of-neighbors 1 0.25 0.5 0.1 10
# RanksumsResult(statistic=-0.05373696252864305, pvalue=0.957144733493817)
# neighbors-of-neighbors 1 0.25 0.5 0.25 3
# RanksumsResult(statistic=-1.8001882447095423, pvalue=0.07183091936205314)
# neighbors-of-neighbors 1 0.25 0.5 0.25 10
# RanksumsResult(statistic=1.4413021021075334, pvalue=0.14949935369034875)
# neighbors-of-neighbors 1 0.25 0.5 0.5 3
# RanksumsResult(statistic=-0.8214078557949724, pvalue=0.41141399034618387)
# neighbors-of-neighbors 1 0.25 0.5 0.5 10
# RanksumsResult(statistic=1.465136471274939, pvalue=0.14288368792399322)
# neighbors-of-neighbors 1 0.25 0.5 0.75 3
# RanksumsResult(statistic=2.0592771711869284, pvalue=0.03946769410547936)
# neighbors-of-neighbors 1 0.25 0.5 0.75 10
# RanksumsResult(statistic=0.489390194457285, pvalue=0.624565476772807)
# neighbors-of-neighbors 1 0.25 0.75 0.01 3
# RanksumsResult(statistic=4.135826937472349, pvalue=3.536786726600644e-05)
# neighbors-of-neighbors 1 0.25 0.75 0.01 10
# RanksumsResult(statistic=1.950257636090424, pvalue=0.05114541926173692)
# neighbors-of-neighbors 1 0.25 0.75 0.05 3
# RanksumsResult(statistic=-0.23989715414572793, pvalue=0.8104099871120831)
# neighbors-of-neighbors 1 0.25 0.75 0.05 10
# RanksumsResult(statistic=2.2224072360060236, pvalue=0.026255796768876398)
# neighbors-of-neighbors 1 0.25 0.75 0.1 3
# RanksumsResult(statistic=-0.5168020925253619, pvalue=0.6052943191675346)
# neighbors-of-neighbors 1 0.25 0.75 0.1 10
# RanksumsResult(statistic=0.08444379825929622, pvalue=0.9327035856420398)
# neighbors-of-neighbors 1 0.25 0.75 0.25 3
# RanksumsResult(statistic=2.0343278671557727, pvalue=0.04191854928085284)
# neighbors-of-neighbors 1 0.25 0.75 0.25 10
# RanksumsResult(statistic=2.274225021301501, pvalue=0.02295246057635867)
# neighbors-of-neighbors 1 0.25 0.75 0.5 3
# RanksumsResult(statistic=1.2474652015577852, pvalue=0.21222697207142127)
# neighbors-of-neighbors 1 0.25 0.75 0.5 10
# RanksumsResult(statistic=-0.5148592275158681, pvalue=0.6066513940880064)
# neighbors-of-neighbors 1 0.25 0.75 0.75 3
# RanksumsResult(statistic=-0.07868626655979875, pvalue=0.9372821693056437)
# neighbors-of-neighbors 1 0.25 0.75 0.75 10
# RanksumsResult(statistic=1.4374637476412018, pvalue=0.15058626656571794)
# neighbors-of-neighbors 1 0.5 0.01 0.01 3
# RanksumsResult(statistic=0.1880793688502507, pvalue=0.8508144337517071)
# neighbors-of-neighbors 1 0.5 0.01 0.01 10
# RanksumsResult(statistic=0.49514772615678243, pvalue=0.6204958467384245)
# neighbors-of-neighbors 1 0.5 0.01 0.05 3
# RanksumsResult(statistic=0.4279765229959786, pvalue=0.6686682129448881)
# neighbors-of-neighbors 1 0.5 0.01 0.05 10
# RanksumsResult(statistic=0.1324232290884418, pvalue=0.8946495423136553)
# neighbors-of-neighbors 1 0.5 0.01 0.1 3
# RanksumsResult(statistic=2.0592771711869284, pvalue=0.03946769410547936)
# neighbors-of-neighbors 1 0.5 0.01 0.1 10
# RanksumsResult(statistic=0.5508038659185913, pvalue=0.5817681337497668)
# neighbors-of-neighbors 1 0.5 0.01 0.25 3
# RanksumsResult(statistic=1.7185438575450271, pvalue=0.08569746200846853)
# neighbors-of-neighbors 1 0.5 0.01 0.25 10
# RanksumsResult(statistic=-1.3280706453507498, pvalue=0.18415476986914625)
# neighbors-of-neighbors 1 0.5 0.01 0.5 3
# RanksumsResult(statistic=0.8597914004582888, pvalue=0.3899040404976287)
# neighbors-of-neighbors 1 0.5 0.01 0.5 10
# RanksumsResult(statistic=-2.479576985250244, pvalue=0.013153833113576218)
# neighbors-of-neighbors 1 0.5 0.01 0.75 3
# RanksumsResult(statistic=-1.1822131756301473, pvalue=0.23712112600013358)
# neighbors-of-neighbors 1 0.5 0.01 0.75 10
# RanksumsResult(statistic=1.2513035560241168, pvalue=0.21082374858662567)
# neighbors-of-neighbors 1 0.5 0.05 0.01 3
# RanksumsResult(statistic=-0.20727114118190892, pvalue=0.8357981107453628)
# neighbors-of-neighbors 1 0.5 0.05 0.01 10
# RanksumsResult(statistic=-0.1727259509849241, pvalue=0.8628668444358498)
# neighbors-of-neighbors 1 0.5 0.05 0.05 3
# RanksumsResult(statistic=1.4720089378381866, pvalue=0.14101846401347218)
# neighbors-of-neighbors 1 0.5 0.05 0.05 10
# RanksumsResult(statistic=-0.5296929163537673, pvalue=0.5963248600893174)
# neighbors-of-neighbors 1 0.5 0.05 0.1 3
# RanksumsResult(statistic=-2.1322059060472296, pvalue=0.032989923160380276)
# neighbors-of-neighbors 1 0.5 0.05 0.1 10
# RanksumsResult(statistic=-0.5085819667889432, pvalue=0.6110452718137109)
# neighbors-of-neighbors 1 0.5 0.05 0.25 3
# RanksumsResult(statistic=-1.8635210934040145, pvalue=0.06238898767107983)
# neighbors-of-neighbors 1 0.5 0.05 0.25 10
# RanksumsResult(statistic=-0.8386804508934649, pvalue=0.40164865134320393)
# neighbors-of-neighbors 1 0.5 0.05 0.5 3
# RanksumsResult(statistic=0.2859574077417077, pvalue=0.774910743630478)
# neighbors-of-neighbors 1 0.5 0.05 0.5 10
# RanksumsResult(statistic=3.314419081677377, pvalue=0.0009183375560014835)
# neighbors-of-neighbors 1 0.5 0.05 0.75 3
# RanksumsResult(statistic=-1.4048377346773828, pvalue=0.16006953537007662)
# neighbors-of-neighbors 1 0.5 0.05 0.75 10
# RanksumsResult(statistic=-0.7427215892351736, pvalue=0.4576502561739243)
# neighbors-of-neighbors 1 0.5 0.1 0.01 3
# RanksumsResult(statistic=-0.10939310229045193, pvalue=0.9128907044912136)
# neighbors-of-neighbors 1 0.5 0.1 0.01 10
# RanksumsResult(statistic=1.6217047620251208, pvalue=0.10486657869897187)
# neighbors-of-neighbors 1 0.5 0.1 0.05 3
# RanksumsResult(statistic=2.0496812850210993, pvalue=0.04039554246776404)
# neighbors-of-neighbors 1 0.5 0.1 0.05 10
# RanksumsResult(statistic=0.6928229811728622, pvalue=0.48842064827052367)
# neighbors-of-neighbors 1 0.5 0.1 0.1 3
# RanksumsResult(statistic=0.8943365906552737, pvalue=0.37114182799456563)
# neighbors-of-neighbors 1 0.5 0.1 0.1 10
# RanksumsResult(statistic=0.5776723471829128, pvalue=0.563485352108883)
# neighbors-of-neighbors 1 0.5 0.1 0.25 3
# RanksumsResult(statistic=-0.075306978027254, pvalue=0.9399704695875648)
# neighbors-of-neighbors 1 0.5 0.1 0.25 10
# RanksumsResult(statistic=1.8923087519015018, pvalue=0.05844985554177635)
# neighbors-of-neighbors 1 0.5 0.1 0.5 3
# RanksumsResult(statistic=-1.4278678614753726, pvalue=0.15332989561346633)
# neighbors-of-neighbors 1 0.5 0.1 0.5 10
# RanksumsResult(statistic=-0.06141367146130635, pvalue=0.9510297646605194)
# neighbors-of-neighbors 1 0.5 0.1 0.75 3
# RanksumsResult(statistic=-0.3089875345396976, pvalue=0.7573310091666936)
# neighbors-of-neighbors 1 0.5 0.1 0.75 10
# RanksumsResult(statistic=-2.794081979626578, pvalue=0.005204728243129156)
# neighbors-of-neighbors 1 0.5 0.25 0.01 3
# RanksumsResult(statistic=-2.274225021301501, pvalue=0.02295246057635867)
# neighbors-of-neighbors 1 0.5 0.25 0.01 10
# RanksumsResult(statistic=-0.6411454531329678, pvalue=0.5214281852655442)
# neighbors-of-neighbors 1 0.5 0.25 0.05 3
# RanksumsResult(statistic=0.7484791209346712, pvalue=0.45417121424637863)
# neighbors-of-neighbors 1 0.5 0.25 0.05 10
# RanksumsResult(statistic=3.139773953459287, pvalue=0.0016907824355920356)
# neighbors-of-neighbors 1 0.5 0.25 0.1 3
# RanksumsResult(statistic=-1.3837267851125588, pvalue=0.16644212874128073)
# neighbors-of-neighbors 1 0.5 0.25 0.1 10
# RanksumsResult(statistic=-1.2167583658271321, pvalue=0.22369616504280088)
# neighbors-of-neighbors 1 0.5 0.25 0.25 3
# RanksumsResult(statistic=-0.1324232290884418, pvalue=0.8946495423136553)
# neighbors-of-neighbors 1 0.5 0.25 0.25 10
# RanksumsResult(statistic=-1.2992829868532625, pvalue=0.19384683078513643)
# neighbors-of-neighbors 1 0.5 0.25 0.5 3
# RanksumsResult(statistic=0.31474454919083084, pvalue=0.752955616635139)
# neighbors-of-neighbors 1 0.5 0.25 0.5 10
# RanksumsResult(statistic=-2.129651996106658, pvalue=0.03320035489222454)
# neighbors-of-neighbors 1 0.5 0.25 0.75 3
# RanksumsResult(statistic=-0.29939164837386845, pvalue=0.7646412337360282)
# neighbors-of-neighbors 1 0.5 0.25 0.75 10
# RanksumsResult(statistic=-1.044032414842208, pvalue=0.2964703927825385)
# neighbors-of-neighbors 1 0.5 0.5 0.01 3
# RanksumsResult(statistic=1.7426129277145677, pvalue=0.08140125031434149)
# neighbors-of-neighbors 1 0.5 0.5 0.01 10
# RanksumsResult(statistic=-3.099471231562805, pvalue=0.0019386640409453561)
# neighbors-of-neighbors 1 0.5 0.5 0.05 3
# RanksumsResult(statistic=-0.8444379825929623, pvalue=0.39842470511736217)
# neighbors-of-neighbors 1 0.5 0.5 0.05 10
# RanksumsResult(statistic=-0.9327201353185902, pvalue=0.3509644858938379)
# neighbors-of-neighbors 1 0.5 0.5 0.1 3
# RanksumsResult(statistic=2.863596113190197, pvalue=0.00418861716924164)
# neighbors-of-neighbors 1 0.5 0.5 0.1 10
# RanksumsResult(statistic=1.2090816568944687, pvalue=0.22663147559684438)
# neighbors-of-neighbors 1 0.5 0.5 0.25 3
# RanksumsResult(statistic=-0.7542366526341686, pvalue=0.4507071325759193)
# neighbors-of-neighbors 1 0.5 0.5 0.25 10
# RanksumsResult(statistic=-1.8539252072381853, pvalue=0.06374986103542868)
# neighbors-of-neighbors 1 0.5 0.5 0.5 3
# RanksumsResult(statistic=2.4642235673849173, pvalue=0.013731043454147733)
# neighbors-of-neighbors 1 0.5 0.5 0.5 10
# RanksumsResult(statistic=-1.7541279911135625, pvalue=0.07940857838118887)
# neighbors-of-neighbors 1 0.5 0.5 0.75 3
# RanksumsResult(statistic=-0.24373550861205956, pvalue=0.8074356706537857)
# neighbors-of-neighbors 1 0.5 0.5 0.75 10
# RanksumsResult(statistic=3.2357328151175784, pvalue=0.0012133089565009676)
# neighbors-of-neighbors 1 0.5 0.75 0.01 3
# RanksumsResult(statistic=3.063006864132654, pvalue=0.0021912503352960674)
# neighbors-of-neighbors 1 0.5 0.75 0.01 10
# RanksumsResult(statistic=2.6158385688050174, pvalue=0.00890086284711697)
# neighbors-of-neighbors 1 0.5 0.75 0.05 3
# RanksumsResult(statistic=-0.4586833587266318, pvalue=0.64646156601489)
# neighbors-of-neighbors 1 0.5 0.75 0.05 10
# RanksumsResult(statistic=2.855735722950745, pvalue=0.0042937236645293735)
# neighbors-of-neighbors 1 0.5 0.75 0.1 3
# RanksumsResult(statistic=0.5795915244160786, pvalue=0.562190109971288)
# neighbors-of-neighbors 1 0.5 0.75 0.1 10
# RanksumsResult(statistic=-4.581076055566821, pvalue=4.625895612185265e-06)
# neighbors-of-neighbors 1 0.5 0.75 0.25 3
# RanksumsResult(statistic=-1.3127172274854233, pvalue=0.18927825033744783)
# neighbors-of-neighbors 1 0.5 0.75 0.25 10
# RanksumsResult(statistic=4.051383139213053, pvalue=5.091575431925575e-05)
# neighbors-of-neighbors 1 0.5 0.75 0.5 3
# RanksumsResult(statistic=-2.4066482503899427, pvalue=0.016099668113182256)
# neighbors-of-neighbors 1 0.5 0.75 0.5 10
# RanksumsResult(statistic=-1.8286079023540907, pvalue=0.06745836802571947)
# neighbors-of-neighbors 1 0.5 0.75 0.75 3
# RanksumsResult(statistic=0.8310037419608015, pvalue=0.40597151545399235)
# neighbors-of-neighbors 1 0.5 0.75 0.75 10
# RanksumsResult(statistic=-2.4814961624834098, pvalue=0.013083211909542444)
# neighbors-of-neighbors 1 0.75 0.01 0.01 3
# RanksumsResult(statistic=1.0736071739270057, pvalue=0.2829987809363509)
# neighbors-of-neighbors 1 0.75 0.01 0.01 10
# RanksumsResult(statistic=0.5738339927165812, pvalue=0.5660801435165529)
# neighbors-of-neighbors 1 0.75 0.01 0.05 3
# RanksumsResult(statistic=-1.7138252692170803, pvalue=0.08656082107727454)
# neighbors-of-neighbors 1 0.75 0.01 0.05 10
# RanksumsResult(statistic=2.4227526668388206, pvalue=0.015403409944449003)
# neighbors-of-neighbors 1 0.75 0.01 0.1 3
# RanksumsResult(statistic=-1.2762528600552725, pvalue=0.20186614816058446)
# neighbors-of-neighbors 1 0.75 0.01 0.1 10
# RanksumsResult(statistic=-0.8463571598261281, pvalue=0.39735352961405923)
# neighbors-of-neighbors 1 0.75 0.01 0.25 3
# RanksumsResult(statistic=-0.9960529840130623, pvalue=0.31922440213545233)
# neighbors-of-neighbors 1 0.75 0.01 0.25 10
# RanksumsResult(statistic=1.9441265371969791, pvalue=0.051880193862253766)
# neighbors-of-neighbors 1 0.75 0.01 0.5 3
# RanksumsResult(statistic=1.3261514681175839, pvalue=0.1847895309862091)
# neighbors-of-neighbors 1 0.75 0.01 0.5 10
# RanksumsResult(statistic=-1.3971610257447193, pvalue=0.1623651538806934)
# neighbors-of-neighbors 1 0.75 0.01 0.75 3
# RanksumsResult(statistic=-2.117246235666636, pvalue=0.03423895524453882)
# neighbors-of-neighbors 1 0.75 0.01 0.75 10
# RanksumsResult(statistic=-0.08303077064543389, pvalue=0.9338270726453869)
# neighbors-of-neighbors 1 0.75 0.05 0.01 3
# RanksumsResult(statistic=0.9519119076502484, pvalue=0.34114166001764523)
# neighbors-of-neighbors 1 0.75 0.05 0.01 10
# RanksumsResult(statistic=4.39299668671657, pvalue=1.1179883179534345e-05)
# neighbors-of-neighbors 1 0.75 0.05 0.05 3
# RanksumsResult(statistic=0.44524911809447104, pvalue=0.6561397341590249)
# neighbors-of-neighbors 1 0.75 0.05 0.05 10
# RanksumsResult(statistic=3.0035123699045134, pvalue=0.002668826993920252)
# neighbors-of-neighbors 1 0.75 0.05 0.1 3
# RanksumsResult(statistic=0.9847835588179369, pvalue=0.32473039821065364)
# neighbors-of-neighbors 1 0.75 0.05 0.1 10
# RanksumsResult(statistic=-0.7408024120020078, pvalue=0.45881325250095917)
# neighbors-of-neighbors 1 0.75 0.05 0.25 3
# RanksumsResult(statistic=-1.1257427740997201, pvalue=0.26027441280335784)
# neighbors-of-neighbors 1 0.75 0.05 0.25 10
# RanksumsResult(statistic=-1.4912007101698448, pvalue=0.13590880729197993)
# neighbors-of-neighbors 1 0.75 0.05 0.5 3
# RanksumsResult(statistic=-0.7753476021989927, pvalue=0.4381342881648449)
# neighbors-of-neighbors 1 0.75 0.05 0.5 10
# RanksumsResult(statistic=1.1419104537336648, pvalue=0.25349124291876657)
# neighbors-of-neighbors 1 0.75 0.05 0.75 3
# RanksumsResult(statistic=-3.404620411636171, pvalue=0.0006625608245765527)
# neighbors-of-neighbors 1 0.75 0.05 0.75 10
# RanksumsResult(statistic=-0.47979430829145586, pvalue=0.6313736604383959)
# neighbors-of-neighbors 1 0.75 0.1 0.01 3
# RanksumsResult(statistic=2.3740222374261237, pvalue=0.017595490750954283)
# neighbors-of-neighbors 1 0.75 0.1 0.01 10
# RanksumsResult(statistic=0.08444379825929622, pvalue=0.9327035856420398)
# neighbors-of-neighbors 1 0.75 0.1 0.05 3
# RanksumsResult(statistic=0.6064600056804001, pvalue=0.5442093325449675)
# neighbors-of-neighbors 1 0.75 0.1 0.05 10
# RanksumsResult(statistic=-1.899985460834165, pvalue=0.05743502765678223)
# neighbors-of-neighbors 1 0.75 0.1 0.1 3
# RanksumsResult(statistic=0.8920980473997782, pvalue=0.3723403814041373)
# neighbors-of-neighbors 1 0.75 0.1 0.1 10
# RanksumsResult(statistic=2.2224072360060236, pvalue=0.026255796768876398)
# neighbors-of-neighbors 1 0.75 0.1 0.25 3
# RanksumsResult(statistic=-0.5368035869635028, pvalue=0.5914032937114075)
# neighbors-of-neighbors 1 0.75 0.1 0.25 10
# RanksumsResult(statistic=-0.7704483136634448, pvalue=0.44103400362716105)
# neighbors-of-neighbors 1 0.75 0.1 0.5 3
# RanksumsResult(statistic=-0.31474454919083084, pvalue=0.752955616635139)
# neighbors-of-neighbors 1 0.75 0.1 0.5 10
# RanksumsResult(statistic=-3.9074448467256166, pvalue=9.327732454411029e-05)
# neighbors-of-neighbors 1 0.75 0.1 0.75 3
# RanksumsResult(statistic=0.02303012679798988, pvalue=0.981626241608544)
# neighbors-of-neighbors 1 0.75 0.1 0.75 10
# RanksumsResult(statistic=2.1456401466793906, pvalue=0.03190169983115447)
# neighbors-of-neighbors 1 0.75 0.25 0.01 3
# RanksumsResult(statistic=3.379671107605015, pvalue=0.0007257261754295058)
# neighbors-of-neighbors 1 0.75 0.25 0.01 10
# RanksumsResult(statistic=4.168452950436168, pvalue=3.0667404644136364e-05)
# neighbors-of-neighbors 1 0.75 0.25 0.05 3
# RanksumsResult(statistic=1.0574666554743688, pvalue=0.29029866482910194)
# neighbors-of-neighbors 1 0.75 0.25 0.05 10
# RanksumsResult(statistic=3.489064209895467, pvalue=0.0004847147004618877)
# neighbors-of-neighbors 1 0.75 0.25 0.1 3
# RanksumsResult(statistic=1.8059457764090399, pvalue=0.07092680978038632)
# neighbors-of-neighbors 1 0.75 0.25 0.1 10
# RanksumsResult(statistic=-1.2647377966562776, pvalue=0.20596533609697365)
# neighbors-of-neighbors 1 0.75 0.25 0.25 3
# RanksumsResult(statistic=2.035219354890403, pvalue=0.04182880640860445)
# neighbors-of-neighbors 1 0.75 0.25 0.25 10
# RanksumsResult(statistic=1.9383690054974816, pvalue=0.05257821902628632)
# neighbors-of-neighbors 1 0.75 0.25 0.5 3
# RanksumsResult(statistic=-1.7905923585437133, pvalue=0.07335873418248692)
# neighbors-of-neighbors 1 0.75 0.25 0.5 10
# RanksumsResult(statistic=-0.24373550861205956, pvalue=0.8074356706537857)
# neighbors-of-neighbors 1 0.75 0.25 0.75 3
# RanksumsResult(statistic=-0.28754402140508856, pvalue=0.7736958001731616)
# neighbors-of-neighbors 1 0.75 0.25 0.75 10
# RanksumsResult(statistic=-3.508255982227125, pvalue=0.0004510548127098582)
# neighbors-of-neighbors 1 0.75 0.5 0.01 3
# RanksumsResult(statistic=-1.2129200113608003, pvalue=0.22516040390980097)
# neighbors-of-neighbors 1 0.75 0.5 0.01 10
# RanksumsResult(statistic=1.976752550160798, pvalue=0.04806960758426403)
# neighbors-of-neighbors 1 0.75 0.5 0.05 3
# RanksumsResult(statistic=-0.6467627275768825, pvalue=0.5177855185978588)
# neighbors-of-neighbors 1 0.75 0.5 0.05 10
# RanksumsResult(statistic=1.7637238772793917, pvalue=0.07777847906698608)
# neighbors-of-neighbors 1 0.75 0.5 0.1 3
# RanksumsResult(statistic=4.2528967486954645, pvalue=2.110228893564327e-05)
# neighbors-of-neighbors 1 0.75 0.5 0.1 10
# RanksumsResult(statistic=0.9576694393497459, pvalue=0.3382294717847558)
# neighbors-of-neighbors 1 0.75 0.5 0.25 3
# RanksumsResult(statistic=0.6448435503437167, pvalue=0.519028576358953)
# neighbors-of-neighbors 1 0.75 0.5 0.25 10
# RanksumsResult(statistic=-1.0785776050391929, pvalue=0.28077606915433795)
# neighbors-of-neighbors 1 0.75 0.5 0.5 3
# RanksumsResult(statistic=-0.05020465201816933, pvalue=0.9599593044564874)
# neighbors-of-neighbors 1 0.75 0.5 0.5 10
# RanksumsResult(statistic=5.260464796107522, pvalue=1.4369171380902566e-07)
# neighbors-of-neighbors 1 0.75 0.5 0.75 3
# ...
# RanksumsResult(statistic=4.874710172241191, pvalue=1.0896831775522894e-06)
# high-degree-cit-and-media 5 0.5 0.01 0.5 10
# RanksumsResult(statistic=-0.5527230431517571, pvalue=0.5804530719565921)
# high-degree-cit-and-media 5 0.5 0.01 0.75 3
# RanksumsResult(statistic=4.6232979546964685, pvalue=3.7768660710558873e-06)
# high-degree-cit-and-media 5 0.5 0.01 0.75 10
# RanksumsResult(statistic=2.9804822431065237, pvalue=0.002877949227275472)
# high-degree-cit-and-media 5 0.5 0.05 0.01 3
# RanksumsResult(statistic=2.2339222994050183, pvalue=0.02548818603048029)
# high-degree-cit-and-media 5 0.5 0.05 0.01 10
# RanksumsResult(statistic=1.575644508429141, pvalue=0.11510775263867654)
# high-degree-cit-and-media 5 0.5 0.05 0.05 3
# RanksumsResult(statistic=1.7982690674763766, pvalue=0.0721343791056096)
# high-degree-cit-and-media 5 0.5 0.05 0.05 10
# RanksumsResult(statistic=-2.3836181235919525, pvalue=0.017143381635202425)
# high-degree-cit-and-media 5 0.5 0.05 0.1 3
# RanksumsResult(statistic=-1.1131227952361775, pvalue=0.26565569477059336)
# high-degree-cit-and-media 5 0.5 0.05 0.1 10
# RanksumsResult(statistic=-0.35504778813567733, pvalue=0.7225537906178525)
# high-degree-cit-and-media 5 0.5 0.05 0.25 3
# RanksumsResult(statistic=1.3069596957859257, pvalue=0.19122640012749392)
# high-degree-cit-and-media 5 0.5 0.05 0.25 10
# RanksumsResult(statistic=-0.7657517160331635, pvalue=0.44382404881545123)
# high-degree-cit-and-media 5 0.5 0.05 0.5 3
# RanksumsResult(statistic=1.3875651395788904, pvalue=0.16526950283772024)
# high-degree-cit-and-media 5 0.5 0.05 0.5 10
# RanksumsResult(statistic=2.2224072360060236, pvalue=0.026255796768876398)
# high-degree-cit-and-media 5 0.5 0.05 0.75 3
# RanksumsResult(statistic=1.443221279340699, pvalue=0.1489581469938538)
# high-degree-cit-and-media 5 0.5 0.05 0.75 10
# RanksumsResult(statistic=-0.9000941223547712, pvalue=0.36807016367448087)
# high-degree-cit-and-media 5 0.5 0.1 0.01 3
# RanksumsResult(statistic=1.6504924205226081, pvalue=0.09884226228012435)
# high-degree-cit-and-media 5 0.5 0.1 0.01 10
# RanksumsResult(statistic=0.9039324768211028, pvalue=0.3660312069101994)
# high-degree-cit-and-media 5 0.5 0.1 0.05 3
# RanksumsResult(statistic=1.827056725973864, pvalue=0.0676912408007997)
# high-degree-cit-and-media 5 0.5 0.1 0.05 10
# RanksumsResult(statistic=0.6544394365095458, pvalue=0.5128287339295505)
# high-degree-cit-and-media 5 0.5 0.1 0.1 3
# RanksumsResult(statistic=1.8289759032070296, pvalue=0.0674032181768864)
# high-degree-cit-and-media 5 0.5 0.1 0.1 10
# RanksumsResult(statistic=1.8399566878127376, pvalue=0.06577459639093948)
# high-degree-cit-and-media 5 0.5 0.1 0.25 3
# RanksumsResult(statistic=1.8189531615813659, pvalue=0.06891857623415527)
# high-degree-cit-and-media 5 0.5 0.1 0.25 10
# RanksumsResult(statistic=1.4528171655065283, pvalue=0.14627452464863303)
# high-degree-cit-and-media 5 0.5 0.1 0.5 3
# RanksumsResult(statistic=2.1801853368763755, pvalue=0.029243726079016288)
# high-degree-cit-and-media 5 0.5 0.1 0.5 10
# RanksumsResult(statistic=1.9153388786994918, pvalue=0.055449300439666845)
# high-degree-cit-and-media 5 0.5 0.1 0.75 3
# RanksumsResult(statistic=2.4200824910221033, pvalue=0.015516986617747953)
# high-degree-cit-and-media 5 0.5 0.1 0.75 10
# RanksumsResult(statistic=-2.502508808290287, pvalue=0.01233165568948767)
# high-degree-cit-and-media 5 0.5 0.25 0.01 3
# RanksumsResult(statistic=-0.38767380109949634, pvalue=0.6982574461378661)
# high-degree-cit-and-media 5 0.5 0.25 0.01 10
# RanksumsResult(statistic=2.873497349041392, pvalue=0.004059544850004436)
# high-degree-cit-and-media 5 0.5 0.25 0.05 3
# RanksumsResult(statistic=1.7003910285849195, pvalue=0.08905739820497705)
# high-degree-cit-and-media 5 0.5 0.25 0.05 10
# RanksumsResult(statistic=3.3623985125065228, pvalue=0.0007726852306051764)
# high-degree-cit-and-media 5 0.5 0.25 0.1 3
# RanksumsResult(statistic=0.03454519019698482, pvalue=0.9724424072689765)
# high-degree-cit-and-media 5 0.5 0.25 0.1 10
# RanksumsResult(statistic=-1.2992829868532625, pvalue=0.19384683078513643)
# high-degree-cit-and-media 5 0.5 0.25 0.25 3
# RanksumsResult(statistic=1.5142308369678348, pvalue=0.12996730315983268)
# high-degree-cit-and-media 5 0.5 0.25 0.25 10
# RanksumsResult(statistic=0.8118119696291433, pvalue=0.41689953274570746)
# high-degree-cit-and-media 5 0.5 0.25 0.5 3
# RanksumsResult(statistic=3.6977657159536257, pvalue=0.00021750549249525955)
# high-degree-cit-and-media 5 0.5 0.25 0.5 10
# RanksumsResult(statistic=-1.4700897606050207, pvalue=0.14153744517291428)
# high-degree-cit-and-media 5 0.5 0.25 0.75 3
# RanksumsResult(statistic=0.18999854608341651, pvalue=0.8493102698369646)
# high-degree-cit-and-media 5 0.5 0.25 0.75 10
# RanksumsResult(statistic=-2.1014990703165766, pvalue=0.03559717951592693)
# high-degree-cit-and-media 5 0.5 0.5 0.01 3
# RanksumsResult(statistic=3.489064209895467, pvalue=0.0004847147004618877)
# high-degree-cit-and-media 5 0.5 0.5 0.01 10
# RanksumsResult(statistic=3.4084587661025023, pvalue=0.0006533095789827311)
# high-degree-cit-and-media 5 0.5 0.5 0.05 3
# RanksumsResult(statistic=2.479576985250244, pvalue=0.013153833113576218)
# high-degree-cit-and-media 5 0.5 0.5 0.05 10
# RanksumsResult(statistic=2.19170040027537, pvalue=0.028401146825188257)
# high-degree-cit-and-media 5 0.5 0.5 0.1 3
# RanksumsResult(statistic=3.608942100844557, pvalue=0.00030744821237593963)
# high-degree-cit-and-media 5 0.5 0.5 0.1 10
# RanksumsResult(statistic=0.30131082560703426, pvalue=0.763177486650608)
# high-degree-cit-and-media 5 0.5 0.5 0.25 3
# RanksumsResult(statistic=0.09212050719195952, pvalue=0.9266022953464405)
# high-degree-cit-and-media 5 0.5 0.5 0.25 10
# RanksumsResult(statistic=1.7272595098492411, pvalue=0.08412106747869064)
# high-degree-cit-and-media 5 0.5 0.5 0.5 3
# RanksumsResult(statistic=1.0593858327075345, pvalue=0.28942409909654476)
# high-degree-cit-and-media 5 0.5 0.5 0.5 10
# RanksumsResult(statistic=-0.9730228572150724, pvalue=0.3305419420824196)
# high-degree-cit-and-media 5 0.5 0.5 0.75 3
# RanksumsResult(statistic=2.164831919011049, pvalue=0.03040055945565768)
# high-degree-cit-and-media 5 0.5 0.5 0.75 10
# RanksumsResult(statistic=2.778968633624112, pvalue=0.0054531790482251815)
# high-degree-cit-and-media 5 0.5 0.75 0.01 3
# RanksumsResult(statistic=3.7347188957406923, pvalue=0.00018792497616974688)
# high-degree-cit-and-media 5 0.5 0.75 0.01 10
# RanksumsResult(statistic=7.06257221805023, pvalue=1.6344831790329374e-12)
# high-degree-cit-and-media 5 0.5 0.75 0.05 3
# RanksumsResult(statistic=1.629381470957784, pvalue=0.10323228879689252)
# high-degree-cit-and-media 5 0.5 0.75 0.05 10
# RanksumsResult(statistic=5.034001882593955, pvalue=4.803449494706286e-07)
# high-degree-cit-and-media 5 0.5 0.75 0.1 3
# RanksumsResult(statistic=2.2761441985346664, pvalue=0.022837380450483048)
# high-degree-cit-and-media 5 0.5 0.75 0.1 10
# RanksumsResult(statistic=0.6256517780120584, pvalue=0.5315433690381426)
# high-degree-cit-and-media 5 0.5 0.75 0.25 3
# RanksumsResult(statistic=2.19170040027537, pvalue=0.028401146825188257)
# high-degree-cit-and-media 5 0.5 0.75 0.25 10
# RanksumsResult(statistic=5.744097458865309, pvalue=9.241255404221698e-09)
# high-degree-cit-and-media 5 0.5 0.75 0.5 3
# RanksumsResult(statistic=-0.41262310513065203, pvalue=0.67988277037759)
# high-degree-cit-and-media 5 0.5 0.75 0.5 10
# RanksumsResult(statistic=0.7607935728907199, pvalue=0.44678037386331904)
# high-degree-cit-and-media 5 0.5 0.75 0.75 3
# RanksumsResult(statistic=3.1647232574904427, pvalue=0.0015523051952041698)
# high-degree-cit-and-media 5 0.5 0.75 0.75 10
# RanksumsResult(statistic=-0.6832270950070332, pvalue=0.49446335401501396)
# high-degree-cit-and-media 5 0.75 0.01 0.01 3
# RanksumsResult(statistic=0.2915731713362911, pvalue=0.7706129906753921)
# high-degree-cit-and-media 5 0.75 0.01 0.01 10
# RanksumsResult(statistic=-1.1284762131015043, pvalue=0.2591188571074261)
# high-degree-cit-and-media 5 0.75 0.01 0.05 3
# RanksumsResult(statistic=-1.3242322908844182, pvalue=0.18542590970342232)
# high-degree-cit-and-media 5 0.75 0.01 0.05 10
# RanksumsResult(statistic=-0.1729149858449519, pvalue=0.8627182520886836)
# high-degree-cit-and-media 5 0.75 0.01 0.1 3
# RanksumsResult(statistic=-0.3166642434723609, pvalue=0.7514983830681264)
# high-degree-cit-and-media 5 0.75 0.01 0.1 10
# RanksumsResult(statistic=-0.3953505100321596, pvalue=0.6925842275141214)
# high-degree-cit-and-media 5 0.75 0.01 0.25 3
# RanksumsResult(statistic=2.892200090380896, pvalue=0.0038255422530487633)
# high-degree-cit-and-media 5 0.75 0.01 0.25 10
# RanksumsResult(statistic=-0.9538310848834143, pvalue=0.34016915188524965)
# high-degree-cit-and-media 5 0.75 0.01 0.5 3
# RanksumsResult(statistic=2.9152302171788858, pvalue=0.0035542625177278028)
# high-degree-cit-and-media 5 0.75 0.01 0.5 10
# RanksumsResult(statistic=-0.5738339927165812, pvalue=0.5660801435165529)
# high-degree-cit-and-media 5 0.75 0.01 0.75 3
# RanksumsResult(statistic=4.7824581821060255, pvalue=1.731644192922014e-06)
# high-degree-cit-and-media 5 0.75 0.01 0.75 10
# RanksumsResult(statistic=0.7183127134907304, pvalue=0.47256449290962976)
# high-degree-cit-and-media 5 0.75 0.05 0.01 3
# RanksumsResult(statistic=0.228382090746733, pvalue=0.8193492110986211)
# high-degree-cit-and-media 5 0.75 0.05 0.01 10
# RanksumsResult(statistic=0.44908747256080267, pvalue=0.6533685570905088)
# high-degree-cit-and-media 5 0.75 0.05 0.05 3
# RanksumsResult(statistic=1.0862543139718561, pvalue=0.2773664934897989)
# high-degree-cit-and-media 5 0.75 0.05 0.05 10
# RanksumsResult(statistic=1.4969582418693423, pvalue=0.1344041239568254)
# high-degree-cit-and-media 5 0.75 0.05 0.1 3
# RanksumsResult(statistic=-0.40163721614535464, pvalue=0.6879510364483259)
# high-degree-cit-and-media 5 0.75 0.05 0.1 10
# RanksumsResult(statistic=-0.8463571598261281, pvalue=0.39735352961405923)
# high-degree-cit-and-media 5 0.75 0.05 0.25 3
# RanksumsResult(statistic=1.050435796072466, pvalue=0.2935177951248066)
# high-degree-cit-and-media 5 0.75 0.05 0.25 10
# RanksumsResult(statistic=0.5124203212552748, pvalue=0.608356871776905)
# high-degree-cit-and-media 5 0.75 0.05 0.5 3
# RanksumsResult(statistic=-0.9327201353185902, pvalue=0.3509644858938379)
# high-degree-cit-and-media 5 0.75 0.05 0.5 10
# RanksumsResult(statistic=0.19959443224924564, pvalue=0.8417977825892821)
# high-degree-cit-and-media 5 0.75 0.05 0.75 3
# RanksumsResult(statistic=3.074521927531649, pvalue=0.0021084022187305047)
# high-degree-cit-and-media 5 0.75 0.05 0.75 10
# RanksumsResult(statistic=-0.738883234768842, pvalue=0.45997790347151124)
# high-degree-cit-and-media 5 0.75 0.1 0.01 3
# RanksumsResult(statistic=0.23989715414572793, pvalue=0.8104099871120831)
# high-degree-cit-and-media 5 0.75 0.1 0.01 10
# RanksumsResult(statistic=0.27636152157587857, pvalue=0.7822704075890778)
# high-degree-cit-and-media 5 0.75 0.1 0.05 3
# RanksumsResult(statistic=-0.3953505100321596, pvalue=0.6925842275141214)
# high-degree-cit-and-media 5 0.75 0.1 0.05 10
# RanksumsResult(statistic=-0.4913093716904508, pvalue=0.6232076524641327)
# high-degree-cit-and-media 5 0.75 0.1 0.1 3
# RanksumsResult(statistic=2.544989667690276, pvalue=0.01092809717628205)
# high-degree-cit-and-media 5 0.75 0.1 0.1 10
# RanksumsResult(statistic=2.957452116308534, pvalue=0.003101929231275989)
# high-degree-cit-and-media 5 0.75 0.1 0.25 3
# RanksumsResult(statistic=-1.0620214849997358, pvalue=0.28822593165416477)
# high-degree-cit-and-media 5 0.75 0.1 0.25 10
# RanksumsResult(statistic=0.5773534982089473, pvalue=0.5637006807902722)
# high-degree-cit-and-media 5 0.75 0.1 0.5 3
# RanksumsResult(statistic=1.204911648436064, pvalue=0.2282374113055513)
# high-degree-cit-and-media 5 0.75 0.1 0.5 10
# RanksumsResult(statistic=-2.1763469824100437, pvalue=0.0295293249406084)
# high-degree-cit-and-media 5 0.75 0.1 0.75 3
# RanksumsResult(statistic=1.901904638067331, pvalue=0.057183622739205985)
# high-degree-cit-and-media 5 0.75 0.1 0.75 10
# RanksumsResult(statistic=4.206836495099485, pvalue=2.589703665484977e-05)
# high-degree-cit-and-media 5 0.75 0.25 0.01 3
# RanksumsResult(statistic=2.408567427623108, pvalue=0.016015267600244847)
# high-degree-cit-and-media 5 0.75 0.25 0.01 10
# RanksumsResult(statistic=4.381481623317574, pvalue=1.1787498725908494e-05)
# high-degree-cit-and-media 5 0.75 0.25 0.05 3
# RanksumsResult(statistic=1.0056488701788915, pvalue=0.31458450662362225)
# high-degree-cit-and-media 5 0.75 0.25 0.05 10
# RanksumsResult(statistic=1.8961471063678335, pvalue=0.05794059510886767)
# high-degree-cit-and-media 5 0.75 0.25 0.1 3
# RanksumsResult(statistic=-0.39151215556582797, pvalue=0.695418705454059)
# high-degree-cit-and-media 5 0.75 0.25 0.1 10
# RanksumsResult(statistic=-1.521907545900498, pvalue=0.12803224816622086)
# high-degree-cit-and-media 5 0.75 0.25 0.25 3
# RanksumsResult(statistic=1.1392594111815348, pvalue=0.25459497222033345)
# high-degree-cit-and-media 5 0.75 0.25 0.25 10
# RanksumsResult(statistic=1.5986746352271308, pvalue=0.10989291641530463)
# high-degree-cit-and-media 5 0.75 0.25 0.5 3
# RanksumsResult(statistic=0.6678736771417065, pvalue=0.5042142312837063)
# high-degree-cit-and-media 5 0.75 0.25 0.5 10
# RanksumsResult(statistic=0.20727114118190892, pvalue=0.8357981107453628)
# high-degree-cit-and-media 5 0.75 0.25 0.75 3
# RanksumsResult(statistic=0.503202037458905, pvalue=0.6148222324794231)
# high-degree-cit-and-media 5 0.75 0.25 0.75 10
# RanksumsResult(statistic=-2.0669538801195917, pvalue=0.038738499957647235)
# high-degree-cit-and-media 5 0.75 0.5 0.01 3
# RanksumsResult(statistic=-1.9729141956944665, pvalue=0.04850533899865822)
# high-degree-cit-and-media 5 0.75 0.5 0.01 10
# RanksumsResult(statistic=7.189237915439175, pvalue=6.515395585095012e-13)
# high-degree-cit-and-media 5 0.75 0.5 0.05 3
# RanksumsResult(statistic=-0.9384776670180877, pvalue=0.3479989887720877)
# high-degree-cit-and-media 5 0.75 0.5 0.05 10
# RanksumsResult(statistic=1.5161500142010005, pvalue=0.12948142413048272)
# high-degree-cit-and-media 5 0.75 0.5 0.1 3
# RanksumsResult(statistic=4.984103274531644, pvalue=6.224982635366893e-07)
# high-degree-cit-and-media 5 0.75 0.5 0.1 10
# RanksumsResult(statistic=1.7905923585437133, pvalue=0.07335873418248692)
# high-degree-cit-and-media 5 0.75 0.5 0.25 3
# RanksumsResult(statistic=0.5047436123226116, pvalue=0.6137389250435618)
# high-degree-cit-and-media 5 0.75 0.5 0.25 10
# RanksumsResult(statistic=2.0957415386170792, pvalue=0.03610512488244955)
# high-degree-cit-and-media 5 0.75 0.5 0.5 3
# RanksumsResult(statistic=2.3789281263994084, pvalue=0.01736306106419802)
# high-degree-cit-and-media 5 0.75 0.5 0.5 10
# RanksumsResult(statistic=2.7117974304633083, pvalue=0.006691947440791171)
# high-degree-cit-and-media 5 0.75 0.5 0.75 3
# RanksumsResult(statistic=3.0610876868994885, pvalue=0.002205344981492029)
# high-degree-cit-and-media 5 0.75 0.5 0.75 10
# RanksumsResult(statistic=0.06179034094543918, pvalue=0.9507297955990536)
# high-degree-cit-and-media 5 0.75 0.75 0.01 3
# RanksumsResult(statistic=2.510283820980897, pvalue=0.012063415964255827)
# high-degree-cit-and-media 5 0.75 0.75 0.01 10
# RanksumsResult(statistic=6.3236889832813885, pvalue=2.553915147033019e-10)
# high-degree-cit-and-media 5 0.75 0.75 0.05 3
# RanksumsResult(statistic=2.491092048649239, pvalue=0.012735112151677056)
# high-degree-cit-and-media 5 0.75 0.75 0.05 10
# RanksumsResult(statistic=3.1167438266612972, pvalue=0.0018286039476547087)
# high-degree-cit-and-media 5 0.75 0.75 0.1 3
# RanksumsResult(statistic=4.210674849565817, pvalue=2.546089762818851e-05)
# high-degree-cit-and-media 5 0.75 0.75 0.1 10
# RanksumsResult(statistic=4.536934979204006, pvalue=5.707769463397931e-06)
# high-degree-cit-and-media 5 0.75 0.75 0.25 3
# RanksumsResult(statistic=-0.527148846190778, pvalue=0.598090228436652)
# high-degree-cit-and-media 5 0.75 0.75 0.25 10
# RanksumsResult(statistic=6.087630183601992, pvalue=1.1459418897309056e-09)
# high-degree-cit-and-media 5 0.75 0.75 0.5 3
# RanksumsResult(statistic=3.7212846551085317, pvalue=0.00019821185327970157)
# high-degree-cit-and-media 5 0.75 0.75 0.5 10
# RanksumsResult(statistic=3.4871450326623012, pvalue=0.0004882065281269717)
# high-degree-cit-and-media 5 0.75 0.75 0.75 3
# RanksumsResult(statistic=0.22012808961812708, pvalue=0.825771398951862)
# high-degree-cit-and-media 5 0.75 0.75 0.75 10
# RanksumsResult(statistic=-1.976752550160798, pvalue=0.04806960758426403)
# total_Scen 3456

# %% [markdown]
# ## Which scenarios had non-significant results??
#
# #### SAME CODE, ONLY PRINT IF PVALE > 0.05

# %%
org_strat_list = ['neighbors-of-neighbors', "high-degree-citizens", "high-degree-media", "high-degree-cit-and-media"]
org_cap_list = [1,5]
p_list =[0.01, 0.05, 0.1, 0.25, 0.5, 0.75]
cit_cit_list = [0.01, 0.05, 0.1, 0.25, 0.5, 0.75]
cit_media_list = [0.01, 0.05, 0.1, 0.25, 0.5, 0.75]
ba_m_list = [3, 10]
count_scenarios = 0
ranksums_df= pd.DataFrame(columns = ["flint-organizing-strategy", "organizing-capacity", "simple-spread-chance", "citizen-citizen-influence", "citizen-media-influence", "ba-m", "pvalue", "p*cc", "p*cm", "sig?"])

for i in range(0, len(org_strat_list)):
    org_mod_strat = org_mod_df.loc[org_mod_df["flint-organizing-strategy"] == org_strat_list[i]]
    for j in range(0, len(org_cap_list)):
        org_mod_cap = org_mod_strat.loc[org_mod_strat['organizing-capacity'] == org_cap_list[j]]
        for k in range(0, len(p_list)):
            org_mod_p = org_mod_cap.loc[org_mod_cap["simple-spread-chance"] == p_list[k]]
            infl_mod_p = infl_mod_df.loc[infl_mod_df["simple-spread-chance"] == p_list[k]]
            for l in range(0, len(cit_cit_list)):
                org_mod_cc= org_mod_p.loc[org_mod_p["citizen-citizen-influence"] == cit_cit_list[l]]
                infl_mod_cc = infl_mod_p.loc[infl_mod_p["citizen-citizen-influence"] == cit_cit_list[l]]
                for m in range(0, len(cit_media_list)):
                    org_mod_cm= org_mod_cc.loc[org_mod_cc["citizen-media-influence"] == cit_media_list[m]]
                    infl_mod_cm = infl_mod_cc.loc[infl_mod_cc["citizen-media-influence"] == cit_media_list[m]]
                    for n in range(0, len(ba_m_list)):
                        org_mod_b= org_mod_cm.loc[org_mod_cm["ba-m"] == ba_m_list[n]]
                        infl_mod_b = infl_mod_cm.loc[infl_mod_cm["ba-m"] == ba_m_list[n]]
                        
                        infl_mod_peaks = infl_mod_b['peak-time'].to_numpy()
                        org_mod_peaks = org_mod_b['peak-time'].to_numpy()
                        #print(org_strat_list[i], org_cap_list[j], p_list[k], cit_cit_list[l], cit_media_list[m], ba_m_list[n])
                        statistic, pvalue = ranksums(infl_mod_peaks, org_mod_peaks)
                        if pvalue >= 0.05:
                            count_scenarios = count_scenarios +1
                            print(org_strat_list[i], org_cap_list[j], p_list[k], cit_cit_list[l], cit_media_list[m], ba_m_list[n])
                            print(statistic, pvalue)
                            p_c_m = p_list[k] * cit_media_list[m]
                            p_c_c = p_list[k] * cit_cit_list[l]
                            sig = 0
                            ranksums_df = ranksums_df.append({'flint-organizing-strategy': org_strat_list[i], "organizing-capacity": org_cap_list[j], "simple-spread-chance": p_list[k], "citizen-citizen-influence": cit_cit_list[l], "citizen-media-influence": cit_media_list[m], "ba-m": ba_m_list[n], "p*cc": p_c_c, "p*cm": p_c_m, "sig?":sig }, ignore_index = True)
                        if pvalue < 0.05:
                            sig = 1
                            p_c_m = p_list[k] * cit_media_list[m]
                            p_c_c = p_list[k] * cit_cit_list[l]
                            ranksums_df = ranksums_df.append({'flint-organizing-strategy': org_strat_list[i], "organizing-capacity": org_cap_list[j], "simple-spread-chance": p_list[k], "citizen-citizen-influence": cit_cit_list[l], "citizen-media-influence": cit_media_list[m], "ba-m": ba_m_list[n], "p*cc": p_c_c, "p*cm": p_c_m, "sig?":sig }, ignore_index = True)
                        
print("scenarios_non_sig:", count_scenarios )
# Out:
# neighbors-of-neighbors 1 0.01 0.01 0.5 3
# 0.9768612116814042 0.3286378669763188
# neighbors-of-neighbors 1 0.01 0.01 0.75 3
# 0.9308009580854244 0.3519565340173525
# neighbors-of-neighbors 1 0.01 0.01 0.75 10
# 0.019309481545449744 0.984594220160167
# neighbors-of-neighbors 1 0.01 0.05 0.1 10
# 1.7829156496110499 0.0746000351864719
# neighbors-of-neighbors 1 0.01 0.05 0.25 3
# 1.2244350747597954 0.22078814455690277
# neighbors-of-neighbors 1 0.01 0.05 0.5 3
# 0.529659384167093 0.5963481131324073
# neighbors-of-neighbors 1 0.01 0.05 0.75 3
# -0.575753169949747 0.5647820310198043
# neighbors-of-neighbors 1 0.01 0.05 0.75 10
# 0.32633023811810064 0.7441745126173596
# neighbors-of-neighbors 1 0.01 0.1 0.01 3
# 1.9135696211540696 0.05567516978839568
# neighbors-of-neighbors 1 0.01 0.1 0.05 3
# 1.0075680474120572 0.31366187485574926
# neighbors-of-neighbors 1 0.01 0.1 0.05 10
# 1.3012021640864282 0.19318926472900855
# neighbors-of-neighbors 1 0.01 0.1 0.1 3
# 1.3875651395788904 0.16526950283772024
# neighbors-of-neighbors 1 0.01 0.1 0.1 10
# 0.1554533558864317 0.8764639234477992
# neighbors-of-neighbors 1 0.01 0.1 0.5 3
# 0.4507446822025713 0.6521735745592814
# neighbors-of-neighbors 1 0.01 0.1 0.5 10
# -0.8770639955567813 0.38045187937888747
# neighbors-of-neighbors 1 0.01 0.1 0.75 3
# -0.9039324768211028 0.3660312069101994
# neighbors-of-neighbors 1 0.01 0.1 0.75 10
# 1.4163527980763777 0.1566722365473763
# neighbors-of-neighbors 1 0.01 0.25 0.01 3
# -0.4209466976908044 0.6737940046160676
# neighbors-of-neighbors 1 0.01 0.25 0.05 3
# -0.11585688927269847 0.9077659629132487
# neighbors-of-neighbors 1 0.01 0.25 0.1 10
# -0.47501324601806366 0.634777532017426
# neighbors-of-neighbors 1 0.01 0.25 0.25 3
# -0.7811051338984901 0.4347406626573165
# neighbors-of-neighbors 1 0.01 0.25 0.25 10
# -0.2590889264773862 0.7955666285533602
# neighbors-of-neighbors 1 0.01 0.25 0.75 10
# 0.5638368611271325 0.5728651630341485
# neighbors-of-neighbors 1 0.01 0.5 0.01 3
# -1.6159472303256233 0.10610572285091015
# neighbors-of-neighbors 1 0.01 0.5 0.05 10
# -1.9460457144301448 0.051649248557880036
# neighbors-of-neighbors 1 0.01 0.5 0.25 3
# -0.5508038659185913 0.5817681337497668
# neighbors-of-neighbors 1 0.01 0.5 0.25 10
# 0.35888614260200896 0.7196802666070132
# neighbors-of-neighbors 1 0.01 0.5 0.5 3
# -0.26950056370884945 0.7875445084811331
# neighbors-of-neighbors 1 0.01 0.5 0.5 10
# 0.37999709216683303 0.7039475736599878
# neighbors-of-neighbors 1 0.01 0.5 0.75 3
# -1.2704953283557752 0.2039082458779019
# neighbors-of-neighbors 1 0.01 0.5 0.75 10
# 0.7676708932663293 0.44268273274812764
# neighbors-of-neighbors 1 0.01 0.75 0.25 3
# 1.421177841745101 0.15526506471327697
# neighbors-of-neighbors 1 0.01 0.75 0.25 10
# 0.8727885658543284 0.3827783330602269
# neighbors-of-neighbors 1 0.01 0.75 0.5 3
# -0.9538310848834143 0.34016915188524965
# neighbors-of-neighbors 1 0.01 0.75 0.75 3
# 0.4855518399909533 0.6272849492883783
# neighbors-of-neighbors 1 0.05 0.01 0.05 3
# 0.20151360948241145 0.8402969888731917
# neighbors-of-neighbors 1 0.05 0.01 0.1 3
# 0.5066627895557774 0.612391443618159
# neighbors-of-neighbors 1 0.05 0.01 0.25 3
# -0.424138168529647 0.6714650508637703
# neighbors-of-neighbors 1 0.05 0.01 0.25 10
# 1.9095813469999943 0.05618713867980016
# neighbors-of-neighbors 1 0.05 0.01 0.5 3
# -0.4711513497089737 0.6375326577220026
# neighbors-of-neighbors 1 0.05 0.01 0.5 10
# -0.6507295280816563 0.5152210985520869
# neighbors-of-neighbors 1 0.05 0.01 0.75 3
# -1.846248498305522 0.06485613197554005
# neighbors-of-neighbors 1 0.05 0.01 0.75 10
# 0.7926201972974851 0.42799913769412745
# neighbors-of-neighbors 1 0.05 0.05 0.01 3
# -1.1342337448010016 0.2566965126668186
# neighbors-of-neighbors 1 0.05 0.05 0.01 10
# -1.4604938744391915 0.14415438982860032
# neighbors-of-neighbors 1 0.05 0.05 0.05 3
# 1.2205967202934638 0.22223874873102079
# neighbors-of-neighbors 1 0.05 0.05 0.05 10
# 0.6966613356391939 0.4860147610388904
# neighbors-of-neighbors 1 0.05 0.05 0.1 10
# 1.663926661154769 0.09612708630458668
# neighbors-of-neighbors 1 0.05 0.05 0.25 3
# 0.6870654494733648 0.4920414854783316
# neighbors-of-neighbors 1 0.05 0.05 0.25 10
# 0.13434240632160763 0.893131821752615
# neighbors-of-neighbors 1 0.05 0.05 0.5 3
# -0.6717120316080382 0.5017670403101799
# neighbors-of-neighbors 1 0.05 0.05 0.5 10
# 0.3723203832341697 0.7096543241593918
# neighbors-of-neighbors 1 0.05 0.05 0.75 3
# 0.8981749451216053 0.36909228861252075
# neighbors-of-neighbors 1 0.05 0.05 0.75 10
# -1.554533558864317 0.12005719820843133
# neighbors-of-neighbors 1 0.05 0.1 0.01 10
# -1.0040930403633868 0.3153337696977423
# neighbors-of-neighbors 1 0.05 0.1 0.05 3
# -0.9653461482824092 0.33437146461036793
# neighbors-of-neighbors 1 0.05 0.1 0.05 10
# 0.49706690338994824 0.6191418728797323
# neighbors-of-neighbors 1 0.05 0.1 0.1 3
# -1.2858487462211017 0.19849585406545112
# neighbors-of-neighbors 1 0.05 0.1 0.1 10
# -1.8616019161708488 0.06265922300744195
# neighbors-of-neighbors 1 0.05 0.1 0.25 3
# 0.4107039278974862 0.681289646406868
# neighbors-of-neighbors 1 0.05 0.1 0.25 10
# 0.1800808673178424 0.8570890827239026
# neighbors-of-neighbors 1 0.05 0.1 0.5 3
# 1.1150419724693434 0.26483243585236604
# neighbors-of-neighbors 1 0.05 0.1 0.5 10
# 0.5603997520844204 0.5752068006930979
# neighbors-of-neighbors 1 0.05 0.1 0.75 3
# -0.999891338479394 0.317363096533678
# neighbors-of-neighbors 1 0.05 0.25 0.05 3
# 0.13626158355477347 0.8916144924501823
# neighbors-of-neighbors 1 0.05 0.25 0.1 3
# 0.10363557059095446 0.9174585583906181
# neighbors-of-neighbors 1 0.05 0.25 0.1 10
# 1.5913667948848464 0.11152705259423713
# neighbors-of-neighbors 1 0.05 0.25 0.25 10
# -1.361318448954207 0.1734130752315972
# neighbors-of-neighbors 1 0.05 0.25 0.5 10
# -0.021110949564824056 0.9831571503525829
# neighbors-of-neighbors 1 0.05 0.25 0.75 3
# -1.262818619423112 0.2066543716759306
# neighbors-of-neighbors 1 0.05 0.25 0.75 10
# 0.3281793068713558 0.74277609291809
# neighbors-of-neighbors 1 0.05 0.5 0.01 3
# 1.021002288044218 0.3072533546840891
# neighbors-of-neighbors 1 0.05 0.5 0.01 10
# -1.2570610877236144 0.20873151614671603
# neighbors-of-neighbors 1 0.05 0.5 0.05 10
# 0.8350410686570711 0.40369458546468195
# neighbors-of-neighbors 1 0.05 0.5 0.1 10
# 1.7042293830512512 0.08833824183020182
# neighbors-of-neighbors 1 0.05 0.5 0.25 3
# -1.2110008341276346 0.2258950850152639
# neighbors-of-neighbors 1 0.05 0.5 0.5 3
# -0.29939164837386845 0.7646412337360282
# neighbors-of-neighbors 1 0.05 0.5 0.5 10
# 1.109284440769846 0.26730749509949026
# neighbors-of-neighbors 1 0.05 0.5 0.75 3
# -0.848276337059294 0.3962840926183341
# neighbors-of-neighbors 1 0.05 0.5 0.75 10
# 1.2685761511226092 0.20459227472632047
# neighbors-of-neighbors 1 0.05 0.75 0.01 3
# 1.5449376726984878 0.12236133996673944
# neighbors-of-neighbors 1 0.05 0.75 0.05 3
# 0.978990714354302 0.32758456759015064
# neighbors-of-neighbors 1 0.05 0.75 0.05 10
# 1.3933226712783877 0.16352223790825693
# neighbors-of-neighbors 1 0.05 0.75 0.1 10
# -0.6333284869447218 0.5265191542415524
# neighbors-of-neighbors 1 0.05 0.75 0.25 3
# 1.4018683601996513 0.160954560209425
# neighbors-of-neighbors 1 0.05 0.75 0.5 10
# 1.6792800790200955 0.09309747154851818
# neighbors-of-neighbors 1 0.05 0.75 0.75 3
# -0.3514325641271853 0.7252638557803162
# neighbors-of-neighbors 1 0.05 0.75 0.75 10
# 0.23989715414572793 0.8104099871120831
# neighbors-of-neighbors 1 0.1 0.01 0.05 3
# -0.4344633347726192 0.6639520144809165
# neighbors-of-neighbors 1 0.1 0.01 0.05 10
# 0.3552944604362753 0.7223690050391373
# neighbors-of-neighbors 1 0.1 0.01 0.1 3
# -0.1400999380211051 0.8885810295622768
# neighbors-of-neighbors 1 0.1 0.01 0.1 10
# -0.21110949564824058 0.8328018307548968
# neighbors-of-neighbors 1 0.1 0.01 0.25 3
# -0.6870654494733648 0.4920414854783316
# neighbors-of-neighbors 1 0.1 0.01 0.25 10
# 0.7369640575356762 0.46114420714392645
# neighbors-of-neighbors 1 0.1 0.01 0.5 3
# 0.5174941054180531 0.6048112827057195
# neighbors-of-neighbors 1 0.1 0.01 0.5 10
# 0.2648464581768836 0.7911277459294537
# neighbors-of-neighbors 1 0.1 0.01 0.75 3
# 0.4625217131929634 0.6437072350586424
# neighbors-of-neighbors 1 0.1 0.01 0.75 10
# 0.25141221754472287 0.801495422766016
# neighbors-of-neighbors 1 0.1 0.05 0.01 3
# -0.41262310513065203 0.67988277037759
# neighbors-of-neighbors 1 0.1 0.05 0.01 10
# -1.0335075863458782 0.3013664221313901
# neighbors-of-neighbors 1 0.1 0.05 0.05 3
# 1.011406401878389 0.3118219583724834
# neighbors-of-neighbors 1 0.1 0.05 0.05 10
# -1.262818619423112 0.2066543716759306
# neighbors-of-neighbors 1 0.1 0.05 0.1 10
# -0.10363557059095446 0.9174585583906181
# neighbors-of-neighbors 1 0.1 0.05 0.25 3
# -0.8214078557949724 0.41141399034618387
# neighbors-of-neighbors 1 0.1 0.05 0.25 10
# -0.22262455904723552 0.8238277207325432
# neighbors-of-neighbors 1 0.1 0.05 0.5 3
# -0.09595886165829116 0.9235532453724784
# neighbors-of-neighbors 1 0.1 0.05 0.5 10
# 0.9442351987175851 0.3450494719089633
# neighbors-of-neighbors 1 0.1 0.05 0.75 3
# 0.6928229811728622 0.48842064827052367
# neighbors-of-neighbors 1 0.1 0.05 0.75 10
# -0.554642220384923 0.5791394044060465
# neighbors-of-neighbors 1 0.1 0.1 0.01 3
# -0.6774695633075357 0.49810807508836663
# neighbors-of-neighbors 1 0.1 0.1 0.01 10
# -0.47787513105829005 0.6327390827335031
# neighbors-of-neighbors 1 0.1 0.1 0.05 3
# 0.07484791209346711 0.9403357203629744
# neighbors-of-neighbors 1 0.1 0.1 0.05 10
# 1.0407810552997412 0.2979771744262667
# neighbors-of-neighbors 1 0.1 0.1 0.1 10
# -1.184132352863313 0.2363606750121815
# neighbors-of-neighbors 1 0.1 0.1 0.25 3
# 1.0497899465417053 0.2938146984792791
# neighbors-of-neighbors 1 0.1 0.1 0.25 10
# -1.4508979882733626 0.14680826818487328
# neighbors-of-neighbors 1 0.1 0.1 0.5 3
# -0.14182914569305044 0.8872149618431077
# neighbors-of-neighbors 1 0.1 0.1 0.5 10
# -0.8885790589557763 0.37422934958738574
# neighbors-of-neighbors 1 0.1 0.1 0.75 3
# 0.01727259509849241 0.9862191482850413
# neighbors-of-neighbors 1 0.1 0.1 0.75 10
# -0.02303012679798988 0.981626241608544
# neighbors-of-neighbors 1 0.1 0.25 0.01 3
# -0.23222044521306462 0.8163667987697143
# neighbors-of-neighbors 1 0.1 0.25 0.01 10
# -0.32626012963818996 0.7442275511207657
# neighbors-of-neighbors 1 0.1 0.25 0.05 3
# 0.03089517047271959 0.9753531414906936
# neighbors-of-neighbors 1 0.1 0.25 0.05 10
# 0.5128389917095078 0.6080639521780646
# neighbors-of-neighbors 1 0.1 0.25 0.1 3
# 0.3185834207055267 0.7500424272133137
# neighbors-of-neighbors 1 0.1 0.25 0.1 10
# -0.9979721612462281 0.3182928581022264
# neighbors-of-neighbors 1 0.1 0.25 0.5 3
# 0.14393829248743675 0.8855491974882863
# neighbors-of-neighbors 1 0.1 0.25 0.5 10
# -0.5412079797527622 0.5883642379549373
# neighbors-of-neighbors 1 0.1 0.25 0.75 10
# -0.6506010820432141 0.5153040317018884
# neighbors-of-neighbors 1 0.1 0.5 0.01 10
# -0.7964585517638167 0.42576555750840805
# neighbors-of-neighbors 1 0.1 0.5 0.05 3
# 0.7216106396703496 0.4705338958624645
# neighbors-of-neighbors 1 0.1 0.5 0.05 10
# -0.22262455904723552 0.8238277207325432
# neighbors-of-neighbors 1 0.1 0.5 0.1 3
# 0.3704012060010039 0.7110835753511068
# neighbors-of-neighbors 1 0.1 0.5 0.1 10
# -0.1976752550160798 0.8432991513049917
# neighbors-of-neighbors 1 0.1 0.5 0.25 3
# 1.3031213413195941 0.19253333872238787
# neighbors-of-neighbors 1 0.1 0.5 0.25 10
# 1.1438296309668308 0.2526942987885128
# neighbors-of-neighbors 1 0.1 0.5 0.5 3
# -0.10171639335778863 0.9189817896190008
# neighbors-of-neighbors 1 0.1 0.5 0.5 10
# 0.5565613976180888 0.5778271344533535
# neighbors-of-neighbors 1 0.1 0.5 0.75 3
# -0.06333284869447217 0.9495014587827427
# neighbors-of-neighbors 1 0.1 0.5 0.75 10
# -0.6064600056804001 0.5442093325449675
# neighbors-of-neighbors 1 0.1 0.75 0.01 3
# 1.560120602623555 0.11873138371094565
# neighbors-of-neighbors 1 0.1 0.75 0.01 10
# 1.807367472654096 0.07070500209264298
# neighbors-of-neighbors 1 0.1 0.75 0.05 3
# 1.0382748831427104 0.2991420986269484
# neighbors-of-neighbors 1 0.1 0.75 0.05 10
# 1.1508451001088047 0.2497959668749783
# neighbors-of-neighbors 1 0.1 0.75 0.25 10
# -1.2280830262906037 0.21941580212682332
# neighbors-of-neighbors 1 0.1 0.75 0.5 10
# -0.8233270330281383 0.4103220447446183
# neighbors-of-neighbors 1 0.1 0.75 0.75 3
# 1.7822651466450112 0.07470600351686256
# neighbors-of-neighbors 1 0.25 0.01 0.01 3
# -1.694633496885422 0.09014496854631131
# neighbors-of-neighbors 1 0.25 0.01 0.01 10
# -1.901904638067331 0.057183622739205985
# neighbors-of-neighbors 1 0.25 0.01 0.05 3
# 0.7772667794321585 0.4370013904170186
# neighbors-of-neighbors 1 0.25 0.01 0.05 10
# 1.2129200113608003 0.22516040390980097
# neighbors-of-neighbors 1 0.25 0.01 0.1 3
# -0.9077708312874345 0.363999312270168
# neighbors-of-neighbors 1 0.25 0.01 0.1 10
# 0.07337602987270903 0.9415068915579807
# neighbors-of-neighbors 1 0.25 0.01 0.25 3
# -0.6717120316080382 0.5017670403101799
# neighbors-of-neighbors 1 0.25 0.01 0.25 10
# 0.7878268470543496 0.43079799512002603
# neighbors-of-neighbors 1 0.25 0.01 0.5 3
# 1.1265570358683383 0.2599298130019171
# neighbors-of-neighbors 1 0.25 0.01 0.5 10
# -0.6717120316080382 0.5017670403101799
# neighbors-of-neighbors 1 0.25 0.01 0.75 3
# 0.4759559538251242 0.6341057578683958
# neighbors-of-neighbors 1 0.25 0.01 0.75 10
# 1.2473925078360535 0.2122536123498181
# neighbors-of-neighbors 1 0.25 0.05 0.01 3
# -1.5257459003668297 0.12707315852207726
# neighbors-of-neighbors 1 0.25 0.05 0.01 10
# 1.2781720372884384 0.20118877333696328
# neighbors-of-neighbors 1 0.25 0.05 0.05 3
# -0.5503202240453177 0.5820997551838216
# neighbors-of-neighbors 1 0.25 0.05 0.05 10
# -0.12164973373633338 0.9031764241252673
# neighbors-of-neighbors 1 0.25 0.05 0.1 3
# 0.7312065258361787 0.4646530147317377
# neighbors-of-neighbors 1 0.25 0.05 0.25 3
# -0.33969437027035077 0.734086701785257
# neighbors-of-neighbors 1 0.25 0.05 0.25 10
# -0.8789831727899471 0.37941039969512314
# neighbors-of-neighbors 1 0.25 0.05 0.5 3
# 1.1687789349979865 0.2424927095278695
# neighbors-of-neighbors 1 0.25 0.05 0.5 10
# -1.9425338434722441 0.052072506977969744
# neighbors-of-neighbors 1 0.25 0.05 0.75 3
# 0.02878765849748735 0.9770339438941905
# neighbors-of-neighbors 1 0.25 0.05 0.75 10
# -0.00575753169949747 0.9954061797288744
# neighbors-of-neighbors 1 0.25 0.1 0.01 3
# -1.4105952663768802 0.1583639881852129
# neighbors-of-neighbors 1 0.25 0.1 0.01 10
# -1.2877679234542676 0.19782676127449295
# neighbors-of-neighbors 1 0.25 0.1 0.05 3
# 0.8789831727899471 0.37941039969512314
# neighbors-of-neighbors 1 0.25 0.1 0.05 10
# -0.08252462102613041 0.9342295403590714
# neighbors-of-neighbors 1 0.25 0.1 0.1 3
# 0.815650324095475 0.4147001582481622
# neighbors-of-neighbors 1 0.25 0.1 0.1 10
# -1.7829156496110499 0.0746000351864719
# neighbors-of-neighbors 1 0.25 0.1 0.25 3
# -0.33969437027035077 0.734086701785257
# neighbors-of-neighbors 1 0.25 0.1 0.25 10
# 1.1778783742724344 0.23884509764610296
# neighbors-of-neighbors 1 0.25 0.1 0.5 3
# -1.0581595886906459 0.28998269144748545
# neighbors-of-neighbors 1 0.25 0.1 0.5 10
# 0.07100955762713547 0.9433901488085427
# neighbors-of-neighbors 1 0.25 0.25 0.1 3
# -1.8289759032070296 0.0674032181768864
# neighbors-of-neighbors 1 0.25 0.25 0.1 10
# 0.34929025643617984 0.7268714126094481
# neighbors-of-neighbors 1 0.25 0.25 0.25 3
# -1.773319763445221 0.0761757359999075
# neighbors-of-neighbors 1 0.25 0.25 0.5 3
# 0.6655162487833306 0.505720354251779
# neighbors-of-neighbors 1 0.25 0.25 0.5 10
# -0.2840382305085419 0.7763810829410939
# neighbors-of-neighbors 1 0.25 0.25 0.75 3
# 0.8386804508934649 0.40164865134320393
# neighbors-of-neighbors 1 0.25 0.25 0.75 10
# 1.314636404718589 0.18863212906207494
# neighbors-of-neighbors 1 0.25 0.5 0.01 3
# -1.2359501381587903 0.21647709841856766
# neighbors-of-neighbors 1 0.25 0.5 0.01 10
# -1.2359501381587903 0.21647709841856766
# neighbors-of-neighbors 1 0.25 0.5 0.05 3
# 0.11323145675678357 0.9098470571496396
# neighbors-of-neighbors 1 0.25 0.5 0.1 3
# 1.673522547320598 0.09422447164973127
# neighbors-of-neighbors 1 0.25 0.5 0.1 10
# -0.05373696252864305 0.957144733493817
# neighbors-of-neighbors 1 0.25 0.5 0.25 3
# -1.8001882447095423 0.07183091936205314
# neighbors-of-neighbors 1 0.25 0.5 0.25 10
# 1.4413021021075334 0.14949935369034875
# neighbors-of-neighbors 1 0.25 0.5 0.5 3
# -0.8214078557949724 0.41141399034618387
# neighbors-of-neighbors 1 0.25 0.5 0.5 10
# 1.465136471274939 0.14288368792399322
# neighbors-of-neighbors 1 0.25 0.5 0.75 10
# 0.489390194457285 0.624565476772807
# neighbors-of-neighbors 1 0.25 0.75 0.01 10
# 1.950257636090424 0.05114541926173692
# neighbors-of-neighbors 1 0.25 0.75 0.05 3
# -0.23989715414572793 0.8104099871120831
# neighbors-of-neighbors 1 0.25 0.75 0.1 3
# -0.5168020925253619 0.6052943191675346
# neighbors-of-neighbors 1 0.25 0.75 0.1 10
# 0.08444379825929622 0.9327035856420398
# neighbors-of-neighbors 1 0.25 0.75 0.5 3
# 1.2474652015577852 0.21222697207142127
# neighbors-of-neighbors 1 0.25 0.75 0.5 10
# -0.5148592275158681 0.6066513940880064
# neighbors-of-neighbors 1 0.25 0.75 0.75 3
# -0.07868626655979875 0.9372821693056437
# neighbors-of-neighbors 1 0.25 0.75 0.75 10
# 1.4374637476412018 0.15058626656571794
# neighbors-of-neighbors 1 0.5 0.01 0.01 3
# 0.1880793688502507 0.8508144337517071
# neighbors-of-neighbors 1 0.5 0.01 0.01 10
# 0.49514772615678243 0.6204958467384245
# neighbors-of-neighbors 1 0.5 0.01 0.05 3
# 0.4279765229959786 0.6686682129448881
# neighbors-of-neighbors 1 0.5 0.01 0.05 10
# 0.1324232290884418 0.8946495423136553
# neighbors-of-neighbors 1 0.5 0.01 0.1 10
# 0.5508038659185913 0.5817681337497668
# neighbors-of-neighbors 1 0.5 0.01 0.25 3
# 1.7185438575450271 0.08569746200846853
# neighbors-of-neighbors 1 0.5 0.01 0.25 10
# -1.3280706453507498 0.18415476986914625
# neighbors-of-neighbors 1 0.5 0.01 0.5 3
# 0.8597914004582888 0.3899040404976287
# neighbors-of-neighbors 1 0.5 0.01 0.75 3
# -1.1822131756301473 0.23712112600013358
# neighbors-of-neighbors 1 0.5 0.01 0.75 10
# 1.2513035560241168 0.21082374858662567
# neighbors-of-neighbors 1 0.5 0.05 0.01 3
# -0.20727114118190892 0.8357981107453628
# neighbors-of-neighbors 1 0.5 0.05 0.01 10
# -0.1727259509849241 0.8628668444358498
# neighbors-of-neighbors 1 0.5 0.05 0.05 3
# 1.4720089378381866 0.14101846401347218
# neighbors-of-neighbors 1 0.5 0.05 0.05 10
# -0.5296929163537673 0.5963248600893174
# neighbors-of-neighbors 1 0.5 0.05 0.1 10
# -0.5085819667889432 0.6110452718137109
# neighbors-of-neighbors 1 0.5 0.05 0.25 3
# -1.8635210934040145 0.06238898767107983
# neighbors-of-neighbors 1 0.5 0.05 0.25 10
# -0.8386804508934649 0.40164865134320393
# neighbors-of-neighbors 1 0.5 0.05 0.5 3
# 0.2859574077417077 0.774910743630478
# neighbors-of-neighbors 1 0.5 0.05 0.75 3
# -1.4048377346773828 0.16006953537007662
# neighbors-of-neighbors 1 0.5 0.05 0.75 10
# -0.7427215892351736 0.4576502561739243
# neighbors-of-neighbors 1 0.5 0.1 0.01 3
# -0.10939310229045193 0.9128907044912136
# neighbors-of-neighbors 1 0.5 0.1 0.01 10
# 1.6217047620251208 0.10486657869897187
# neighbors-of-neighbors 1 0.5 0.1 0.05 10
# 0.6928229811728622 0.48842064827052367
# neighbors-of-neighbors 1 0.5 0.1 0.1 3
# 0.8943365906552737 0.37114182799456563
# neighbors-of-neighbors 1 0.5 0.1 0.1 10
# 0.5776723471829128 0.563485352108883
# neighbors-of-neighbors 1 0.5 0.1 0.25 3
# -0.075306978027254 0.9399704695875648
# neighbors-of-neighbors 1 0.5 0.1 0.25 10
# 1.8923087519015018 0.05844985554177635
# neighbors-of-neighbors 1 0.5 0.1 0.5 3
# -1.4278678614753726 0.15332989561346633
# neighbors-of-neighbors 1 0.5 0.1 0.5 10
# -0.06141367146130635 0.9510297646605194
# neighbors-of-neighbors 1 0.5 0.1 0.75 3
# -0.3089875345396976 0.7573310091666936
# neighbors-of-neighbors 1 0.5 0.25 0.01 10
# -0.6411454531329678 0.5214281852655442
# neighbors-of-neighbors 1 0.5 0.25 0.05 3
# 0.7484791209346712 0.45417121424637863
# neighbors-of-neighbors 1 0.5 0.25 0.1 3
# -1.3837267851125588 0.16644212874128073
# neighbors-of-neighbors 1 0.5 0.25 0.1 10
# -1.2167583658271321 0.22369616504280088
# neighbors-of-neighbors 1 0.5 0.25 0.25 3
# -0.1324232290884418 0.8946495423136553
# neighbors-of-neighbors 1 0.5 0.25 0.25 10
# -1.2992829868532625 0.19384683078513643
# neighbors-of-neighbors 1 0.5 0.25 0.5 3
# 0.31474454919083084 0.752955616635139
# neighbors-of-neighbors 1 0.5 0.25 0.75 3
# -0.29939164837386845 0.7646412337360282
# neighbors-of-neighbors 1 0.5 0.25 0.75 10
# -1.044032414842208 0.2964703927825385
# neighbors-of-neighbors 1 0.5 0.5 0.01 3
# 1.7426129277145677 0.08140125031434149
# neighbors-of-neighbors 1 0.5 0.5 0.05 3
# -0.8444379825929623 0.39842470511736217
# neighbors-of-neighbors 1 0.5 0.5 0.05 10
# -0.9327201353185902 0.3509644858938379
# neighbors-of-neighbors 1 0.5 0.5 0.1 10
# 1.2090816568944687 0.22663147559684438
# neighbors-of-neighbors 1 0.5 0.5 0.25 3
# -0.7542366526341686 0.4507071325759193
# neighbors-of-neighbors 1 0.5 0.5 0.25 10
# -1.8539252072381853 0.06374986103542868
# neighbors-of-neighbors 1 0.5 0.5 0.5 10
# -1.7541279911135625 0.07940857838118887
# neighbors-of-neighbors 1 0.5 0.5 0.75 3
# -0.24373550861205956 0.8074356706537857
# neighbors-of-neighbors 1 0.5 0.75 0.05 3
# -0.4586833587266318 0.64646156601489
# neighbors-of-neighbors 1 0.5 0.75 0.1 3
# 0.5795915244160786 0.562190109971288
# neighbors-of-neighbors 1 0.5 0.75 0.25 3
# -1.3127172274854233 0.18927825033744783
# neighbors-of-neighbors 1 0.5 0.75 0.5 10
# -1.8286079023540907 0.06745836802571947
# neighbors-of-neighbors 1 0.5 0.75 0.75 3
# 0.8310037419608015 0.40597151545399235
# neighbors-of-neighbors 1 0.75 0.01 0.01 3
# 1.0736071739270057 0.2829987809363509
# neighbors-of-neighbors 1 0.75 0.01 0.01 10
# 0.5738339927165812 0.5660801435165529
# neighbors-of-neighbors 1 0.75 0.01 0.05 3
# -1.7138252692170803 0.08656082107727454
# neighbors-of-neighbors 1 0.75 0.01 0.1 3
# -1.2762528600552725 0.20186614816058446
# neighbors-of-neighbors 1 0.75 0.01 0.1 10
# -0.8463571598261281 0.39735352961405923
# neighbors-of-neighbors 1 0.75 0.01 0.25 3
# -0.9960529840130623 0.31922440213545233
# neighbors-of-neighbors 1 0.75 0.01 0.25 10
# 1.9441265371969791 0.051880193862253766
# neighbors-of-neighbors 1 0.75 0.01 0.5 3
# 1.3261514681175839 0.1847895309862091
# neighbors-of-neighbors 1 0.75 0.01 0.5 10
# -1.3971610257447193 0.1623651538806934
# neighbors-of-neighbors 1 0.75 0.01 0.75 10
# -0.08303077064543389 0.9338270726453869
# neighbors-of-neighbors 1 0.75 0.05 0.01 3
# 0.9519119076502484 0.34114166001764523
# neighbors-of-neighbors 1 0.75 0.05 0.05 3
# 0.44524911809447104 0.6561397341590249
# neighbors-of-neighbors 1 0.75 0.05 0.1 3
# 0.9847835588179369 0.32473039821065364
# neighbors-of-neighbors 1 0.75 0.05 0.1 10
# -0.7408024120020078 0.45881325250095917
# neighbors-of-neighbors 1 0.75 0.05 0.25 3
# -1.1257427740997201 0.26027441280335784
# neighbors-of-neighbors 1 0.75 0.05 0.25 10
# -1.4912007101698448 0.13590880729197993
# neighbors-of-neighbors 1 0.75 0.05 0.5 3
# -0.7753476021989927 0.4381342881648449
# neighbors-of-neighbors 1 0.75 0.05 0.5 10
# 1.1419104537336648 0.25349124291876657
# neighbors-of-neighbors 1 0.75 0.05 0.75 10
# -0.47979430829145586 0.6313736604383959
# neighbors-of-neighbors 1 0.75 0.1 0.01 10
# 0.08444379825929622 0.9327035856420398
# neighbors-of-neighbors 1 0.75 0.1 0.05 3
# 0.6064600056804001 0.5442093325449675
# neighbors-of-neighbors 1 0.75 0.1 0.05 10
# -1.899985460834165 0.05743502765678223
# neighbors-of-neighbors 1 0.75 0.1 0.1 3
# 0.8920980473997782 0.3723403814041373
# neighbors-of-neighbors 1 0.75 0.1 0.25 3
# -0.5368035869635028 0.5914032937114075
# neighbors-of-neighbors 1 0.75 0.1 0.25 10
# -0.7704483136634448 0.44103400362716105
# neighbors-of-neighbors 1 0.75 0.1 0.5 3
# -0.31474454919083084 0.752955616635139
# neighbors-of-neighbors 1 0.75 0.1 0.75 3
# 0.02303012679798988 0.981626241608544
# neighbors-of-neighbors 1 0.75 0.25 0.05 3
# 1.0574666554743688 0.29029866482910194
# neighbors-of-neighbors 1 0.75 0.25 0.1 3
# 1.8059457764090399 0.07092680978038632
# neighbors-of-neighbors 1 0.75 0.25 0.1 10
# -1.2647377966562776 0.20596533609697365
# neighbors-of-neighbors 1 0.75 0.25 0.25 10
# 1.9383690054974816 0.05257821902628632
# neighbors-of-neighbors 1 0.75 0.25 0.5 3
# -1.7905923585437133 0.07335873418248692
# neighbors-of-neighbors 1 0.75 0.25 0.5 10
# -0.24373550861205956 0.8074356706537857
# neighbors-of-neighbors 1 0.75 0.25 0.75 3
# -0.28754402140508856 0.7736958001731616
# neighbors-of-neighbors 1 0.75 0.5 0.01 3
# -1.2129200113608003 0.22516040390980097
# neighbors-of-neighbors 1 0.75 0.5 0.05 3
# -0.6467627275768825 0.5177855185978588
# neighbors-of-neighbors 1 0.75 0.5 0.05 10
# 1.7637238772793917 0.07777847906698608
# neighbors-of-neighbors 1 0.75 0.5 0.1 10
# 0.9576694393497459 0.3382294717847558
# neighbors-of-neighbors 1 0.75 0.5 0.25 3
# 0.6448435503437167 0.519028576358953
# neighbors-of-neighbors 1 0.75 0.5 0.25 10
# -1.0785776050391929 0.28077606915433795
# neighbors-of-neighbors 1 0.75 0.5 0.5 3
# -0.05020465201816933 0.9599593044564874
# neighbors-of-neighbors 1 0.75 0.5 0.75 10
# -0.08496171879997887 0.9322918245976544
# neighbors-of-neighbors 1 0.75 0.75 0.01 3
# -0.7273681713698471 0.4670004470304009
# neighbors-of-neighbors 1 0.75 0.75 0.05 3
# -0.5699956382502496 0.5686806564471028
# neighbors-of-neighbors 1 0.75 0.75 0.05 10
# 1.3741308989467296 0.1694010483730899
# neighbors-of-neighbors 1 0.75 0.75 0.1 3
# 1.923015587632155 0.054478092282080295
# neighbors-of-neighbors 1 0.75 0.75 0.25 3
# 0.05792844463634923 0.953805625616874
# neighbors-of-neighbors 1 0.75 0.75 0.5 3
# 1.6754417245537638 0.09384759589834961
# neighbors-of-neighbors 1 0.75 0.75 0.5 10
# 0.7638325387999977 0.4449670434085755
# neighbors-of-neighbors 1 0.75 0.75 0.75 3
# 0.3379159270453705 0.7354265448017584
# neighbors-of-neighbors 5 0.01 0.01 0.25 3
# 1.7349362187819044 0.08275210303538112
# neighbors-of-neighbors 5 0.01 0.01 0.25 10
# 1.8750361568030094 0.060787749515480306
# neighbors-of-neighbors 5 0.01 0.01 0.5 3
# 0.2303012679798988 0.8178576753859506
# neighbors-of-neighbors 5 0.01 0.01 0.75 10
# 1.7764723021813764 0.07565510323398887
# neighbors-of-neighbors 5 0.01 0.05 0.05 3
# 0.8418933953816088 0.39984762756829784
# neighbors-of-neighbors 5 0.01 0.05 0.05 10
# 1.2225158975266295 0.22151259578378568
# neighbors-of-neighbors 5 0.01 0.05 0.1 3
# -0.8866598817226105 0.37526204369155924
# neighbors-of-neighbors 5 0.01 0.05 0.25 10
# 0.030706835730653175 0.9755033396099162
# neighbors-of-neighbors 5 0.01 0.05 0.5 3
# -1.3328314011417834 0.1825871384229214
# neighbors-of-neighbors 5 0.01 0.05 0.5 10
# -1.3917119202498474 0.1640096511777811
# neighbors-of-neighbors 5 0.01 0.05 0.75 3
# -0.8425188053597965 0.39949761800260786
# neighbors-of-neighbors 5 0.01 0.05 0.75 10
# -0.34757066781809537 0.7281626380641433
# neighbors-of-neighbors 5 0.01 0.1 0.01 3
# -0.19116386729995247 0.8483972112529832
# neighbors-of-neighbors 5 0.01 0.1 0.05 3
# 0.30131082560703426 0.763177486650608
# neighbors-of-neighbors 5 0.01 0.1 0.05 10
# 1.0574666554743688 0.29029866482910194
# neighbors-of-neighbors 5 0.01 0.1 0.1 3
# 1.1016077318371826 0.2706322454826603
# neighbors-of-neighbors 5 0.01 0.1 0.1 10
# 0.2648464581768836 0.7911277459294537
# neighbors-of-neighbors 5 0.01 0.1 0.25 3
# -1.0613050099407004 0.28855130967966736
# neighbors-of-neighbors 5 0.01 0.1 0.25 10
# -1.9428650094938418 0.05203247062143558
# neighbors-of-neighbors 5 0.01 0.1 0.5 10
# -1.8596827389376829 0.0629304255519525
# neighbors-of-neighbors 5 0.01 0.1 0.75 3
# -1.5046349508020056 0.1324179553857516
# neighbors-of-neighbors 5 0.01 0.25 0.05 3
# -1.581446538572334 0.11377597364732497
# neighbors-of-neighbors 5 0.01 0.25 0.25 10
# 0.424138168529647 0.6714650508637703
# neighbors-of-neighbors 5 0.01 0.25 0.5 10
# -0.42221899129648116 0.6728651807888246
# neighbors-of-neighbors 5 0.01 0.25 0.75 10
# 0.11199499296360851 0.9108273766311561
# neighbors-of-neighbors 5 0.01 0.5 0.05 10
# -0.12858487462211016 0.89768613524464
# neighbors-of-neighbors 5 0.01 0.5 0.1 3
# -1.8212991942743664 0.06856138886391021
# neighbors-of-neighbors 5 0.01 0.5 0.1 10
# -1.8328142576733613 0.06683019811802052
# neighbors-of-neighbors 5 0.01 0.5 0.25 3
# 0.8655489321577864 0.3867375709984181
# neighbors-of-neighbors 5 0.01 0.5 0.75 3
# 1.7215019781497436 0.08515977352938923
# neighbors-of-neighbors 5 0.01 0.75 0.01 3
# -0.750398298167837 0.45301485561117605
# neighbors-of-neighbors 5 0.01 0.75 0.05 3
# -0.05949449422814052 0.9525582506806729
# neighbors-of-neighbors 5 0.01 0.75 0.05 10
# 1.1045023443997253 0.26937528714265
# neighbors-of-neighbors 5 0.01 0.75 0.1 3
# -0.9864570978472332 0.3239088580933056
# neighbors-of-neighbors 5 0.01 0.75 0.1 10
# 0.5908701352907622 0.5546074376283425
# neighbors-of-neighbors 5 0.05 0.01 0.05 3
# 1.4835240012371815 0.13793524446995767
# neighbors-of-neighbors 5 0.05 0.01 0.1 3
# -0.8636297549246206 0.3877913131813021
# neighbors-of-neighbors 5 0.05 0.01 0.25 3
# -0.8386804508934649 0.40164865134320393
# neighbors-of-neighbors 5 0.05 0.01 0.25 10
# 1.6121088758592916 0.10693824962627325
# neighbors-of-neighbors 5 0.05 0.01 0.5 3
# -0.8708576176997834 0.38383190054771144
# neighbors-of-neighbors 5 0.05 0.01 0.5 10
# 0.673900905936196 0.5003743161284118
# neighbors-of-neighbors 5 0.05 0.01 0.75 3
# -0.2955532939075368 0.7675712468612716
# neighbors-of-neighbors 5 0.05 0.01 0.75 10
# 0.9365584897849218 0.34898571281040014
# neighbors-of-neighbors 5 0.05 0.05 0.01 3
# 0.34929025643617984 0.7268714126094481
# neighbors-of-neighbors 5 0.05 0.05 0.05 3
# -0.7369640575356762 0.46114420714392645
# neighbors-of-neighbors 5 0.05 0.05 0.05 10
# -0.12858487462211016 0.89768613524464
# neighbors-of-neighbors 5 0.05 0.05 0.1 10
# 0.04030272189648229 0.9678517837842313
# neighbors-of-neighbors 5 0.05 0.05 0.25 3
# 1.249384378790951 0.21152451917085535
# neighbors-of-neighbors 5 0.05 0.05 0.25 10
# 1.73685539601507 0.0824126981733556
# neighbors-of-neighbors 5 0.05 0.05 0.5 3
# -1.0075680474120572 0.31366187485574926
# neighbors-of-neighbors 5 0.05 0.05 0.5 10
# -0.44908747256080267 0.6533685570905088
# neighbors-of-neighbors 5 0.05 0.05 0.75 3
# 0.7945393745306509 0.4268814961263746
# neighbors-of-neighbors 5 0.05 0.05 0.75 10
# 0.4836326627577875 0.6286465898590077
# neighbors-of-neighbors 5 0.05 0.1 0.05 3
# -0.43757240916180773 0.6616962755909802
# neighbors-of-neighbors 5 0.05 0.1 0.1 3
# -0.554642220384923 0.5791394044060465
# neighbors-of-neighbors 5 0.05 0.1 0.1 10
# 0.130504051855276 0.8961676486426331
# neighbors-of-neighbors 5 0.05 0.1 0.25 10
# 1.9594799550623057 0.05005660511685516
# neighbors-of-neighbors 5 0.05 0.1 0.5 10
# 0.7427215892351736 0.4576502561739243
# neighbors-of-neighbors 5 0.05 0.1 0.75 10
# 1.5967554579939651 0.11032022825454066
# neighbors-of-neighbors 5 0.05 0.25 0.01 10
# 0.8809023500231129 0.3783706754273647
# neighbors-of-neighbors 5 0.05 0.25 0.05 10
# 0.7956523390034357 0.4262341362595984
# neighbors-of-neighbors 5 0.05 0.25 0.25 10
# 0.8747195140088734 0.3817265396640894
# neighbors-of-neighbors 5 0.05 0.25 0.5 10
# -0.24757386307839122 0.8044641354926282
# neighbors-of-neighbors 5 0.05 0.25 0.75 10
# 0.9480735531839167 0.3430920107983433
# neighbors-of-neighbors 5 0.05 0.5 0.01 10
# 1.8001882447095423 0.07183091936205314
# neighbors-of-neighbors 5 0.05 0.5 0.25 10
# 1.4604938744391915 0.14415438982860032
# neighbors-of-neighbors 5 0.05 0.5 0.75 3
# 1.391403494045222 0.1641031056914024
# neighbors-of-neighbors 5 0.05 0.75 0.01 10
# 0.3377751930371849 0.735532605385693
# neighbors-of-neighbors 5 0.1 0.01 0.01 3
# 1.794430713010045 0.07274444841924942
# neighbors-of-neighbors 5 0.1 0.01 0.05 3
# -0.2626089490181165 0.7928520017808313
# neighbors-of-neighbors 5 0.1 0.01 0.05 10
# -0.028964222318174616 0.9768931250688623
# neighbors-of-neighbors 5 0.1 0.01 0.1 3
# 0.4433299408613052 0.6575271022616973
# neighbors-of-neighbors 5 0.1 0.01 0.1 10
# 1.5295842548331613 0.12611966922432907
# neighbors-of-neighbors 5 0.1 0.01 0.25 3
# -0.3934313327989938 0.6940009314308933
# neighbors-of-neighbors 5 0.1 0.01 0.25 10
# 0.8118119696291433 0.41689953274570746
# neighbors-of-neighbors 5 0.1 0.01 0.5 3
# 1.2918043153905878 0.19642492053246197
# neighbors-of-neighbors 5 0.1 0.01 0.5 10
# 1.2225158975266295 0.22151259578378568
# neighbors-of-neighbors 5 0.1 0.01 0.75 3
# -1.1937282390291422 0.23258429043087925
# neighbors-of-neighbors 5 0.1 0.01 0.75 10
# 0.021110949564824056 0.9831571503525829
# neighbors-of-neighbors 5 0.1 0.05 0.01 3
# -1.4163527980763777 0.1566722365473763
# neighbors-of-neighbors 5 0.1 0.05 0.05 3
# 0.026868481264321526 0.9785646327445474
# neighbors-of-neighbors 5 0.1 0.05 0.05 10
# -0.522016207421104 0.6016590460672593
# neighbors-of-neighbors 5 0.1 0.05 0.1 3
# 0.3185834207055267 0.7500424272133137
# neighbors-of-neighbors 5 0.1 0.05 0.1 10
# -0.4855518399909533 0.6272849492883783
# neighbors-of-neighbors 5 0.1 0.05 0.25 3
# 1.3280706453507498 0.18415476986914625
# neighbors-of-neighbors 5 0.1 0.05 0.25 10
# 0.738883234768842 0.45997790347151124
# neighbors-of-neighbors 5 0.1 0.05 0.5 3
# 0.6832270950070332 0.49446335401501396
# neighbors-of-neighbors 5 0.1 0.05 0.5 10
# -0.5617740100023997 0.5742700019057735
# neighbors-of-neighbors 5 0.1 0.05 0.75 3
# 1.9095813469999943 0.05618713867980016
# neighbors-of-neighbors 5 0.1 0.05 0.75 10
# 1.6600883066884373 0.09689668893727973
# neighbors-of-neighbors 5 0.1 0.1 0.01 3
# -0.3185834207055267 0.7500424272133137
# neighbors-of-neighbors 5 0.1 0.1 0.01 10
# -1.186051530096479 0.23560195023188657
# neighbors-of-neighbors 5 0.1 0.1 0.05 3
# -0.33009848410452164 0.7413255486053987
# neighbors-of-neighbors 5 0.1 0.1 0.1 10
# -0.9365584897849218 0.34898571281040014
# neighbors-of-neighbors 5 0.1 0.1 0.5 3
# 1.3969199418260723 0.16243764707428965
# neighbors-of-neighbors 5 0.1 0.1 0.5 10
# -0.5623189293175863 0.5738987435265961
# neighbors-of-neighbors 5 0.1 0.1 0.75 10
# 1.1073652635366802 0.2681360379385004
# neighbors-of-neighbors 5 0.1 0.25 0.01 3
# 1.696552674118588 0.0897812636450185
# neighbors-of-neighbors 5 0.1 0.25 0.05 3
# 1.6104107608905085 0.10730821292604428
# neighbors-of-neighbors 5 0.1 0.25 0.1 10
# 1.5622102677969802 0.1182384625329842
# neighbors-of-neighbors 5 0.1 0.25 0.25 3
# 0.38383544663316466 0.7011004140906372
# neighbors-of-neighbors 5 0.1 0.25 0.5 10
# -1.0459515920753737 0.2955833826846017
# neighbors-of-neighbors 5 0.1 0.25 0.75 3
# 0.510501144022109 0.6097004133108391
# neighbors-of-neighbors 5 0.1 0.25 0.75 10
# 0.8521146915256256 0.3941504385790532
# neighbors-of-neighbors 5 0.1 0.5 0.05 3
# 1.1207995041688408 0.2623732152727213
# neighbors-of-neighbors 5 0.1 0.5 0.5 3
# 1.9383690054974816 0.05257821902628632
# neighbors-of-neighbors 5 0.1 0.5 0.75 10
# 0.6390860186442192 0.5227669748230976
# neighbors-of-neighbors 5 0.25 0.01 0.01 3
# -0.12474652015577851 0.9007242272672782
# neighbors-of-neighbors 5 0.25 0.01 0.01 10
# 0.33201766133768745 0.7398759229466028
# neighbors-of-neighbors 5 0.25 0.01 0.05 3
# 1.7560471683467285 0.07908035493686501
# neighbors-of-neighbors 5 0.25 0.01 0.05 10
# 0.999891338479394 0.317363096533678
# neighbors-of-neighbors 5 0.25 0.01 0.1 3
# -0.771509247732661 0.44040514310631795
# neighbors-of-neighbors 5 0.25 0.01 0.1 10
# 0.7260365061089104 0.4678163912398364
# neighbors-of-neighbors 5 0.25 0.01 0.25 3
# -0.38191626939999884 0.702523472158411
# neighbors-of-neighbors 5 0.25 0.01 0.25 10
# 0.6545914243907462 0.5127308468846183
# neighbors-of-neighbors 5 0.25 0.01 0.5 3
# 1.5660486222633119 0.11733723468934405
# neighbors-of-neighbors 5 0.25 0.01 0.5 10
# 1.9364498282643159 0.052812631739716565
# neighbors-of-neighbors 5 0.25 0.01 0.75 3
# 1.7426129277145677 0.08140125031434149
# neighbors-of-neighbors 5 0.25 0.01 0.75 10
# 0.7743102099725347 0.4387473673359904
# neighbors-of-neighbors 5 0.25 0.05 0.01 3
# -0.44716829532763686 0.6547535510722631
# neighbors-of-neighbors 5 0.25 0.05 0.01 10
# 0.7695900704994952 0.44154309693919325
# neighbors-of-neighbors 5 0.25 0.05 0.05 3
# 0.8689266695452385 0.3848872411840476
# neighbors-of-neighbors 5 0.25 0.05 0.05 10
# 0.16219964498177783 0.8711486393615063
# neighbors-of-neighbors 5 0.25 0.05 0.1 3
# 1.044032414842208 0.2964703927825385
# neighbors-of-neighbors 5 0.25 0.05 0.25 3
# 1.2685761511226092 0.20459227472632047
# neighbors-of-neighbors 5 0.25 0.05 0.25 10
# -0.15929171035276335 0.8734390515523964
# neighbors-of-neighbors 5 0.25 0.05 0.5 3
# 1.9287731193316526 0.05375903430066124
# neighbors-of-neighbors 5 0.25 0.05 0.75 3
# -0.10555474782412029 0.9159356300951328
# neighbors-of-neighbors 5 0.25 0.05 0.75 10
# 0.2801998760422102 0.7793241617655278
# neighbors-of-neighbors 5 0.25 0.1 0.01 3
# 1.0593858327075345 0.28942409909654476
# neighbors-of-neighbors 5 0.25 0.1 0.01 10
# -0.1727259509849241 0.8628668444358498
# neighbors-of-neighbors 5 0.25 0.1 0.05 3
# 0.6832270950070332 0.49446335401501396
# neighbors-of-neighbors 5 0.25 0.1 0.05 10
# 1.60827052139296 0.10777594391358317
# neighbors-of-neighbors 5 0.25 0.1 0.1 3
# 1.0286789969768813 0.3036305426455296
# neighbors-of-neighbors 5 0.25 0.1 0.25 3
# 1.0670625416401978 0.28594359526499624
# neighbors-of-neighbors 5 0.25 0.1 0.25 10
# 0.5580440166634976 0.5768143275589764
# neighbors-of-neighbors 5 0.25 0.1 0.5 3
# -0.34950161597264034 0.7267127578474624
# neighbors-of-neighbors 5 0.25 0.1 0.5 10
# 0.08252462102613041 0.9342295403590714
# neighbors-of-neighbors 5 0.25 0.1 0.75 10
# -1.2321117836924587 0.21790733019478703
# neighbors-of-neighbors 5 0.25 0.25 0.01 10
# 1.4297870387085385 0.15277815020964536
# neighbors-of-neighbors 5 0.25 0.25 0.05 10
# 1.337666531516579 0.18100516573920344
# neighbors-of-neighbors 5 0.25 0.25 0.1 3
# -0.07868626655979875 0.9372821693056437
# neighbors-of-neighbors 5 0.25 0.25 0.5 3
# -0.23989715414572793 0.8104099871120831
# neighbors-of-neighbors 5 0.25 0.25 0.5 10
# 0.18232183715075323 0.8553301623212772
# neighbors-of-neighbors 5 0.25 0.25 0.75 3
# 1.4854431784703472 0.13742646487010268
# neighbors-of-neighbors 5 0.25 0.5 0.01 3
# -0.5335312708200989 0.5936658703635442
# neighbors-of-neighbors 5 0.25 0.5 0.05 3
# 0.13626158355477347 0.8916144924501823
# neighbors-of-neighbors 5 0.25 0.5 0.1 10
# 1.8750361568030094 0.060787749515480306
# neighbors-of-neighbors 5 0.25 0.5 0.25 3
# -0.08444379825929622 0.9327035856420398
# neighbors-of-neighbors 5 0.25 0.5 0.5 3
# -0.5412079797527622 0.5883642379549373
# neighbors-of-neighbors 5 0.25 0.5 0.5 10
# 1.7289999115993357 0.08380911090041465
# neighbors-of-neighbors 5 0.25 0.5 0.75 10
# 0.9269626036190927 0.3539459510195796
# neighbors-of-neighbors 5 0.25 0.75 0.05 3
# -0.05565613976180888 0.9556157407093809
# neighbors-of-neighbors 5 0.25 0.75 0.25 10
# 1.7790772951447182 0.07522709052295362
# neighbors-of-neighbors 5 0.5 0.01 0.01 3
# 0.738883234768842 0.45997790347151124
# neighbors-of-neighbors 5 0.5 0.01 0.01 10
# 1.2647377966562776 0.20596533609697365
# neighbors-of-neighbors 5 0.5 0.01 0.05 3
# -0.22454373628040133 0.8223342389872648
# neighbors-of-neighbors 5 0.5 0.01 0.05 10
# 0.9960529840130623 0.31922440213545233
# neighbors-of-neighbors 5 0.5 0.01 0.1 10
# 1.3741308989467296 0.1694010483730899
# neighbors-of-neighbors 5 0.5 0.01 0.25 10
# -0.5181778529547724 0.6043341854628569
# neighbors-of-neighbors 5 0.5 0.01 0.5 3
# -0.3723203832341697 0.7096543241593918
# neighbors-of-neighbors 5 0.5 0.01 0.5 10
# -1.4835240012371815 0.13793524446995767
# neighbors-of-neighbors 5 0.5 0.01 0.75 3
# -1.9095813469999943 0.05618713867980016
# neighbors-of-neighbors 5 0.5 0.01 0.75 10
# 0.7523174754010028 0.4518601611036812
# neighbors-of-neighbors 5 0.5 0.05 0.01 3
# -0.3109067117728634 0.7558715419210881
# neighbors-of-neighbors 5 0.5 0.05 0.01 10
# 1.8424101438391904 0.06541517913225874
# neighbors-of-neighbors 5 0.5 0.05 0.05 3
# 1.2532227332572827 0.21012465886464415
# neighbors-of-neighbors 5 0.5 0.05 0.05 10
# -1.7637238772793917 0.07777847906698608
# neighbors-of-neighbors 5 0.5 0.05 0.1 3
# -1.109284440769846 0.26730749509949026
# neighbors-of-neighbors 5 0.5 0.05 0.1 10
# -1.5084733052683372 0.1314334338370654
# neighbors-of-neighbors 5 0.5 0.05 0.25 10
# -0.6429243731105508 0.5202731734417126
# neighbors-of-neighbors 5 0.5 0.05 0.5 3
# -1.044032414842208 0.2964703927825385
# neighbors-of-neighbors 5 0.5 0.05 0.75 10
# -0.228382090746733 0.8193492110986211
# neighbors-of-neighbors 5 0.5 0.1 0.01 3
# 1.5046349508020056 0.1324179553857516
# neighbors-of-neighbors 5 0.5 0.1 0.05 10
# -0.47403677659195836 0.6354736819542119
# neighbors-of-neighbors 5 0.5 0.1 0.1 3
# 0.5028244350894457 0.6150877123960647
# neighbors-of-neighbors 5 0.5 0.1 0.1 10
# -0.02878765849748735 0.9770339438941905
# neighbors-of-neighbors 5 0.5 0.1 0.25 3
# 0.6391438391543866 0.5227293630069216
# neighbors-of-neighbors 5 0.5 0.1 0.25 10
# 0.12666569738894434 0.89920499662059
# neighbors-of-neighbors 5 0.5 0.1 0.5 3
# -0.33201766133768745 0.7398759229466028
# neighbors-of-neighbors 5 0.5 0.1 0.5 10
# -1.3645350127809004 0.17239924239577475
# neighbors-of-neighbors 5 0.5 0.1 0.75 3
# -0.7619133615668319 0.44611171477998957
# neighbors-of-neighbors 5 0.5 0.25 0.01 3
# 0.8463571598261281 0.39735352961405923
# neighbors-of-neighbors 5 0.5 0.25 0.01 10
# 1.7349784534780006 0.0827446216930343
# neighbors-of-neighbors 5 0.5 0.25 0.1 3
# -0.9039324768211028 0.3660312069101994
# neighbors-of-neighbors 5 0.5 0.25 0.1 10
# 0.6659544999085407 0.5054401835855094
# neighbors-of-neighbors 5 0.5 0.25 0.25 10
# -0.23413962244623046 0.8148765864474832
# neighbors-of-neighbors 5 0.5 0.25 0.5 10
# 0.16888759651859245 0.8658850555958869
# neighbors-of-neighbors 5 0.5 0.25 0.75 3
# 1.554533558864317 0.12005719820843133
# neighbors-of-neighbors 5 0.5 0.25 0.75 10
# -1.6600883066884373 0.09689668893727973
# neighbors-of-neighbors 5 0.5 0.5 0.05 10
# 1.5506952043979854 0.12097474431734569
# neighbors-of-neighbors 5 0.5 0.5 0.25 3
# -1.021002288044218 0.3072533546840891
# neighbors-of-neighbors 5 0.5 0.5 0.25 10
# -0.8521146915256256 0.3941504385790532
# neighbors-of-neighbors 5 0.5 0.5 0.5 10
# -1.5698869767296435 0.11644140791514182
# neighbors-of-neighbors 5 0.5 0.5 0.75 10
# 0.9538310848834143 0.34016915188524965
# neighbors-of-neighbors 5 0.5 0.75 0.01 3
# 1.3760500761798953 0.16880613029726954
# neighbors-of-neighbors 5 0.5 0.75 0.05 3
# 0.44716829532763686 0.6547535510722631
# neighbors-of-neighbors 5 0.5 0.75 0.1 10
# -1.8711978023366778 0.0613176692798299
# neighbors-of-neighbors 5 0.5 0.75 0.25 3
# 1.5276650775999954 0.1265957149996264
# neighbors-of-neighbors 5 0.5 0.75 0.5 3
# -0.04606025359597976 0.9632622254005128
# neighbors-of-neighbors 5 0.5 0.75 0.5 10
# 1.0851928628542755 0.27783624461344014
# neighbors-of-neighbors 5 0.5 0.75 0.75 10
# -1.9249347648653208 0.05423751998129005
# neighbors-of-neighbors 5 0.75 0.01 0.01 3
# -1.4231087898996462 0.15470462065321997
# neighbors-of-neighbors 5 0.75 0.01 0.01 10
# 0.1324232290884418 0.8946495423136553
# neighbors-of-neighbors 5 0.75 0.01 0.05 10
# 0.5692594477816957 0.5691800825960809
# neighbors-of-neighbors 5 0.75 0.01 0.1 3
# 0.619894246312561 0.5353274140558366
# neighbors-of-neighbors 5 0.75 0.01 0.1 10
# 0.2878765849748735 0.7734412110247795
# neighbors-of-neighbors 5 0.75 0.01 0.25 10
# -1.5295842548331613 0.12611966922432907
# neighbors-of-neighbors 5 0.75 0.01 0.5 3
# 1.7982690674763766 0.0721343791056096
# neighbors-of-neighbors 5 0.75 0.01 0.75 3
# 0.14223790790271454 0.8868920900007279
# neighbors-of-neighbors 5 0.75 0.01 0.75 10
# -1.7030962723086673 0.08855005343711744
# neighbors-of-neighbors 5 0.75 0.05 0.01 3
# 1.9537224233628083 0.05073405297284305
# neighbors-of-neighbors 5 0.75 0.05 0.05 3
# -0.4298957002291444 0.6672715133825093
# neighbors-of-neighbors 5 0.75 0.05 0.1 3
# 0.49239177940896844 0.622442409545763
# neighbors-of-neighbors 5 0.75 0.05 0.1 10
# -0.2590889264773862 0.7955666285533602
# neighbors-of-neighbors 5 0.75 0.05 0.25 3
# 0.47501324601806366 0.634777532017426
# neighbors-of-neighbors 5 0.75 0.05 0.25 10
# 0.5584805748512546 0.5765162654398766
# neighbors-of-neighbors 5 0.75 0.05 0.5 3
# -1.685037610719593 0.09198131532065487
# neighbors-of-neighbors 5 0.75 0.05 0.5 10
# 0.2456546858452254 0.8059495528371325
# neighbors-of-neighbors 5 0.75 0.05 0.75 3
# 0.19959443224924564 0.8417977825892821
# neighbors-of-neighbors 5 0.75 0.05 0.75 10
# -0.32434095240502414 0.7456799184397783
# neighbors-of-neighbors 5 0.75 0.1 0.01 10
# -0.03838354466331647 0.9693818807701129
# neighbors-of-neighbors 5 0.75 0.1 0.05 3
# 0.5968641195145711 0.5505981044704186
# neighbors-of-neighbors 5 0.75 0.1 0.05 10
# -0.5450463342190939 0.5857216508254123
# neighbors-of-neighbors 5 0.75 0.1 0.1 3
# 0.2394375711635768 0.8107662995335785
# neighbors-of-neighbors 5 0.75 0.1 0.25 3
# 0.7781721062816247 0.4364675585646921
# neighbors-of-neighbors 5 0.75 0.1 0.25 10
# -0.09654740772724872 0.9230858238324982
# neighbors-of-neighbors 5 0.75 0.1 0.5 3
# -0.7588626247361749 0.4479347388132756
# neighbors-of-neighbors 5 0.75 0.1 0.75 3
# 1.2973638096200966 0.19450603856345627
# neighbors-of-neighbors 5 0.75 0.25 0.05 3
# 1.6025129896934625 0.10904221741973849
# neighbors-of-neighbors 5 0.75 0.25 0.1 3
# 1.73685539601507 0.0824126981733556
# neighbors-of-neighbors 5 0.75 0.25 0.1 10
# 0.20727114118190892 0.8357981107453628
# neighbors-of-neighbors 5 0.75 0.25 0.25 3
# 1.6700821373141421 0.09490311377549442
# neighbors-of-neighbors 5 0.75 0.25 0.25 10
# 0.6390860186442192 0.5227669748230976
# neighbors-of-neighbors 5 0.75 0.25 0.5 3
# 1.7099869147507487 0.08726829277674741
# neighbors-of-neighbors 5 0.75 0.25 0.75 3
# -0.7965746538924752 0.4256981025885308
# neighbors-of-neighbors 5 0.75 0.25 0.75 10
# -1.9402881827306475 0.0523446767251481
# neighbors-of-neighbors 5 0.75 0.5 0.05 3
# -0.6601969682090433 0.5091274376215161
# neighbors-of-neighbors 5 0.75 0.5 0.05 10
# 1.4163527980763777 0.1566722365473763
# neighbors-of-neighbors 5 0.75 0.5 0.1 10
# 0.8617105776914548 0.38884680334585797
# neighbors-of-neighbors 5 0.75 0.5 0.25 3
# -0.18232183715075323 0.8553301623212772
# neighbors-of-neighbors 5 0.75 0.5 0.25 10
# -0.3857546238663305 0.6996784039297608
# neighbors-of-neighbors 5 0.75 0.5 0.5 3
# 1.8266769541995458 0.06774835529447196
# neighbors-of-neighbors 5 0.75 0.75 0.01 3
# -0.003838354466331647 0.9969374437525161
# neighbors-of-neighbors 5 0.75 0.75 0.05 3
# 1.7272595098492411 0.08412106747869064
# neighbors-of-neighbors 5 0.75 0.75 0.25 3
# 1.5911012793450587 0.11158678466893003
# neighbors-of-neighbors 5 0.75 0.75 0.5 3
# 1.2301926064592927 0.2186249878927392
# neighbors-of-neighbors 5 0.75 0.75 0.5 10
# 0.3416135475035166 0.7326417405106179
# neighbors-of-neighbors 5 0.75 0.75 0.75 3
# 0.5059084164907832 0.612920943584043
# high-degree-citizens 1 0.01 0.01 0.75 3
# 1.2225158975266295 0.22151259578378568
# high-degree-citizens 1 0.01 0.01 0.75 10
# 1.4404873232905508 0.14972957396737205
# high-degree-citizens 1 0.01 0.05 0.1 3
# 1.9306922965648183 0.05352111613991979
# high-degree-citizens 1 0.01 0.05 0.25 3
# 1.4604938744391915 0.14415438982860032
# high-degree-citizens 1 0.01 0.05 0.25 10
# 1.391403494045222 0.1641031056914024
# high-degree-citizens 1 0.01 0.05 0.5 10
# 0.19378267243985214 0.8463460552201691
# high-degree-citizens 1 0.01 0.05 0.75 3
# -1.7023102058180855 0.08869723264103213
# high-degree-citizens 1 0.01 0.05 0.75 10
# 0.3359849788908255 0.7368821938171055
# high-degree-citizens 1 0.01 0.1 0.05 3
# 1.9249347648653208 0.05423751998129005
# high-degree-citizens 1 0.01 0.1 0.25 3
# -0.9269626036190927 0.3539459510195796
# high-degree-citizens 1 0.01 0.1 0.25 10
# 1.315319611427331 0.1884025098028217
# high-degree-citizens 1 0.01 0.1 0.5 3
# 0.7421744336266476 0.4579816565882321
# high-degree-citizens 1 0.01 0.1 0.5 10
# -0.6659544999085407 0.5054401835855094
# high-degree-citizens 1 0.01 0.1 0.75 3
# 0.3166642434723609 0.7514983830681264
# high-degree-citizens 1 0.01 0.1 0.75 10
# -0.42221899129648116 0.6728651807888246
# high-degree-citizens 1 0.01 0.25 0.01 10
# -0.7427215892351736 0.4576502561739243
# high-degree-citizens 1 0.01 0.25 0.05 3
# -0.03089517047271959 0.9753531414906936
# high-degree-citizens 1 0.01 0.25 0.05 10
# -0.3665628515346723 0.7139451222845772
# high-degree-citizens 1 0.01 0.25 0.1 3
# -0.5565613976180888 0.5778271344533535
# high-degree-citizens 1 0.01 0.25 0.1 10
# 1.7397842872450218 0.08189690253121325
# high-degree-citizens 1 0.01 0.25 0.25 3
# -0.9653461482824092 0.33437146461036793
# high-degree-citizens 1 0.01 0.25 0.5 3
# -0.38959297833266215 0.6968375451659856
# high-degree-citizens 1 0.01 0.25 0.5 10
# -1.5257459003668297 0.12707315852207726
# high-degree-citizens 1 0.01 0.25 0.75 10
# 0.18730197099086252 0.8514238777078418
# high-degree-citizens 1 0.01 0.5 0.25 3
# 0.4817134855246217 0.630009494859147
# high-degree-citizens 1 0.01 0.5 0.25 10
# -1.3434240632160763 0.17913469943635674
# high-degree-citizens 1 0.01 0.5 0.5 10
# 0.38191626939999884 0.702523472158411
# high-degree-citizens 1 0.01 0.5 0.75 10
# 0.7887818428311534 0.430239523567835
# high-degree-citizens 1 0.01 0.75 0.05 3
# -1.827056725973864 0.0676912408007997
# high-degree-citizens 1 0.01 0.75 0.05 10
# -1.3883517231178366 0.16502996933321923
# high-degree-citizens 1 0.01 0.75 0.1 10
# -1.496484819772355 0.13452736083741268
# high-degree-citizens 1 0.01 0.75 0.25 3
# -0.17764723021813764 0.859000030088878
# high-degree-citizens 1 0.01 0.75 0.25 10
# -0.5117012609544181 0.6088601034901006
# high-degree-citizens 1 0.01 0.75 0.5 3
# -0.1573725331195975 0.8749512591028442
# high-degree-citizens 1 0.01 0.75 0.5 10
# 1.4182719753095434 0.1561113753526265
# high-degree-citizens 1 0.01 0.75 0.75 3
# 0.9058516540542686 0.3650143764836147
# high-degree-citizens 1 0.05 0.01 0.1 3
# -0.3032300028402001 0.7617145857596233
# high-degree-citizens 1 0.05 0.01 0.25 3
# 0.2840382305085419 0.7763810829410939
# high-degree-citizens 1 0.05 0.01 0.25 10
# 1.2896871006874333 0.19715932007391535
# high-degree-citizens 1 0.05 0.01 0.5 3
# 0.9114075289452279 0.362080688108105
# high-degree-citizens 1 0.05 0.01 0.5 10
# 0.5522511721998626 0.5807762790196844
# high-degree-citizens 1 0.05 0.01 0.75 10
# -0.07676708932663294 0.9388088323646916
# ...
# 0.7936196915179844 0.4274168652936231
# high-degree-cit-and-media 5 0.01 0.75 0.25 3
# 1.3458708637178471 0.1783441667688873
# high-degree-cit-and-media 5 0.01 0.75 0.5 3
# 1.6600883066884373 0.09689668893727973
# high-degree-cit-and-media 5 0.05 0.01 0.05 3
# 0.771509247732661 0.44040514310631795
# high-degree-cit-and-media 5 0.05 0.01 0.1 3
# -0.23413962244623046 0.8148765864474832
# high-degree-cit-and-media 5 0.05 0.01 0.25 3
# -1.6504924205226081 0.09884226228012435
# high-degree-cit-and-media 5 0.05 0.01 0.25 10
# 0.505009388782645 0.6135522416528005
# high-degree-cit-and-media 5 0.05 0.01 0.5 3
# 0.046342755709079385 0.963037061769895
# high-degree-cit-and-media 5 0.05 0.01 0.5 10
# 0.0907545632636138 0.927687614257537
# high-degree-cit-and-media 5 0.05 0.01 0.75 3
# 1.0094872246452231 0.31274102545806604
# high-degree-cit-and-media 5 0.05 0.05 0.01 10
# 0.32626012963818996 0.7442275511207657
# high-degree-cit-and-media 5 0.05 0.05 0.05 3
# 0.2878765849748735 0.7734412110247795
# high-degree-cit-and-media 5 0.05 0.05 0.05 10
# 0.12858487462211016 0.89768613524464
# high-degree-cit-and-media 5 0.05 0.05 0.1 10
# 0.6371668414110534 0.5240161737105699
# high-degree-cit-and-media 5 0.05 0.05 0.25 10
# -0.09787803889145699 0.9220291386660867
# high-degree-cit-and-media 5 0.05 0.05 0.5 10
# 1.7618047000462258 0.0781023003768407
# high-degree-cit-and-media 5 0.05 0.05 0.75 10
# -0.24373550861205956 0.8074356706537857
# high-degree-cit-and-media 5 0.05 0.1 0.01 10
# -0.6623152170089261 0.5077692265548865
# high-degree-cit-and-media 5 0.05 0.1 0.05 10
# 0.3742395604673356 0.7082260938723048
# high-degree-cit-and-media 5 0.05 0.1 0.1 3
# 0.04030272189648229 0.9678517837842313
# high-degree-cit-and-media 5 0.05 0.1 0.1 10
# -0.42029981406331535 0.6742664457169081
# high-degree-cit-and-media 5 0.05 0.1 0.25 10
# 1.4105952663768802 0.1583639881852129
# high-degree-cit-and-media 5 0.05 0.1 0.5 10
# 0.3089875345396976 0.7573310091666936
# high-degree-cit-and-media 5 0.05 0.25 0.01 10
# -0.06333284869447217 0.9495014587827427
# high-degree-cit-and-media 5 0.05 0.25 0.05 3
# 1.076658427806027 0.28163289118046175
# high-degree-cit-and-media 5 0.05 0.25 0.05 10
# 1.284080522772408 0.19911378228211618
# high-degree-cit-and-media 5 0.05 0.25 0.25 10
# 0.9268551141815877 0.354001764823334
# high-degree-cit-and-media 5 0.05 0.25 0.5 10
# -0.36272449706834065 0.7168106982381137
# high-degree-cit-and-media 5 0.05 0.25 0.75 10
# 0.5258545618874356 0.5989892614306506
# high-degree-cit-and-media 5 0.05 0.5 0.5 10
# 1.3280706453507498 0.18415476986914625
# high-degree-cit-and-media 5 0.05 0.5 0.75 3
# 1.7138252692170803 0.08656082107727454
# high-degree-cit-and-media 5 0.1 0.01 0.01 3
# 1.8117033081085372 0.07003205221012027
# high-degree-cit-and-media 5 0.1 0.01 0.05 3
# -1.7204748056995722 0.08534616950711424
# high-degree-cit-and-media 5 0.1 0.01 0.05 10
# 0.13323542266360322 0.8940071973343866
# high-degree-cit-and-media 5 0.1 0.01 0.1 3
# 0.34929025643617984 0.7268714126094481
# high-degree-cit-and-media 5 0.1 0.01 0.1 10
# -0.28211905327537606 0.7778522239808947
# high-degree-cit-and-media 5 0.1 0.01 0.25 3
# 0.5392888025195964 0.5896875939709143
# high-degree-cit-and-media 5 0.1 0.01 0.25 10
# 0.6717120316080382 0.5017670403101799
# high-degree-cit-and-media 5 0.1 0.01 0.5 10
# 0.09979721612462282 0.9205053182290066
# high-degree-cit-and-media 5 0.1 0.05 0.01 3
# -1.0267598197437156 0.30453357367331435
# high-degree-cit-and-media 5 0.1 0.05 0.01 10
# -0.9538310848834143 0.34016915188524965
# high-degree-cit-and-media 5 0.1 0.05 0.05 3
# 1.8616019161708488 0.06265922300744195
# high-degree-cit-and-media 5 0.1 0.05 0.05 10
# -1.3511007721487396 0.17666315417050116
# high-degree-cit-and-media 5 0.1 0.05 0.1 3
# 0.11131227952361776 0.9113687182684092
# high-degree-cit-and-media 5 0.1 0.05 0.1 10
# 0.2706039898763811 0.7866956268117425
# high-degree-cit-and-media 5 0.1 0.05 0.25 10
# -0.6064600056804001 0.5442093325449675
# high-degree-cit-and-media 5 0.1 0.05 0.5 10
# 0.8290845647276357 0.40705655726438705
# high-degree-cit-and-media 5 0.1 0.1 0.01 3
# -1.1246378586351726 0.2607425241300698
# high-degree-cit-and-media 5 0.1 0.1 0.01 10
# -0.2955532939075368 0.7675712468612716
# high-degree-cit-and-media 5 0.1 0.1 0.1 3
# 0.9384776670180877 0.3479989887720877
# high-degree-cit-and-media 5 0.1 0.1 0.1 10
# -0.5412079797527622 0.5883642379549373
# high-degree-cit-and-media 5 0.1 0.1 0.5 10
# 0.15353417865326588 0.8779770391520672
# high-degree-cit-and-media 5 0.1 0.1 0.75 10
# 1.5391801409989905 0.12376032440614516
# high-degree-cit-and-media 5 0.1 0.25 0.01 3
# 1.1687789349979865 0.2424927095278695
# high-degree-cit-and-media 5 0.1 0.25 0.05 3
# 0.9326479586452227 0.3510017628668958
# high-degree-cit-and-media 5 0.1 0.25 0.1 3
# 0.8885790589557763 0.37422934958738574
# high-degree-cit-and-media 5 0.1 0.25 0.1 10
# 0.4087847506643204 0.6826976317918118
# high-degree-cit-and-media 5 0.1 0.25 0.25 3
# 1.5641294450301462 0.11778717227606685
# high-degree-cit-and-media 5 0.1 0.25 0.5 10
# -0.9288817808522585 0.35295035589113777
# high-degree-cit-and-media 5 0.1 0.25 0.75 10
# 1.0709008961065294 0.2842139929131078
# high-degree-cit-and-media 5 0.1 0.5 0.05 3
# 1.93453065103115 0.053047917242851385
# high-degree-cit-and-media 5 0.1 0.5 0.5 10
# 1.207162479661303 0.22736957691358894
# high-degree-cit-and-media 5 0.1 0.5 0.75 3
# 1.794430713010045 0.07274444841924942
# high-degree-cit-and-media 5 0.1 0.5 0.75 10
# 1.447059633807031 0.14788022231779002
# high-degree-cit-and-media 5 0.25 0.01 0.01 3
# -1.207162479661303 0.22736957691358894
# high-degree-cit-and-media 5 0.25 0.01 0.01 10
# -0.22646291351356715 0.8208414007030007
# high-degree-cit-and-media 5 0.25 0.01 0.05 3
# 1.4393829248743675 0.15004205949830238
# high-degree-cit-and-media 5 0.25 0.01 0.05 10
# 0.7523174754010028 0.4518601611036812
# high-degree-cit-and-media 5 0.25 0.01 0.1 3
# 1.8097841308753715 0.07032926978234619
# high-degree-cit-and-media 5 0.25 0.01 0.1 10
# -0.5483892758907727 0.583424638473497
# high-degree-cit-and-media 5 0.25 0.01 0.25 10
# 0.4267395421544393 0.6695690460753772
# high-degree-cit-and-media 5 0.25 0.05 0.01 3
# -1.8385717893728588 0.06597819377892059
# high-degree-cit-and-media 5 0.25 0.05 0.01 10
# 1.9402881827306475 0.0523446767251481
# high-degree-cit-and-media 5 0.25 0.05 0.05 3
# -1.2261520781360586 0.2201414511186025
# high-degree-cit-and-media 5 0.25 0.05 0.05 10
# -1.355525604490572 0.17525015654716147
# high-degree-cit-and-media 5 0.25 0.05 0.1 3
# 1.15342551713266 0.2487357729107207
# high-degree-cit-and-media 5 0.25 0.05 0.1 10
# 1.5449376726984878 0.12236133996673944
# high-degree-cit-and-media 5 0.25 0.05 0.25 10
# -1.337666531516579 0.18100516573920344
# high-degree-cit-and-media 5 0.25 0.05 0.75 10
# -1.0171639335778864 0.3090754502125299
# high-degree-cit-and-media 5 0.25 0.1 0.01 3
# -0.13434240632160763 0.893131821752615
# high-degree-cit-and-media 5 0.25 0.1 0.01 10
# -0.40686557343115454 0.6841067222171472
# high-degree-cit-and-media 5 0.25 0.1 0.05 3
# 1.3606966583145688 0.173609571084137
# high-degree-cit-and-media 5 0.25 0.1 0.05 10
# 0.3416135475035166 0.7326417405106179
# high-degree-cit-and-media 5 0.25 0.1 0.1 3
# -0.5335312708200989 0.5936658703635442
# high-degree-cit-and-media 5 0.25 0.1 0.1 10
# -1.8539252072381853 0.06374986103542868
# high-degree-cit-and-media 5 0.25 0.1 0.25 10
# 1.9193624656177044 0.054938477667475304
# high-degree-cit-and-media 5 0.25 0.1 0.5 10
# 0.15929171035276335 0.8734390515523964
# high-degree-cit-and-media 5 0.25 0.25 0.01 10
# 0.9288817808522585 0.35295035589113777
# high-degree-cit-and-media 5 0.25 0.25 0.05 10
# 1.3261514681175839 0.1847895309862091
# high-degree-cit-and-media 5 0.25 0.25 0.1 3
# -1.500796596335674 0.13340817930734636
# high-degree-cit-and-media 5 0.25 0.25 0.1 10
# 0.3991888644984913 0.6897540476141777
# high-degree-cit-and-media 5 0.25 0.25 0.25 3
# -0.10939310229045193 0.9128907044912136
# high-degree-cit-and-media 5 0.25 0.25 0.5 10
# 0.38767380109949634 0.6982574461378661
# high-degree-cit-and-media 5 0.25 0.25 0.75 10
# -1.6044321669266284 0.10861882536948049
# high-degree-cit-and-media 5 0.25 0.5 0.01 3
# -0.01727259509849241 0.9862191482850413
# high-degree-cit-and-media 5 0.25 0.5 0.05 3
# -0.42029981406331535 0.6742664457169081
# high-degree-cit-and-media 5 0.25 0.5 0.1 3
# 0.9288817808522585 0.35295035589113777
# high-degree-cit-and-media 5 0.25 0.5 0.25 3
# -1.7406937504814017 0.08173727432960308
# high-degree-cit-and-media 5 0.25 0.5 0.5 3
# -1.3031213413195941 0.19253333872238787
# high-degree-cit-and-media 5 0.25 0.5 0.5 10
# 1.6595621641455471 0.09700256518435443
# high-degree-cit-and-media 5 0.25 0.5 0.75 10
# 1.3088788730190917 0.19057538415453146
# high-degree-cit-and-media 5 0.25 0.75 0.05 3
# 0.9519119076502484 0.34114166001764523
# high-degree-cit-and-media 5 0.25 0.75 0.25 10
# 1.7790772951447182 0.07522709052295362
# high-degree-cit-and-media 5 0.25 0.75 0.5 3
# 1.0094872246452231 0.31274102545806604
# high-degree-cit-and-media 5 0.25 0.75 0.75 10
# 0.5488846886854255 0.5830845864165102
# high-degree-cit-and-media 5 0.5 0.01 0.01 3
# -1.738774573248236 0.08207442277703479
# high-degree-cit-and-media 5 0.5 0.01 0.01 10
# 0.8022160834633142 0.4224279743711339
# high-degree-cit-and-media 5 0.5 0.01 0.05 3
# 1.4086760891437144 0.15893096832462283
# high-degree-cit-and-media 5 0.5 0.01 0.05 10
# 1.1649405805316548 0.24404304566878565
# high-degree-cit-and-media 5 0.5 0.01 0.1 10
# 1.7023102058180855 0.08869723264103213
# high-degree-cit-and-media 5 0.5 0.01 0.25 10
# 0.9768612116814042 0.3286378669763188
# high-degree-cit-and-media 5 0.5 0.01 0.5 10
# -0.5527230431517571 0.5804530719565921
# high-degree-cit-and-media 5 0.5 0.05 0.01 10
# 1.575644508429141 0.11510775263867654
# high-degree-cit-and-media 5 0.5 0.05 0.05 3
# 1.7982690674763766 0.0721343791056096
# high-degree-cit-and-media 5 0.5 0.05 0.1 3
# -1.1131227952361775 0.26565569477059336
# high-degree-cit-and-media 5 0.5 0.05 0.1 10
# -0.35504778813567733 0.7225537906178525
# high-degree-cit-and-media 5 0.5 0.05 0.25 3
# 1.3069596957859257 0.19122640012749392
# high-degree-cit-and-media 5 0.5 0.05 0.25 10
# -0.7657517160331635 0.44382404881545123
# high-degree-cit-and-media 5 0.5 0.05 0.5 3
# 1.3875651395788904 0.16526950283772024
# high-degree-cit-and-media 5 0.5 0.05 0.75 3
# 1.443221279340699 0.1489581469938538
# high-degree-cit-and-media 5 0.5 0.05 0.75 10
# -0.9000941223547712 0.36807016367448087
# high-degree-cit-and-media 5 0.5 0.1 0.01 3
# 1.6504924205226081 0.09884226228012435
# high-degree-cit-and-media 5 0.5 0.1 0.01 10
# 0.9039324768211028 0.3660312069101994
# high-degree-cit-and-media 5 0.5 0.1 0.05 3
# 1.827056725973864 0.0676912408007997
# high-degree-cit-and-media 5 0.5 0.1 0.05 10
# 0.6544394365095458 0.5128287339295505
# high-degree-cit-and-media 5 0.5 0.1 0.1 3
# 1.8289759032070296 0.0674032181768864
# high-degree-cit-and-media 5 0.5 0.1 0.1 10
# 1.8399566878127376 0.06577459639093948
# high-degree-cit-and-media 5 0.5 0.1 0.25 3
# 1.8189531615813659 0.06891857623415527
# high-degree-cit-and-media 5 0.5 0.1 0.25 10
# 1.4528171655065283 0.14627452464863303
# high-degree-cit-and-media 5 0.5 0.1 0.5 10
# 1.9153388786994918 0.055449300439666845
# high-degree-cit-and-media 5 0.5 0.25 0.01 3
# -0.38767380109949634 0.6982574461378661
# high-degree-cit-and-media 5 0.5 0.25 0.05 3
# 1.7003910285849195 0.08905739820497705
# high-degree-cit-and-media 5 0.5 0.25 0.1 3
# 0.03454519019698482 0.9724424072689765
# high-degree-cit-and-media 5 0.5 0.25 0.1 10
# -1.2992829868532625 0.19384683078513643
# high-degree-cit-and-media 5 0.5 0.25 0.25 3
# 1.5142308369678348 0.12996730315983268
# high-degree-cit-and-media 5 0.5 0.25 0.25 10
# 0.8118119696291433 0.41689953274570746
# high-degree-cit-and-media 5 0.5 0.25 0.5 10
# -1.4700897606050207 0.14153744517291428
# high-degree-cit-and-media 5 0.5 0.25 0.75 3
# 0.18999854608341651 0.8493102698369646
# high-degree-cit-and-media 5 0.5 0.5 0.1 10
# 0.30131082560703426 0.763177486650608
# high-degree-cit-and-media 5 0.5 0.5 0.25 3
# 0.09212050719195952 0.9266022953464405
# high-degree-cit-and-media 5 0.5 0.5 0.25 10
# 1.7272595098492411 0.08412106747869064
# high-degree-cit-and-media 5 0.5 0.5 0.5 3
# 1.0593858327075345 0.28942409909654476
# high-degree-cit-and-media 5 0.5 0.5 0.5 10
# -0.9730228572150724 0.3305419420824196
# high-degree-cit-and-media 5 0.5 0.75 0.05 3
# 1.629381470957784 0.10323228879689252
# high-degree-cit-and-media 5 0.5 0.75 0.1 10
# 0.6256517780120584 0.5315433690381426
# high-degree-cit-and-media 5 0.5 0.75 0.5 3
# -0.41262310513065203 0.67988277037759
# high-degree-cit-and-media 5 0.5 0.75 0.5 10
# 0.7607935728907199 0.44678037386331904
# high-degree-cit-and-media 5 0.5 0.75 0.75 10
# -0.6832270950070332 0.49446335401501396
# high-degree-cit-and-media 5 0.75 0.01 0.01 3
# 0.2915731713362911 0.7706129906753921
# high-degree-cit-and-media 5 0.75 0.01 0.01 10
# -1.1284762131015043 0.2591188571074261
# high-degree-cit-and-media 5 0.75 0.01 0.05 3
# -1.3242322908844182 0.18542590970342232
# high-degree-cit-and-media 5 0.75 0.01 0.05 10
# -0.1729149858449519 0.8627182520886836
# high-degree-cit-and-media 5 0.75 0.01 0.1 3
# -0.3166642434723609 0.7514983830681264
# high-degree-cit-and-media 5 0.75 0.01 0.1 10
# -0.3953505100321596 0.6925842275141214
# high-degree-cit-and-media 5 0.75 0.01 0.25 10
# -0.9538310848834143 0.34016915188524965
# high-degree-cit-and-media 5 0.75 0.01 0.5 10
# -0.5738339927165812 0.5660801435165529
# high-degree-cit-and-media 5 0.75 0.01 0.75 10
# 0.7183127134907304 0.47256449290962976
# high-degree-cit-and-media 5 0.75 0.05 0.01 3
# 0.228382090746733 0.8193492110986211
# high-degree-cit-and-media 5 0.75 0.05 0.01 10
# 0.44908747256080267 0.6533685570905088
# high-degree-cit-and-media 5 0.75 0.05 0.05 3
# 1.0862543139718561 0.2773664934897989
# high-degree-cit-and-media 5 0.75 0.05 0.05 10
# 1.4969582418693423 0.1344041239568254
# high-degree-cit-and-media 5 0.75 0.05 0.1 3
# -0.40163721614535464 0.6879510364483259
# high-degree-cit-and-media 5 0.75 0.05 0.1 10
# -0.8463571598261281 0.39735352961405923
# high-degree-cit-and-media 5 0.75 0.05 0.25 3
# 1.050435796072466 0.2935177951248066
# high-degree-cit-and-media 5 0.75 0.05 0.25 10
# 0.5124203212552748 0.608356871776905
# high-degree-cit-and-media 5 0.75 0.05 0.5 3
# -0.9327201353185902 0.3509644858938379
# high-degree-cit-and-media 5 0.75 0.05 0.5 10
# 0.19959443224924564 0.8417977825892821
# high-degree-cit-and-media 5 0.75 0.05 0.75 10
# -0.738883234768842 0.45997790347151124
# high-degree-cit-and-media 5 0.75 0.1 0.01 3
# 0.23989715414572793 0.8104099871120831
# high-degree-cit-and-media 5 0.75 0.1 0.01 10
# 0.27636152157587857 0.7822704075890778
# high-degree-cit-and-media 5 0.75 0.1 0.05 3
# -0.3953505100321596 0.6925842275141214
# high-degree-cit-and-media 5 0.75 0.1 0.05 10
# -0.4913093716904508 0.6232076524641327
# high-degree-cit-and-media 5 0.75 0.1 0.25 3
# -1.0620214849997358 0.28822593165416477
# high-degree-cit-and-media 5 0.75 0.1 0.25 10
# 0.5773534982089473 0.5637006807902722
# high-degree-cit-and-media 5 0.75 0.1 0.5 3
# 1.204911648436064 0.2282374113055513
# high-degree-cit-and-media 5 0.75 0.1 0.75 3
# 1.901904638067331 0.057183622739205985
# high-degree-cit-and-media 5 0.75 0.25 0.05 3
# 1.0056488701788915 0.31458450662362225
# high-degree-cit-and-media 5 0.75 0.25 0.05 10
# 1.8961471063678335 0.05794059510886767
# high-degree-cit-and-media 5 0.75 0.25 0.1 3
# -0.39151215556582797 0.695418705454059
# high-degree-cit-and-media 5 0.75 0.25 0.1 10
# -1.521907545900498 0.12803224816622086
# high-degree-cit-and-media 5 0.75 0.25 0.25 3
# 1.1392594111815348 0.25459497222033345
# high-degree-cit-and-media 5 0.75 0.25 0.25 10
# 1.5986746352271308 0.10989291641530463
# high-degree-cit-and-media 5 0.75 0.25 0.5 3
# 0.6678736771417065 0.5042142312837063
# high-degree-cit-and-media 5 0.75 0.25 0.5 10
# 0.20727114118190892 0.8357981107453628
# high-degree-cit-and-media 5 0.75 0.25 0.75 3
# 0.503202037458905 0.6148222324794231
# high-degree-cit-and-media 5 0.75 0.5 0.05 3
# -0.9384776670180877 0.3479989887720877
# high-degree-cit-and-media 5 0.75 0.5 0.05 10
# 1.5161500142010005 0.12948142413048272
# high-degree-cit-and-media 5 0.75 0.5 0.1 10
# 1.7905923585437133 0.07335873418248692
# high-degree-cit-and-media 5 0.75 0.5 0.25 3
# 0.5047436123226116 0.6137389250435618
# high-degree-cit-and-media 5 0.75 0.5 0.75 10
# 0.06179034094543918 0.9507297955990536
# high-degree-cit-and-media 5 0.75 0.75 0.25 3
# -0.527148846190778 0.598090228436652
# high-degree-cit-and-media 5 0.75 0.75 0.75 3
# 0.22012808961812708 0.825771398951862
# scenarios_non_sig: 2181

# %%
#Ugh- not a lot of evidence here- fails on more than half of the combinations

plt.hist(insig_df["flint-organizing-strategy"])
plt.title("org-strat")
plt.show()

plt.hist(insig_df["organizing-capacity"])
plt.title("org-cap")
plt.show()

plt.hist(insig_df["simple-spread-chance"])
plt.title("p")
plt.show()

plt.hist(insig_df["citizen-citizen-influence"])
plt.title("cc")
plt.show()

plt.hist(insig_df["citizen-media-influence"])
plt.title("cm")
plt.show()

plt.hist(insig_df["ba-m"])
plt.title("ba-m")
plt.show()

plt.hist(insig_df["p*cc"], bins = 100)
plt.title("p*cc")
plt.show()

plt.hist(insig_df["p*cm"], bins = 100)
plt.title("p*cm")
plt.show()

plt.hist(insig_df["p*cc"], bins = 60)
plt.title("p*cc")
plt.show()

plt.hist(insig_df["p*cm"], bins = 60)
plt.title("p*cm")
plt.show()

# %%
#the easiest way to look at sig/insig might be to add a column for this
print(ranksums_df)
# Out:
#       flint-organizing-strategy organizing-capacity  simple-spread-chance  \
# 0        neighbors-of-neighbors                   1                  0.01
# 1        neighbors-of-neighbors                   1                  0.01
# 2        neighbors-of-neighbors                   1                  0.01
# 3        neighbors-of-neighbors                   1                  0.01
# 4        neighbors-of-neighbors                   1                  0.01
# ...                         ...                 ...                   ...
# 3451  high-degree-cit-and-media                   5                  0.75
# 3452  high-degree-cit-and-media                   5                  0.75
# 3453  high-degree-cit-and-media                   5                  0.75
# 3454  high-degree-cit-and-media                   5                  0.75
# 3455  high-degree-cit-and-media                   5                  0.75
#
#       citizen-citizen-influence  citizen-media-influence ba-m  pvalue    p*cc  \
# 0                          0.01                     0.01    3     NaN  0.0001
# 1                          0.01                     0.01   10     NaN  0.0001
# 2                          0.01                     0.05    3     NaN  0.0001
# 3                          0.01                     0.05   10     NaN  0.0001
# 4                          0.01                     0.10    3     NaN  0.0001
# ...                         ...                      ...  ...     ...     ...
# 3451                       0.75                     0.25   10     NaN  0.5625
# 3452                       0.75                     0.50    3     NaN  0.5625
# 3453                       0.75                     0.50   10     NaN  0.5625
# 3454                       0.75                     0.75    3     NaN  0.5625
# 3455                       0.75                     0.75   10     NaN  0.5625
#
#         p*cm sig?
# 0     0.0001    1
# 1     0.0001    1
# 2     0.0005    1
# 3     0.0005    1
# 4     0.0010    1
# ...      ...  ...
# 3451  0.1875    1
# 3452  0.3750    1
# 3453  0.3750    1
# 3454  0.5625    0
# 3455  0.5625    1
#
# [3456 rows x 10 columns]

# %%
p_cc_count = ranksums_df.groupby("p*cc", as_index = False)["sig?"].count()
p_cc_sum = ranksums_df.groupby("p*cc", as_index = False)["sig?"].sum()
p_cc_combo = pd.merge(p_cc_count, p_cc_sum, left_index = True, right_index = True)
p_cm_count = ranksums_df.groupby("p*cm",as_index = False)["sig?"].count()
p_cm_sum = ranksums_df.groupby("p*cm",as_index = False)["sig?"].sum()
p_cm_combo = pd.merge(p_cm_count, p_cm_sum, left_index = True, right_index = True)

p_cc_combo["proportion"] = p_cc_combo["sig?_y"]/p_cc_combo["sig?_x"]
print(p_cc_combo)

p_cm_combo["proportion"] = p_cm_combo["sig?_y"]/p_cm_combo["sig?_x"]
print(p_cm_combo)
# Out:
#     p*cc_x  sig?_x  p*cc_y  sig?_y  proportion
# 0   0.0001      96  0.0001      73    0.760417
# 1   0.0005     192  0.0005      93    0.484375
# 2   0.0010     192  0.0010      66    0.343750
# 3   0.0025     192  0.0025      64    0.333333
# 4   0.0025      96  0.0025      24    0.250000
# 5   0.0050     192  0.0050      66    0.343750
# 6   0.0050     192  0.0050      51    0.265625
# 7   0.0075     192  0.0075      62    0.322917
# 8   0.0100      96  0.0100      29    0.302083
# 9   0.0125     192  0.0125      60    0.312500
# 10  0.0250     384  0.0250     128    0.333333
# 11  0.0375     192  0.0375      78    0.406250
# 12  0.0500     192  0.0500      53    0.276042
# 13  0.0625      96  0.0625      39    0.406250
# 14  0.0750     192  0.0750      90    0.468750
# 15  0.1250     192  0.1250      58    0.302083
# 16  0.1875     192  0.1875      74    0.385417
# 17  0.2500      96  0.2500      37    0.385417
# 18  0.3750     192  0.3750      85    0.442708
# 19  0.5625      96  0.5625      45    0.468750
#     p*cm_x  sig?_x  p*cm_y  sig?_y  proportion
# 0   0.0001      96  0.0001      73    0.760417
# 1   0.0005     192  0.0005     102    0.531250
# 2   0.0010     192  0.0010      85    0.442708
# 3   0.0025     192  0.0025      68    0.354167
# 4   0.0025      96  0.0025      37    0.385417
# 5   0.0050     192  0.0050      70    0.364583
# 6   0.0050     192  0.0050      62    0.322917
# 7   0.0075     192  0.0075      86    0.447917
# 8   0.0100      96  0.0100      31    0.322917
# 9   0.0125     192  0.0125      60    0.312500
# 10  0.0250     384  0.0250     136    0.354167
# 11  0.0375     192  0.0375      67    0.348958
# 12  0.0500     192  0.0500      57    0.296875
# 13  0.0625      96  0.0625      33    0.343750
# 14  0.0750     192  0.0750      73    0.380208
# 15  0.1250     192  0.1250      52    0.270833
# 16  0.1875     192  0.1875      62    0.322917
# 17  0.2500      96  0.2500      30    0.312500
# 18  0.3750     192  0.3750      57    0.296875
# 19  0.5625      96  0.5625      34    0.354167

# %%
sns.barplot(data=p_cc_combo, x="p*cc_x",  y = "proportion")
plt.title("P*CC on Proportion of Significant Scenarios")
plt.xticks(rotation= 45)
plt.show()

sns.barplot(data=p_cm_combo, x="p*cm_x",  y = "proportion")
plt.title("P*CM on Proportion of Significant Scenarios")
plt.xticks(rotation = 45)
plt.show()

# %%
#really hard to tell anything here- UGHHHHHHH
#what if we further limited our analysis to those scenarios that surpassed a threshold

# %%
#Let's Re-do the CDF so that it looks nice

#can we do a p-cc p-cm grid????
org_mod_df['p-cc'] = org_mod_df["simple-spread-chance"] * org_mod_df["citizen-citizen-influence"]
org_mod_df['p-cm'] = org_mod_df["simple-spread-chance"] * org_mod_df["citizen-media-influence"]
infl_mod_df["p-cm"] = infl_mod_df["simple-spread-chance"] * infl_mod_df['citizen-media-influence']
infl_mod_df["p-cc"] = infl_mod_df["simple-spread-chance"] * infl_mod_df['citizen-citizen-influence']

print(org_mod_df)
# Out:
#         Unnamed: 0     run    n spread-type  simple-spread-chance  \
# 0                0       0  300      simple                  0.01
# 1                1       1  300      simple                  0.01
# 2                2       2  300      simple                  0.01
# 3                3       3  300      simple                  0.01
# 4                4       4  300      simple                  0.01
# ...            ...     ...  ...         ...                   ...
# 103629      103629  103629  300      simple                  0.75
# 103630      103630  103630  300      simple                  0.75
# 103631      103631  103631  300      simple                  0.75
# 103632      103632  103632  300      simple                  0.75
# 103633      103633  103633  300      simple                  0.75
#
#              graph-type  ba-m  citizen-media-influence  \
# 0       barabasi-albert     3                     0.01
# 1       barabasi-albert     3                     0.01
# 2       barabasi-albert     3                     0.01
# 3       barabasi-albert     3                     0.01
# 4       barabasi-albert     3                     0.01
# ...                 ...   ...                      ...
# 103629  barabasi-albert    10                     0.75
# 103630  barabasi-albert    10                     0.75
# 103631  barabasi-albert    10                     0.75
# 103632  barabasi-albert    10                     0.75
# 103633  barabasi-albert    10                     0.75
#
#         citizen-citizen-influence  organizing-capacity  ... total-spread  \
# 0                            0.01                    1  ...            0
# 1                            0.01                    1  ...            0
# 2                            0.01                    1  ...            1
# 3                            0.01                    1  ...            0
# 4                            0.01                    1  ...            0
# ...                           ...                  ...  ...          ...
# 103629                       0.75                    5  ...          324
# 103630                       0.75                    5  ...          327
# 103631                       0.75                    5  ...          327
# 103632                       0.75                    5  ...          326
# 103633                       0.75                    5  ...          326
#
#         1-week-spread 2-week-spread  3-week-spread 4-week-spread  \
# 0                 NaN           NaN            NaN           NaN
# 1                 NaN           NaN            NaN           NaN
# 2                 NaN           NaN            NaN           NaN
# 3                 NaN           NaN            NaN           NaN
# 4                 NaN           NaN            NaN           NaN
# ...               ...           ...            ...           ...
# 103629            NaN           NaN            NaN           NaN
# 103630            NaN           NaN            NaN           NaN
# 103631            NaN           NaN            NaN           NaN
# 103632            NaN           NaN            NaN           NaN
# 103633            NaN           NaN            NaN           NaN
#
#        5-week-spread  total-error         r    p-cm    p-cc
# 0                NaN   467.000000       NaN  0.0001  0.0001
# 1                NaN   467.000000       NaN  0.0001  0.0001
# 2                NaN   541.000000  0.070881  0.0001  0.0001
# 3                NaN   467.000000       NaN  0.0001  0.0001
# 4                NaN   467.000000       NaN  0.0001  0.0001
# ...              ...          ...       ...     ...     ...
# 103629           NaN   772.538462 -0.064171  0.5625  0.5625
# 103630           NaN   781.588235 -0.064373  0.5625  0.5625
# 103631           NaN   766.738318 -0.062823  0.5625  0.5625
# 103632           NaN   715.692913 -0.061499  0.5625  0.5625
# 103633           NaN   677.569536 -0.057693  0.5625  0.5625
#
# [103634 rows x 28 columns]

# %%
sns.boxplot(data= org_mod_df, y="peak-time", x="p-cc")
plt.title("Org_Mod_P_cc")
plt.show()

sns.boxplot(data= org_mod_df, y="peak-time", x="p-cm")
plt.title("Org_Mod_P_cm")
plt.show()

sns.boxplot(data= infl_mod_df, y="peak-time", x="p-cc")
plt.title("infl_Mod_P_cc")
plt.show()

sns.boxplot(data= infl_mod_df, y="peak-time", x="p-cm")
plt.title("infl_Mod_P_cm")
plt.show()
